# %%
import argparse
import yaml
import time
import datetime
import cv2
import torch
from torch.autograd import Variable
import numpy as np
from astropy.visualization import make_lupton_rgb
import random
import numpy as np
from scipy.ndimage import zoom
from __future__ import print_function, division
import os
import torch
import pandas as pd
from skimage import io, transform
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils
from scipy import ndimage, misc
import warnings
import torch.optim as optim
from sklearn.model_selection import KFold
from sklearn.metrics import mean_absolute_error
import sys

# %%
# Load the Drive helper and mount
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !cp -r "/content/drive/My Drive/BerkeleyResults/satellite" ./satellite

# %%
# !ls satellite/
# Out:
# 38.820636,-77.01538.png  38.898014,-76.97927.png  38.938009,-76.98513.png
# 38.831034,-77.00539.png  38.906416,-76.94851.png  38.939464,-77.05280.png
# 38.864641,-76.98592.png  38.906416,-76.98451.png  38.945614,-77.01564.png
# 38.8731,-76.97281.png	 38.907205,-77.05396.png  38.952145,-77.07169.png
# 38.874409,-76.95854.png  38.907725,-77.04406.png  38.954471,-77.06362.png
# 38.874658,-76.98730.png  38.913193,-76.99032.png  38.95682,-77.05096.png
# 38.875372,-77.03315.png  38.914004,-77.05731.png  38.956854,-77.05108.png
# 38.884384,-76.93195.png  38.914656,-77.09722.png  38.971088,-77.02990.png
# 38.887646,-77.04767.png  38.920896,-76.96704.png  38.972853,-77.05300.png
# 38.887771,-77.04232.png  38.921453,-77.01448.png  38.972854,-77.05297.png
# 38.888979,-77.00092.png  38.927132,-77.04890.png  38.980315,-77.05194.png
# 38.890913,-77.01556.png  38.931573,-77.04472.png  38.985287,-77.03816.png
# 38.891675,-77.01952.png  38.937768,-77.09681.png  satellite
# 38.891721,-77.02219.png  38.938009,-76.95813.png

# %%
# !nvidia-smi
# Out:
# Tue Jun 23 09:21:58 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.36.06    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   41C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
categorical_columns = ['TRAPTYPE', 'ATTRACTANTSUSED', 'SETTIMEOFDAY', 'COLLECTTIMEOFDAY', 'GENUS', 'SPECIES', 'TRAPID','TRAPSITE']
numerical_columns = ['LATITUDE', 'LONGITUDE', 'TRAPSET', 'YEAR','TRAPCOLLECT', 'DIFF_DAYS']

weather_columns = ['sunriseTime', 'sunsetTime', 'moonPhase', 
                     'precipIntensity', 'precipIntensityMax', 'precipProbability', 'temperatureHigh', 'temperatureHighTime',
                     'temperatureLow', 'temperatureLowTime', 'apparentTemperatureHigh', 'apparentTemperatureHighTime',
                     'apparentTemperatureLow', 'apparentTemperatureLowTime', 'dewPoint', 'humidity', 'pressure', 'windSpeed', 'windGust', 
                     'windGustTime', 'windBearing', 'cloudCover', 'uvIndex', 'uvIndexTime','visibility', 'temperatureMin',
                     'temperatureMinTime', 'temperatureMax', 'temperatureMaxTime', 'apparentTemperatureMin','apparentTemperatureMinTime', 'apparentTemperatureMax',
                     'apparentTemperatureMaxTime','time']

for item in weather_columns:
    numerical_columns.append(item + str(14))

# %%
sentinel_frame = pd.read_csv('/content/drive/My Drive/BerkeleyResults/Approach2/original_mosquito_weather_semi_clean.csv')
sentinel_frame["TRAPSET"]= pd.to_datetime(sentinel_frame["TRAPSET"])
sentinel_frame["TRAPCOLLECT"]= pd.to_datetime(sentinel_frame["TRAPCOLLECT"])
sentinel_frame["DIFF_DAYS"] = (sentinel_frame["TRAPCOLLECT"] - sentinel_frame["TRAPSET"]).dt.days
sentinel_frame["TRAPSET"]= sentinel_frame["TRAPSET"].dt.week
sentinel_frame["TRAPCOLLECT"]= sentinel_frame["TRAPCOLLECT"].dt.week
sentinel_frame["LATITUDE2"]= sentinel_frame["LATITUDE"]
sentinel_frame["LONGITUDE2"]= sentinel_frame["LONGITUDE"]

for category in categorical_columns:
    sentinel_frame[category] = sentinel_frame[category].astype('category')

categorical_column_sizes = [len(sentinel_frame[column].cat.categories) for column in categorical_columns]
categorical_embedding_sizes = [(col_size, min(50, (col_size+1)//2)) for col_size in categorical_column_sizes]

for col in numerical_columns:
    sentinel_frame[col] = (sentinel_frame[col] - sentinel_frame[col].mean()) / (sentinel_frame[col].max() - sentinel_frame[col].min())
    
def get_categorical_tensor(in_frame, categories):
    categorical_data = np.stack([in_frame[col].cat.codes.values for col in categories], 1)
    categorical_data = torch.tensor(categorical_data, dtype=torch.int64)
    return categorical_data

def get_numerical_tensor(in_frame, numerical_columns):
    numerical_data = np.stack([in_frame[col].values for col in numerical_columns], 1)
    numerical_data = torch.tensor(numerical_data, dtype=torch.float)
    return numerical_data

count = 0
for i in sentinel_frame.columns:
    print(count, i)
    count+= 1
# Out:
# 0 Unnamed: 0
# 1 X
# 2 Y
# 3 OBJECTID
# 4 TRAPTYPE
# 5 ATTRACTANTSUSED
# 6 TRAPID
# 7 LATITUDE
# 8 LONGITUDE
# 9 ADDRESS
# 10 TOWN
# 11 STATE
# 12 COUNTY
# 13 TRAPSITE
# 14 TRAPSET
# 15 SETTIMEOFDAY
# 16 TRAPCOLLECT
# 17 YEAR
# 18 COLLECTTIMEOFDAY
# 19 GENUS
# 20 SPECIES
# 21 TOTAL
# 22 sunriseTime1
# 23 sunsetTime1
# 24 moonPhase1
# 25 precipIntensity1
# 26 precipIntensityMax1
# 27 precipProbability1
# 28 temperatureHigh1
# 29 temperatureHighTime1
# 30 temperatureLow1
# 31 temperatureLowTime1
# 32 apparentTemperatureHigh1
# 33 apparentTemperatureHighTime1
# 34 apparentTemperatureLow1
# 35 apparentTemperatureLowTime1
# 36 dewPoint1
# 37 humidity1
# 38 pressure1
# 39 windSpeed1
# 40 windGust1
# 41 windGustTime1
# 42 windBearing1
# 43 cloudCover1
# 44 uvIndex1
# 45 uvIndexTime1
# 46 visibility1
# 47 temperatureMin1
# 48 temperatureMinTime1
# 49 temperatureMax1
# 50 temperatureMaxTime1
# 51 apparentTemperatureMin1
# 52 apparentTemperatureMinTime1
# 53 apparentTemperatureMax1
# 54 apparentTemperatureMaxTime1
# 55 icon1
# 56 time1
# 57 precipIntensityMaxTime1
# 58 precipType1
# 59 summary1
# 60 sunriseTime2
# 61 sunsetTime2
# 62 moonPhase2
# 63 precipIntensity2
# 64 precipIntensityMax2
# 65 precipProbability2
# 66 temperatureHigh2
# 67 temperatureHighTime2
# 68 temperatureLow2
# 69 temperatureLowTime2
# 70 apparentTemperatureHigh2
# 71 apparentTemperatureHighTime2
# 72 apparentTemperatureLow2
# 73 apparentTemperatureLowTime2
# 74 dewPoint2
# 75 humidity2
# 76 pressure2
# 77 windSpeed2
# 78 windGust2
# 79 windGustTime2
# 80 windBearing2
# 81 cloudCover2
# 82 uvIndex2
# 83 uvIndexTime2
# 84 visibility2
# 85 temperatureMin2
# 86 temperatureMinTime2
# 87 temperatureMax2
# 88 temperatureMaxTime2
# 89 apparentTemperatureMin2
# 90 apparentTemperatureMinTime2
# 91 apparentTemperatureMax2
# 92 apparentTemperatureMaxTime2
# 93 icon2
# 94 time2
# 95 precipIntensityMaxTime2
# 96 precipType2
# 97 summary2
# 98 sunriseTime3
# 99 sunsetTime3
# 100 moonPhase3
# 101 precipIntensity3
# 102 precipIntensityMax3
# 103 precipProbability3
# 104 temperatureHigh3
# 105 temperatureHighTime3
# 106 temperatureLow3
# 107 temperatureLowTime3
# 108 apparentTemperatureHigh3
# 109 apparentTemperatureHighTime3
# 110 apparentTemperatureLow3
# 111 apparentTemperatureLowTime3
# 112 dewPoint3
# 113 humidity3
# 114 pressure3
# 115 windSpeed3
# 116 windGust3
# 117 windGustTime3
# 118 windBearing3
# 119 cloudCover3
# 120 uvIndex3
# 121 uvIndexTime3
# 122 visibility3
# 123 temperatureMin3
# 124 temperatureMinTime3
# 125 temperatureMax3
# 126 temperatureMaxTime3
# 127 apparentTemperatureMin3
# 128 apparentTemperatureMinTime3
# 129 apparentTemperatureMax3
# 130 apparentTemperatureMaxTime3
# 131 icon3
# 132 time3
# 133 precipIntensityMaxTime3
# 134 precipType3
# 135 summary3
# 136 sunriseTime4
# 137 sunsetTime4
# 138 moonPhase4
# 139 precipIntensity4
# 140 precipIntensityMax4
# 141 precipProbability4
# 142 temperatureHigh4
# 143 temperatureHighTime4
# 144 temperatureLow4
# 145 temperatureLowTime4
# 146 apparentTemperatureHigh4
# 147 apparentTemperatureHighTime4
# 148 apparentTemperatureLow4
# 149 apparentTemperatureLowTime4
# 150 dewPoint4
# 151 humidity4
# 152 pressure4
# 153 windSpeed4
# 154 windGust4
# 155 windGustTime4
# 156 windBearing4
# 157 cloudCover4
# 158 uvIndex4
# 159 uvIndexTime4
# 160 visibility4
# 161 temperatureMin4
# 162 temperatureMinTime4
# 163 temperatureMax4
# 164 temperatureMaxTime4
# 165 apparentTemperatureMin4
# 166 apparentTemperatureMinTime4
# 167 apparentTemperatureMax4
# 168 apparentTemperatureMaxTime4
# 169 icon4
# 170 time4
# 171 precipIntensityMaxTime4
# 172 precipType4
# 173 summary4
# 174 sunriseTime5
# 175 sunsetTime5
# 176 moonPhase5
# 177 precipIntensity5
# 178 precipIntensityMax5
# 179 precipProbability5
# 180 temperatureHigh5
# 181 temperatureHighTime5
# 182 temperatureLow5
# 183 temperatureLowTime5
# 184 apparentTemperatureHigh5
# 185 apparentTemperatureHighTime5
# 186 apparentTemperatureLow5
# 187 apparentTemperatureLowTime5
# 188 dewPoint5
# 189 humidity5
# 190 pressure5
# 191 windSpeed5
# 192 windGust5
# 193 windGustTime5
# 194 windBearing5
# 195 cloudCover5
# 196 uvIndex5
# 197 uvIndexTime5
# 198 visibility5
# 199 temperatureMin5
# 200 temperatureMinTime5
# 201 temperatureMax5
# 202 temperatureMaxTime5
# 203 apparentTemperatureMin5
# 204 apparentTemperatureMinTime5
# 205 apparentTemperatureMax5
# 206 apparentTemperatureMaxTime5
# 207 icon5
# 208 time5
# 209 precipIntensityMaxTime5
# 210 precipType5
# 211 summary5
# 212 sunriseTime6
# 213 sunsetTime6
# 214 moonPhase6
# 215 precipIntensity6
# 216 precipIntensityMax6
# 217 precipProbability6
# 218 temperatureHigh6
# 219 temperatureHighTime6
# 220 temperatureLow6
# 221 temperatureLowTime6
# 222 apparentTemperatureHigh6
# 223 apparentTemperatureHighTime6
# 224 apparentTemperatureLow6
# 225 apparentTemperatureLowTime6
# 226 dewPoint6
# 227 humidity6
# 228 pressure6
# 229 windSpeed6
# 230 windGust6
# 231 windGustTime6
# 232 windBearing6
# 233 cloudCover6
# 234 uvIndex6
# 235 uvIndexTime6
# 236 visibility6
# 237 temperatureMin6
# 238 temperatureMinTime6
# 239 temperatureMax6
# 240 temperatureMaxTime6
# 241 apparentTemperatureMin6
# 242 apparentTemperatureMinTime6
# 243 apparentTemperatureMax6
# 244 apparentTemperatureMaxTime6
# 245 icon6
# 246 time6
# 247 precipIntensityMaxTime6
# 248 precipType6
# 249 summary6
# 250 sunriseTime7
# 251 sunsetTime7
# 252 moonPhase7
# 253 precipIntensity7
# 254 precipIntensityMax7
# 255 precipProbability7
# 256 temperatureHigh7
# 257 temperatureHighTime7
# 258 temperatureLow7
# 259 temperatureLowTime7
# 260 apparentTemperatureHigh7
# 261 apparentTemperatureHighTime7
# 262 apparentTemperatureLow7
# 263 apparentTemperatureLowTime7
# 264 dewPoint7
# 265 humidity7
# 266 pressure7
# 267 windSpeed7
# 268 windGust7
# 269 windGustTime7
# 270 windBearing7
# 271 cloudCover7
# 272 uvIndex7
# 273 uvIndexTime7
# 274 visibility7
# 275 temperatureMin7
# 276 temperatureMinTime7
# 277 temperatureMax7
# 278 temperatureMaxTime7
# 279 apparentTemperatureMin7
# 280 apparentTemperatureMinTime7
# 281 apparentTemperatureMax7
# 282 apparentTemperatureMaxTime7
# 283 icon7
# 284 time7
# 285 precipIntensityMaxTime7
# 286 precipType7
# 287 summary7
# 288 sunriseTime8
# 289 sunsetTime8
# 290 moonPhase8
# 291 precipIntensity8
# 292 precipIntensityMax8
# 293 precipProbability8
# 294 temperatureHigh8
# 295 temperatureHighTime8
# 296 temperatureLow8
# 297 temperatureLowTime8
# 298 apparentTemperatureHigh8
# 299 apparentTemperatureHighTime8
# 300 apparentTemperatureLow8
# 301 apparentTemperatureLowTime8
# 302 dewPoint8
# 303 humidity8
# 304 pressure8
# 305 windSpeed8
# 306 windGust8
# 307 windGustTime8
# 308 windBearing8
# 309 cloudCover8
# 310 uvIndex8
# 311 uvIndexTime8
# 312 visibility8
# 313 temperatureMin8
# 314 temperatureMinTime8
# 315 temperatureMax8
# 316 temperatureMaxTime8
# 317 apparentTemperatureMin8
# 318 apparentTemperatureMinTime8
# 319 apparentTemperatureMax8
# 320 apparentTemperatureMaxTime8
# 321 icon8
# 322 time8
# 323 precipIntensityMaxTime8
# 324 precipType8
# 325 summary8
# 326 sunriseTime9
# 327 sunsetTime9
# 328 moonPhase9
# 329 precipIntensity9
# 330 precipIntensityMax9
# 331 precipProbability9
# 332 temperatureHigh9
# 333 temperatureHighTime9
# 334 temperatureLow9
# 335 temperatureLowTime9
# 336 apparentTemperatureHigh9
# 337 apparentTemperatureHighTime9
# 338 apparentTemperatureLow9
# 339 apparentTemperatureLowTime9
# 340 dewPoint9
# 341 humidity9
# 342 pressure9
# 343 windSpeed9
# 344 windGust9
# 345 windGustTime9
# 346 windBearing9
# 347 cloudCover9
# 348 uvIndex9
# 349 uvIndexTime9
# 350 visibility9
# 351 temperatureMin9
# 352 temperatureMinTime9
# 353 temperatureMax9
# 354 temperatureMaxTime9
# 355 apparentTemperatureMin9
# 356 apparentTemperatureMinTime9
# 357 apparentTemperatureMax9
# 358 apparentTemperatureMaxTime9
# 359 icon9
# 360 time9
# 361 precipIntensityMaxTime9
# 362 precipType9
# 363 summary9
# 364 sunriseTime10
# 365 sunsetTime10
# 366 moonPhase10
# 367 precipIntensity10
# 368 precipIntensityMax10
# 369 precipProbability10
# 370 temperatureHigh10
# 371 temperatureHighTime10
# 372 temperatureLow10
# 373 temperatureLowTime10
# 374 apparentTemperatureHigh10
# 375 apparentTemperatureHighTime10
# 376 apparentTemperatureLow10
# 377 apparentTemperatureLowTime10
# 378 dewPoint10
# 379 humidity10
# 380 pressure10
# 381 windSpeed10
# 382 windGust10
# 383 windGustTime10
# 384 windBearing10
# 385 cloudCover10
# 386 uvIndex10
# 387 uvIndexTime10
# 388 visibility10
# 389 temperatureMin10
# 390 temperatureMinTime10
# 391 temperatureMax10
# 392 temperatureMaxTime10
# 393 apparentTemperatureMin10
# 394 apparentTemperatureMinTime10
# 395 apparentTemperatureMax10
# 396 apparentTemperatureMaxTime10
# 397 icon10
# 398 time10
# 399 precipIntensityMaxTime10
# 400 precipType10
# 401 summary10
# 402 sunriseTime11
# 403 sunsetTime11
# 404 moonPhase11
# 405 precipIntensity11
# 406 precipIntensityMax11
# 407 precipProbability11
# 408 temperatureHigh11
# 409 temperatureHighTime11
# 410 temperatureLow11
# 411 temperatureLowTime11
# 412 apparentTemperatureHigh11
# 413 apparentTemperatureHighTime11
# 414 apparentTemperatureLow11
# 415 apparentTemperatureLowTime11
# 416 dewPoint11
# 417 humidity11
# 418 pressure11
# 419 windSpeed11
# 420 windGust11
# 421 windGustTime11
# 422 windBearing11
# 423 cloudCover11
# 424 uvIndex11
# 425 uvIndexTime11
# 426 visibility11
# 427 temperatureMin11
# 428 temperatureMinTime11
# 429 temperatureMax11
# 430 temperatureMaxTime11
# 431 apparentTemperatureMin11
# 432 apparentTemperatureMinTime11
# 433 apparentTemperatureMax11
# 434 apparentTemperatureMaxTime11
# 435 icon11
# 436 time11
# 437 precipIntensityMaxTime11
# 438 precipType11
# 439 summary11
# 440 sunriseTime12
# 441 sunsetTime12
# 442 moonPhase12
# 443 precipIntensity12
# 444 precipIntensityMax12
# 445 precipProbability12
# 446 temperatureHigh12
# 447 temperatureHighTime12
# 448 temperatureLow12
# 449 temperatureLowTime12
# 450 apparentTemperatureHigh12
# 451 apparentTemperatureHighTime12
# 452 apparentTemperatureLow12
# 453 apparentTemperatureLowTime12
# 454 dewPoint12
# 455 humidity12
# 456 pressure12
# 457 windSpeed12
# 458 windGust12
# 459 windGustTime12
# 460 windBearing12
# 461 cloudCover12
# 462 uvIndex12
# 463 uvIndexTime12
# 464 visibility12
# 465 temperatureMin12
# 466 temperatureMinTime12
# 467 temperatureMax12
# 468 temperatureMaxTime12
# 469 apparentTemperatureMin12
# 470 apparentTemperatureMinTime12
# 471 apparentTemperatureMax12
# 472 apparentTemperatureMaxTime12
# 473 icon12
# 474 time12
# 475 precipIntensityMaxTime12
# 476 precipType12
# 477 summary12
# 478 sunriseTime13
# 479 sunsetTime13
# 480 moonPhase13
# 481 precipIntensity13
# 482 precipIntensityMax13
# 483 precipProbability13
# 484 temperatureHigh13
# 485 temperatureHighTime13
# 486 temperatureLow13
# 487 temperatureLowTime13
# 488 apparentTemperatureHigh13
# 489 apparentTemperatureHighTime13
# 490 apparentTemperatureLow13
# 491 apparentTemperatureLowTime13
# 492 dewPoint13
# 493 humidity13
# 494 pressure13
# 495 windSpeed13
# 496 windGust13
# 497 windGustTime13
# 498 windBearing13
# 499 cloudCover13
# 500 uvIndex13
# 501 uvIndexTime13
# 502 visibility13
# 503 temperatureMin13
# 504 temperatureMinTime13
# 505 temperatureMax13
# 506 temperatureMaxTime13
# 507 apparentTemperatureMin13
# 508 apparentTemperatureMinTime13
# 509 apparentTemperatureMax13
# 510 apparentTemperatureMaxTime13
# 511 icon13
# 512 time13
# 513 precipIntensityMaxTime13
# 514 precipType13
# 515 summary13
# 516 sunriseTime14
# 517 sunsetTime14
# 518 moonPhase14
# 519 precipIntensity14
# 520 precipIntensityMax14
# 521 precipProbability14
# 522 temperatureHigh14
# 523 temperatureHighTime14
# 524 temperatureLow14
# 525 temperatureLowTime14
# 526 apparentTemperatureHigh14
# 527 apparentTemperatureHighTime14
# 528 apparentTemperatureLow14
# 529 apparentTemperatureLowTime14
# 530 dewPoint14
# 531 humidity14
# 532 pressure14
# 533 windSpeed14
# 534 windGust14
# 535 windGustTime14
# 536 windBearing14
# 537 cloudCover14
# 538 uvIndex14
# 539 uvIndexTime14
# 540 visibility14
# 541 temperatureMin14
# 542 temperatureMinTime14
# 543 temperatureMax14
# 544 temperatureMaxTime14
# 545 apparentTemperatureMin14
# 546 apparentTemperatureMinTime14
# 547 apparentTemperatureMax14
# 548 apparentTemperatureMaxTime14
# 549 icon14
# 550 time14
# 551 precipIntensityMaxTime14
# 552 precipType14
# 553 summary14
# 554 DIFF_DAYS
# 555 LATITUDE2
# 556 LONGITUDE2

# %%
def paddedzoom(img, zoomfactor=0.8):
    out  = np.zeros_like(img)
    zoomed = cv2.resize(img, None, fx=zoomfactor, fy=zoomfactor)
    
    h, w, _ = img.shape
    zh, zw, _ = zoomed.shape
    if zoomfactor<1:    
        out[int((h-zh)/2):int(-(h-zh)/2),int((w-zw)/2):int(-(w-zw)/2),:] = zoomed
    else:
        out = zoomed[int((zh-h)/2):int(-(zh-h)/2), int((zw-w)/2):int(-(zw-w)/2), :]

    return out

def get_random_crop(image, crop_height, crop_width):

    original_shape = image.shape
    max_x = image.shape[1] - crop_width
    max_y = image.shape[0] - crop_height

    x = np.random.randint(0, max_x)
    y = np.random.randint(0, max_y)

    crop = image[y: y + crop_height, x: x + crop_width]
    resized = cv2.resize(crop, (416, 416), interpolation = cv2.INTER_AREA)

    return resized

def get_affeine(img, rows, cols):
    offset1 = ((random.random() * 2 ) - 1) * 40
    offset2 = ((random.random() * 2 ) - 1) * 40
    M = np.float32([[1,0,offset1],[0,1,offset2]])
    dst = cv2.warpAffine(img,M,(cols,rows))

    return dst

def distort(img, orientation='horizontal', func=np.sin, x_scale=0.05, y_scale=5):
    assert orientation[:3] in ['hor', 'ver'], "dist_orient should be 'horizontal'|'vertical'"
    assert func in [np.sin, np.cos], "supported functions are np.sin and np.cos"
    assert 0.00 <= x_scale <= 0.1, "x_scale should be in [0.0, 0.1]"
    assert 0 <= y_scale <= min(img.shape[0], img.shape[1]), "y_scale should be less then image size"
    img_dist = img.copy()
    
    def shift(x):
        return int(y_scale * func(np.pi * x * x_scale))
    
    for c in range(3):
        for i in range(img.shape[orientation.startswith('ver')]):
            if orientation.startswith('ver'):
                img_dist[:, i, c] = np.roll(img[:, i, c], shift(i))
            else:
                img_dist[i, :, c] = np.roll(img[i, :, c], shift(i))
            
    return img_dist

class SentinelDataset(Dataset):

    def __init__(self, root_dir, data, transform=None):
        self.data = data
        self.root_dir = root_dir
        self.transform = transform

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()
        

        filename = str(self.data.iloc[idx, 555])[0:9]+',' + str(self.data.iloc[idx, 556])[0:9] + '.png'
        img_name = os.path.join(self.root_dir, filename)
        
        image = cv2.imread(img_name)
        image = cv2.resize(image, (416, 416), interpolation = cv2.INTER_AREA)

        #random flip
        if np.random.rand() > 0.5:
            image = np.flip(image, axis=1).copy()
        
        # if np.random.rand() > 0.5:
        #     image = distort(image, orientation=random.choice(['ver','hor']), x_scale=random.uniform(0.01, 0.03), y_scale=random.randint(2,10))
        
        #random rotate
        image = ndimage.rotate(image, random.randint(0,359), axes = [0,1],reshape=False)

        # random zoom
        or_image = image.copy()
        image = paddedzoom(image, 1.0 + (np.random.rand()/2) )
        if image.shape != or_image.shape:
            image = or_image
        
        if np.random.rand() > 0.2:
            image = get_random_crop(image, 380, 380)
        
        if np.random.rand() > 0.5:
            image = get_affeine(image, 416, 416)

        image = torch.from_numpy(image)

        current_row = self.data.iloc[[idx]]
        target = current_row['TOTAL'].values

        category_tensor = get_categorical_tensor(current_row, categorical_columns)
        numerical_tensor = get_numerical_tensor(current_row, numerical_columns)

        # from matplotlib.pyplot import figure
        # from matplotlib import pyplot as PLT


        # PLT.imshow(image)
        # PLT.show()
        # print(numerical_tensor)
        # print(target)
        # print(idx)
        # raise ValueError('A very specific bad thing happened.')

        return image,category_tensor ,numerical_tensor, target

# %%
import torch
import torch.nn as nn

from collections import defaultdict

class Flatten(torch.nn.Module):
    def forward(self, x):
        return x.view(x.size()[0], -1)

def add_conv(in_ch, out_ch, ksize, stride):
    stage = nn.Sequential()
    pad = (ksize - 1) // 2
    stage.add_module('conv', nn.Conv2d(in_channels=in_ch,
                                       out_channels=out_ch, kernel_size=ksize, stride=stride,
                                       padding=pad, bias=False))
    stage.add_module('batch_norm', nn.BatchNorm2d(out_ch))
    stage.add_module('leaky', nn.LeakyReLU(0.1))
    return stage

def add_linear(in_ch, in_dm, out_ch, leaky = True):
    stage = nn.Sequential()
    stage.add_module('linear', nn.Linear(in_features=in_ch*in_dm*in_dm, out_features=out_ch))
    stage.add_module('batch_norm',nn.BatchNorm1d(num_features=out_ch))
    if leaky :
        stage.add_module('LeakyRelu', nn.LeakyReLU())
    else:
        stage.add_module('relu', nn.ReLU())

    return stage


class resblock(nn.Module):
    def __init__(self, ch, nblocks=1, shortcut=True):

        super().__init__()
        self.shortcut = shortcut
        self.module_list = nn.ModuleList()
        for i in range(nblocks):
            resblock_one = nn.ModuleList()
            resblock_one.append(add_conv(ch, ch//2, 1, 1))
            resblock_one.append(add_conv(ch//2, ch, 3, 1))
            self.module_list.append(resblock_one)

    def forward(self, x):
        for module in self.module_list:
            h = x
            for res in module:
                h = res(h)
            x = x + h if self.shortcut else h
        return x

def create_darknet_modules():

    # DarkNet53
    mlist = nn.ModuleList()
    mlist.append(add_conv(in_ch=3, out_ch=32, ksize=3, stride=1))
    mlist.append(add_conv(in_ch=32, out_ch=64, ksize=3, stride=2))
    mlist.append(resblock(ch=64))
    mlist.append(add_conv(in_ch=64, out_ch=128, ksize=3, stride=2))
    mlist.append(resblock(ch=128, nblocks=2))
    mlist.append(add_conv(in_ch=128, out_ch=256, ksize=3, stride=2))
    mlist.append(resblock(ch=256, nblocks=8))
    mlist.append(add_conv(in_ch=256, out_ch=512, ksize=3, stride=2))
    mlist.append(resblock(ch=512, nblocks=8)) 
    mlist.append(add_conv(in_ch=512, out_ch=1024, ksize=3, stride=2))
    mlist.append(resblock(ch=1024, nblocks=4))

    mlist.append(Flatten())
    mlist.append(add_linear(in_ch=1024, in_dm=13, out_ch=2048))
    mlist.append(add_linear(in_ch=2048, in_dm=1, out_ch=1024))
    #mlist.append(add_linear(in_ch=1024, in_dm=1, out_ch=1, leaky = False))

    return mlist

def create_neural_modules(embedding_size, num_numerical_cols, output_size, hidden_size, dropout = 0.3):
    all_layers = []
    num_categorical_cols = sum((nf for ni, nf in embedding_size))
    input_size = num_categorical_cols + num_numerical_cols
    print(input_size)
    print(num_categorical_cols)
    print(num_numerical_cols)

    all_layers.append(nn.Linear(input_size, hidden_size))
    all_layers.append(nn.LeakyReLU())
    all_layers.append(nn.Dropout(dropout))

    all_layers.append(nn.Linear(hidden_size, hidden_size))
    all_layers.append(nn.LeakyReLU())
    all_layers.append(nn.Dropout(dropout))

    all_layers.append(nn.Linear(hidden_size, hidden_size))
    all_layers.append(nn.LeakyReLU())
    all_layers.append(nn.Dropout(dropout))

    # all_layers.append(nn.Linear(hidden_size, output_size))
    # all_layers.append(nn.ReLU())

    return nn.Sequential(*all_layers)

def create_mix_modules(input_size, output_size, dropout = 0.3):
    all_layers = []
    all_layers.append(nn.Linear(input_size, input_size))
    all_layers.append(nn.LeakyReLU())
    all_layers.append(nn.Dropout(dropout))

    all_layers.append(nn.Linear(input_size, input_size))
    all_layers.append(nn.LeakyReLU())
    all_layers.append(nn.Dropout(dropout))

    all_layers.append(nn.Linear(input_size, output_size))
    all_layers.append(nn.ReLU())
    return nn.Sequential(*all_layers)

def turn_conv_lstm_autograd(self):

    def dfs_off(model):
        for name, child in model.named_children():
            for param in child.parameters():
                param.requires_grad = False
            dfs_off(child)

    for i, module in enumerate(self.module_list):
        if i == 11:
          break
        dfs_off(module)

class Sentinel_net(nn.Module):

    def __init__(self, embedding_size, num_numerical_cols, output_size):
        super(Sentinel_net, self).__init__()
        self.module_list = create_darknet_modules()
        turn_conv_lstm_autograd(self)
    
        self.layers = create_neural_modules(embedding_size, num_numerical_cols, output_size, 65)
        self.mix_layers = create_mix_modules(1089, 1)
        self.all_embeddings = nn.ModuleList([nn.Embedding(ni, nf) for ni, nf in embedding_size])
        self.embedding_dropout = nn.Dropout(0.3)

    def forward(self, x, x_categorical, x_numerical):
        for i, module in enumerate(self.module_list):
            x = module(x)

        x = x.squeeze(dim=0)

        embeddings = []
        for i, e in enumerate(self.all_embeddings):
            embeddings.append(e(x_categorical[:, i]))
        
        y = torch.cat(embeddings, 1)

        y = self.embedding_dropout(y)
        y = torch.cat([y, x_numerical], 1)

        y = self.layers(y).squeeze()
                  
        #print('x ', x.shape,'y ', y.shape)

        mixtensor = torch.cat((x, y), 1)
        mixtensor = self.mix_layers(mixtensor)
        return mixtensor

# %%
from __future__ import division
import torch
import numpy as np


def parse_conv_block(m, weights, offset, initflag):
    """
    Initialization of conv layers with batchnorm
    Args:
        m (Sequential): sequence of layers
        weights (numpy.ndarray): pretrained weights data
        offset (int): current position in the weights file
        initflag (bool): if True, the layers are not covered by the weights file. \
            They are initialized using darknet-style initialization.
    Returns:
        offset (int): current position in the weights file
        weights (numpy.ndarray): pretrained weights data
    """
    conv_model = m[0]
    bn_model = m[1]
    param_length = m[1].bias.numel()

    # batchnorm
    for pname in ['bias', 'weight', 'running_mean', 'running_var']:
        layerparam = getattr(bn_model, pname)

        if initflag: # yolo initialization - scale to one, bias to zero
            if pname == 'weight':
                weights = np.append(weights, np.ones(param_length))
            else:
                weights = np.append(weights, np.zeros(param_length))

        param = torch.from_numpy(weights[offset:offset + param_length]).view_as(layerparam)
        layerparam.data.copy_(param)
        offset += param_length

    param_length = conv_model.weight.numel()

    # conv
    if initflag: # yolo initialization
        n, c, k, _ = conv_model.weight.shape
        scale = np.sqrt(2 / (k * k * c))
        weights = np.append(weights, scale * np.random.normal(size=param_length))

    param = torch.from_numpy(
        weights[offset:offset + param_length]).view_as(conv_model.weight)
    conv_model.weight.data.copy_(param)
    offset += param_length

    return offset, weights

def parse_yolo_block(m, weights, offset, initflag):
    """
    YOLO Layer (one conv with bias) Initialization
    Args:
        m (Sequential): sequence of layers
        weights (numpy.ndarray): pretrained weights data
        offset (int): current position in the weights file
        initflag (bool): if True, the layers are not covered by the weights file. \
            They are initialized using darknet-style initialization.
    Returns:
        offset (int): current position in the weights file
        weights (numpy.ndarray): pretrained weights data
    """
    conv_model = m._modules['conv']
    param_length = conv_model.bias.numel()

    if initflag: # yolo initialization - bias to zero
        weights = np.append(weights, np.zeros(param_length))

    param = torch.from_numpy(
        weights[offset:offset + param_length]).view_as(conv_model.bias)
    conv_model.bias.data.copy_(param)
    offset += param_length

    param_length = conv_model.weight.numel()

    if initflag: # yolo initialization
        n, c, k, _ = conv_model.weight.shape
        scale = np.sqrt(2 / (k * k * c))
        weights = np.append(weights, scale * np.random.normal(size=param_length))
 
    param = torch.from_numpy(
        weights[offset:offset + param_length]).view_as(conv_model.weight)
    conv_model.weight.data.copy_(param)
    offset += param_length

    return offset, weights

def parse_yolo_weights(model, weights_path):
    """
    Parse YOLO (darknet) pre-trained weights data onto the pytorch model
    Args:
        model : pytorch model object
        weights_path (str): path to the YOLO (darknet) pre-trained weights file
    """
    fp = open(weights_path, "rb")

    # skip the header
    header = np.fromfile(fp, dtype=np.int32, count=5) # not used
    # read weights 
    weights = np.fromfile(fp, dtype=np.float32)
    fp.close()

    offset = 0 
    initflag = False #whole yolo weights : False, darknet weights : True

    for m in model.module_list:
        if m._get_name() == 'Sequential':
            # normal conv block
            offset, weights = parse_conv_block(m, weights, offset, initflag)

        elif m._get_name() == 'resblock':
            # residual block
            for modu in m._modules['module_list']:
                for blk in modu:
                    offset, weights = parse_conv_block(blk, weights, offset, initflag)
        else:
            break
        # elif m._get_name() == 'YOLOLayer':
        #     # YOLO Layer (one conv with bias) Initialization
        #     offset, weights = parse_yolo_block(m, weights, offset, initflag)

        # initflag = (offset >= len(weights)) # the end of the weights file. turn the flag on

# %%
def train_darknet_net(sentinel_dataset_train,sentinel_dataset_test, fold_count):
    model = Sentinel_net(categorical_embedding_sizes,len(numerical_columns),1)
    parse_yolo_weights(model, "/content/drive/My Drive/Colab/mosquito/darknet53.conv.74")
    model = model.cuda()
    model.train()

    # criterion = torch.nn.MSELoss(size_average = True) 
    criterion = torch.nn.L1Loss()

    params_dict = dict(model.named_parameters())
    params = []
    base_lr = 0.0001

    for key, value in params_dict.items():
        if value.requires_grad:
          print(key)
          if 'weight' in key:
              params += [{'params':value, 'weight_decay':4e-3}]
          else:
              params += [{'params':value, 'weight_decay':0.0}]

    optimizer = torch.optim.RMSprop(params, lr=base_lr, alpha=0.99, eps=1e-08, weight_decay=0, momentum=0.9, centered=False)

    epochs = 20
    min_eval = sys.maxsize
    current_score = 0

    for epoch in range(0,epochs):
        loss_sum = 0
        
        model.train()
        for i_batch, sample_batched in enumerate(train_dataset_loader):
            image = sample_batched[0].cuda().float()
            image = image.permute(0,3,2,1)/255
            cat_tensor = sample_batched[1].squeeze().cuda()
            num_tensor = sample_batched[2].squeeze().cuda().float()

            #print('image shape ', image.shape,'cat_tensor shape ', cat_tensor.shape,'num_tensor shape ', num_tensor.shape)

            y_pred = model(image, cat_tensor, num_tensor)
            y = sample_batched[3].cuda().float()

            loss = criterion(y_pred, y) 
            loss.backward() 
            loss_sum += loss.item()
            optimizer.step() 
            optimizer.zero_grad() 

        model.eval()
        print('Train Accuracy epoch {}, loss {} %'.format(epoch, loss_sum))

        with torch.no_grad():

            if epoch % 10 == 0:
                model.eval()
                eval_loss_sum = 0 
                result_pred = []
                result_act = []
                with torch.no_grad():
                    y2 = None
                    y_pred2 = None
                    for i_batch2, sample_batched2 in enumerate(test_dataset_loader):

                        image2 = sample_batched2[0].cuda().float()
                        image2 = image2.permute(0,3,2,1)/255
                        cat_tensor2 = sample_batched2[1].squeeze().cuda()
                        num_tensor2 = sample_batched2[2].squeeze().cuda().float()
                        #print('test shape ', image.shape,'test shape ', cat_tensor.shape,'test shape ', num_tensor.shape)

                        y_pred2 = model(image2,cat_tensor2,num_tensor2)
                        y2 = sample_batched2[3].cuda().float()
                        eval_loss_sum += criterion(y_pred2, y2) 
                        result_pred += y_pred2.tolist()
                        result_act += y2.tolist()
                    
                    print('')
                    print(' Test Accuracy  {} %'.format( eval_loss_sum))


                    if eval_loss_sum < min_eval:
                        current_score = mean_absolute_error(result_pred, result_act)
                        print("Score!" ,current_score )
                        min_eval = eval_loss_sum
                        print("saved!" ,current_score )
                        torch.save({'iter': epoch,
                          'model_state_dict': model.state_dict(),
                          'optimizer_state_dict': optimizer.state_dict(),
                          'best_ac': min_eval,
                          },
                          os.path.join('/content/drive/My Drive/Colab/Mosquito_Berkeley/Approach4/best_approach' + str(fold_count) + '.ckpt'))


    return current_score

# %%
start_time = time.time()

scores = []
cv = KFold(n_splits=5, random_state=42, shuffle=True)
fold_count = 0
for train_index, test_index in cv.split(sentinel_frame, None):
    print('Fold')
    train, test  = sentinel_frame.iloc[train_index], sentinel_frame.iloc[test_index]

    sentinel_dataset_train = SentinelDataset(data=train, root_dir='satellite/')
    sentinel_dataset_test = SentinelDataset(data=test, root_dir='satellite/')

    train_dataset_loader = torch.utils.data.DataLoader(dataset=sentinel_dataset_train,
                                                    batch_size=20,
                                                    shuffle=False)
    
    test_dataset_loader = torch.utils.data.DataLoader(dataset=sentinel_dataset_test,
                                                    batch_size=20,
                                                    shuffle=False)
    

    current_score = train_darknet_net(sentinel_dataset_train,sentinel_dataset_test, fold_count)
    scores.append(current_score)
    fold_count += 1
print(scores)
print( sum(scores) / len(scores) )
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Fold
# module_list.12.linear.weight
# module_list.12.linear.bias
# module_list.12.batch_norm.weight
# module_list.12.batch_norm.bias
# module_list.13.linear.weight
# module_list.13.linear.bias
# module_list.13.batch_norm.weight
# module_list.13.batch_norm.bias
# layers.0.weight
# layers.0.bias
# layers.3.weight
# layers.3.bias
# layers.6.weight
# layers.6.bias
# mix_layers.0.weight
# mix_layers.0.bias
# mix_layers.3.weight
# mix_layers.3.bias
# mix_layers.6.weight
# mix_layers.6.bias
# all_embeddings.0.weight
# all_embeddings.1.weight
# all_embeddings.2.weight
# all_embeddings.3.weight
# all_embeddings.4.weight
# all_embeddings.5.weight
# all_embeddings.6.weight
# all_embeddings.7.weight
# Train Accuracy epoch 0, loss 914.2718849182129 %
#
#  Test Accuracy  373.99871826171875 %
# Score! 12.769762854222899
# saved! 12.769762854222899
# Train Accuracy epoch 1, loss 881.9241037368774 %
# Train Accuracy epoch 2, loss 882.6869773864746 %
# Train Accuracy epoch 3, loss 881.7567205429077 %
# Train Accuracy epoch 4, loss 880.8119037151337 %
# Train Accuracy epoch 5, loss 878.4779937267303 %
# Train Accuracy epoch 6, loss 875.3486421108246 %
# Train Accuracy epoch 7, loss 873.9870185852051 %
# Train Accuracy epoch 8, loss 874.3850286006927 %
# Train Accuracy epoch 9, loss 867.036895275116 %
# Train Accuracy epoch 10, loss 858.2473411560059 %
#
#  Test Accuracy  365.31805419921875 %
# Score! 12.378662307174118
# saved! 12.378662307174118
# Train Accuracy epoch 11, loss 851.9360115528107 %
# Train Accuracy epoch 12, loss 849.2151663303375 %
# Train Accuracy epoch 13, loss 846.4865477085114 %
# Train Accuracy epoch 14, loss 839.2848567962646 %
# Train Accuracy epoch 15, loss 838.8806531429291 %
# Train Accuracy epoch 16, loss 837.211296081543 %
# Train Accuracy epoch 17, loss 839.283536195755 %
# Train Accuracy epoch 18, loss 835.8574123382568 %
# Train Accuracy epoch 19, loss 828.7862334251404 %
# Train Accuracy epoch 20, loss 833.1412935256958 %
#
#  Test Accuracy  359.59124755859375 %
# Score! 12.112856001324124
# saved! 12.112856001324124
# Train Accuracy epoch 21, loss 829.8978586196899 %
# Train Accuracy epoch 22, loss 830.0913598537445 %
# Train Accuracy epoch 23, loss 831.0018222332001 %
# Train Accuracy epoch 24, loss 819.2046778202057 %
# Train Accuracy epoch 25, loss 829.4322926998138 %
# Train Accuracy epoch 26, loss 820.7264840602875 %
# Train Accuracy epoch 27, loss 825.7950885295868 %
# Train Accuracy epoch 28, loss 815.9439477920532 %
# Train Accuracy epoch 29, loss 822.9118528366089 %
# Train Accuracy epoch 30, loss 809.9253075122833 %
#
#  Test Accuracy  356.01690673828125 %
# Score! 11.942529224760738
# saved! 11.942529224760738
# Train Accuracy epoch 31, loss 818.2188725471497 %
# Train Accuracy epoch 32, loss 809.809237241745 %
# Train Accuracy epoch 33, loss 815.6013839244843 %
# Train Accuracy epoch 34, loss 818.7494344711304 %
# Train Accuracy epoch 35, loss 811.8159160614014 %
# Train Accuracy epoch 36, loss 800.6235382556915 %
# Train Accuracy epoch 37, loss 813.1236090660095 %
# Train Accuracy epoch 38, loss 812.6619770526886 %
# Train Accuracy epoch 39, loss 811.1978704929352 %
# Train Accuracy epoch 40, loss 811.2628428936005 %
#
#  Test Accuracy  354.1938781738281 %
# Score! 11.869237248985856
# saved! 11.869237248985856
# Train Accuracy epoch 41, loss 803.8412828445435 %
# Train Accuracy epoch 42, loss 812.3052070140839 %
# Train Accuracy epoch 43, loss 804.4570410251617 %
# Train Accuracy epoch 44, loss 811.1841673851013 %
# Train Accuracy epoch 45, loss 815.8525228500366 %
# Train Accuracy epoch 46, loss 811.5834600925446 %
# Train Accuracy epoch 47, loss 807.6034276485443 %
# Train Accuracy epoch 48, loss 810.9102580547333 %
# Train Accuracy epoch 49, loss 805.3124279975891 %
# Train Accuracy epoch 50, loss 797.9752750396729 %
#
#  Test Accuracy  350.83843994140625 %
# Score! 11.730815213697928
# saved! 11.730815213697928
# Train Accuracy epoch 51, loss 801.1893134117126 %
# Train Accuracy epoch 52, loss 802.395348072052 %
# Train Accuracy epoch 53, loss 806.4129874706268 %
# Train Accuracy epoch 54, loss 796.3486330509186 %
# Train Accuracy epoch 55, loss 807.1648683547974 %
# Train Accuracy epoch 56, loss 804.2789621353149 %
# Train Accuracy epoch 57, loss 799.42445063591 %
# Train Accuracy epoch 59, loss 807.0757632255554 %
# Train Accuracy epoch 60, loss 803.9259293079376 %
#
#  Test Accuracy  351.212890625 %
# Train Accuracy epoch 61, loss 799.7224612236023 %
# Train Accuracy epoch 62, loss 795.9842128753662 %
# Train Accuracy epoch 63, loss 803.5299663543701 %
# Train Accuracy epoch 64, loss 787.9695560932159 %
# Train Accuracy epoch 65, loss 797.6284499168396 %
# Train Accuracy epoch 66, loss 805.12375664711 %
# Train Accuracy epoch 67, loss 791.783548116684 %
# Train Accuracy epoch 68, loss 789.1825768947601 %
# Train Accuracy epoch 69, loss 791.285884141922 %
# Train Accuracy epoch 70, loss 798.7868237495422 %
#
#  Test Accuracy  346.8031005859375 %
# Score! 11.605462732138458
# saved! 11.605462732138458
# Train Accuracy epoch 71, loss 794.2482812404633 %
# Train Accuracy epoch 72, loss 794.2041554450989 %
# Train Accuracy epoch 73, loss 799.3230645656586 %
# Train Accuracy epoch 74, loss 790.644496679306 %
# Train Accuracy epoch 75, loss 795.5133085250854 %
# Train Accuracy epoch 76, loss 800.011310338974 %
# Train Accuracy epoch 77, loss 786.2892122268677 %
# Train Accuracy epoch 78, loss 791.2073845863342 %
# Train Accuracy epoch 79, loss 787.0711169242859 %
# Train Accuracy epoch 80, loss 796.0848076343536 %
#
#  Test Accuracy  346.06524658203125 %
# Score! 11.580755393299055
# saved! 11.580755393299055
# Train Accuracy epoch 81, loss 794.7012779712677 %
# Train Accuracy epoch 82, loss 797.7921712398529 %
# Train Accuracy epoch 83, loss 790.0989136695862 %
# Train Accuracy epoch 84, loss 794.5233645439148 %
# Train Accuracy epoch 85, loss 787.0075023174286 %
# Train Accuracy epoch 86, loss 784.5034682750702 %
# Train Accuracy epoch 87, loss 793.3362958431244 %
# Train Accuracy epoch 88, loss 783.8845303058624 %
# Train Accuracy epoch 89, loss 789.6446685791016 %
# Train Accuracy epoch 90, loss 782.4965732097626 %
#
#  Test Accuracy  343.67449951171875 %
# Score! 11.487786852283243
# saved! 11.487786852283243
# Train Accuracy epoch 91, loss 783.2070391178131 %
# Train Accuracy epoch 92, loss 789.6310472488403 %
# Train Accuracy epoch 93, loss 781.5676419734955 %
# Train Accuracy epoch 94, loss 791.7606840133667 %
# Train Accuracy epoch 95, loss 780.1242051124573 %
# Train Accuracy epoch 96, loss 771.6193478107452 %
# Train Accuracy epoch 97, loss 784.2858135700226 %
# Train Accuracy epoch 98, loss 777.6928133964539 %
# Train Accuracy epoch 99, loss 775.4611382484436 %
# Train Accuracy epoch 100, loss 779.1105015277863 %
#
#  Test Accuracy  340.2566223144531 %
# Score! 11.351348686218262
# saved! 11.351348686218262
# Train Accuracy epoch 101, loss 781.0260832309723 %
# Train Accuracy epoch 102, loss 785.165415763855 %
# Train Accuracy epoch 103, loss 785.4280710220337 %
# Train Accuracy epoch 104, loss 779.3492431640625 %
# Train Accuracy epoch 105, loss 787.4985954761505 %
# Train Accuracy epoch 106, loss 783.0761895179749 %
# Train Accuracy epoch 107, loss 773.680878162384 %
# Train Accuracy epoch 108, loss 776.39204454422 %
# Train Accuracy epoch 109, loss 761.8102149963379 %
# Train Accuracy epoch 110, loss 772.44504570961 %
#
#  Test Accuracy  341.68194580078125 %
# Train Accuracy epoch 111, loss 765.8949408531189 %
# Train Accuracy epoch 112, loss 777.06574010849 %
# Train Accuracy epoch 113, loss 766.268134355545 %
# Train Accuracy epoch 114, loss 779.307421207428 %
# Train Accuracy epoch 115, loss 760.2487182617188 %
# Train Accuracy epoch 116, loss 768.9109706878662 %
# Train Accuracy epoch 117, loss 766.6592981815338 %
# Train Accuracy epoch 118, loss 783.4393193721771 %
# Train Accuracy epoch 119, loss 764.5181705951691 %
# Train Accuracy epoch 120, loss 777.3845183849335 %
#
#  Test Accuracy  339.2229919433594 %
# Score! 11.319829994366494
# saved! 11.319829994366494
# Train Accuracy epoch 121, loss 768.2093124389648 %
# Train Accuracy epoch 122, loss 773.1510212421417 %
# Train Accuracy epoch 123, loss 761.7237520217896 %
# Train Accuracy epoch 124, loss 765.081738948822 %
# Train Accuracy epoch 125, loss 755.0619964599609 %
# Train Accuracy epoch 126, loss 760.0022783279419 %
# Train Accuracy epoch 127, loss 770.584034204483 %
# Train Accuracy epoch 128, loss 760.2471418380737 %
# Train Accuracy epoch 129, loss 772.0356621742249 %
# Train Accuracy epoch 130, loss 774.7860453128815 %
#
#  Test Accuracy  338.79296875 %
# Score! 11.31205925235042
# saved! 11.31205925235042
# Train Accuracy epoch 131, loss 751.6853580474854 %
# Train Accuracy epoch 132, loss 750.7002667188644 %
# Train Accuracy epoch 133, loss 763.0714645385742 %
# Train Accuracy epoch 134, loss 765.0548164844513 %
# Train Accuracy epoch 135, loss 770.7257208824158 %
# Train Accuracy epoch 136, loss 751.1723628044128 %
# Train Accuracy epoch 137, loss 743.7072455883026 %
# Train Accuracy epoch 138, loss 754.4036257266998 %
# Train Accuracy epoch 139, loss 752.3370034694672 %
# Train Accuracy epoch 140, loss 756.3925857543945 %
#
#  Test Accuracy  335.98333740234375 %
# Score! 11.237040692788582
# saved! 11.237040692788582
# Train Accuracy epoch 141, loss 755.86945271492 %
# Train Accuracy epoch 142, loss 757.2124171257019 %
# Train Accuracy epoch 143, loss 757.8164806365967 %
# Train Accuracy epoch 144, loss 757.2033770084381 %
# Train Accuracy epoch 145, loss 759.9208850860596 %
# Train Accuracy epoch 146, loss 750.0288121700287 %
# Train Accuracy epoch 147, loss 749.8179359436035 %
# Train Accuracy epoch 148, loss 750.9087333679199 %
# Train Accuracy epoch 149, loss 757.233157157898 %
# Train Accuracy epoch 150, loss 736.4305214881897 %
#
#  Test Accuracy  333.58477783203125 %
# Score! 11.187884216544068
# saved! 11.187884216544068
# Train Accuracy epoch 151, loss 759.416582107544 %
# Train Accuracy epoch 152, loss 765.0787708759308 %
# Train Accuracy epoch 153, loss 728.994059085846 %
# Train Accuracy epoch 154, loss 741.8235762119293 %
# Train Accuracy epoch 155, loss 741.8845493793488 %
# Train Accuracy epoch 156, loss 750.2329878807068 %
# Train Accuracy epoch 157, loss 747.2374422550201 %
# Train Accuracy epoch 158, loss 741.8673892021179 %
# Train Accuracy epoch 159, loss 742.2534561157227 %
# Train Accuracy epoch 160, loss 744.4884865283966 %
#
#  Test Accuracy  334.1092224121094 %
# Train Accuracy epoch 161, loss 743.0298976898193 %
# Train Accuracy epoch 162, loss 747.2253065109253 %
# Train Accuracy epoch 163, loss 747.1193206310272 %
# Train Accuracy epoch 164, loss 742.1404006481171 %
# Train Accuracy epoch 165, loss 749.4477643966675 %
# Train Accuracy epoch 166, loss 741.2757441997528 %
# Train Accuracy epoch 167, loss 745.7563014030457 %
# Train Accuracy epoch 168, loss 739.6996204853058 %
# Train Accuracy epoch 169, loss 754.515328168869 %
# Train Accuracy epoch 170, loss 724.0388810634613 %
#
#  Test Accuracy  332.16943359375 %
# Score! 11.1381301579652
# saved! 11.1381301579652
# Train Accuracy epoch 171, loss 756.6856718063354 %
# Train Accuracy epoch 172, loss 739.5027945041656 %
# Train Accuracy epoch 173, loss 740.2580428123474 %
# Train Accuracy epoch 174, loss 745.8283822536469 %
# Train Accuracy epoch 175, loss 733.895754814148 %
# Train Accuracy epoch 176, loss 731.9029269218445 %
# Train Accuracy epoch 177, loss 718.4565849304199 %
# Train Accuracy epoch 178, loss 735.9949309825897 %
# Train Accuracy epoch 179, loss 731.7800841331482 %
# Train Accuracy epoch 180, loss 747.098482131958 %
#
#  Test Accuracy  329.89300537109375 %
# Score! 11.030573223255299
# saved! 11.030573223255299
# Train Accuracy epoch 181, loss 761.3529448509216 %
# Train Accuracy epoch 182, loss 728.4732005596161 %
# Train Accuracy epoch 183, loss 731.8561658859253 %
# Train Accuracy epoch 184, loss 739.598718881607 %
# Train Accuracy epoch 185, loss 729.3138599395752 %
# Train Accuracy epoch 186, loss 734.3815171718597 %
# Train Accuracy epoch 187, loss 726.959067106247 %
# Train Accuracy epoch 188, loss 746.6399114131927 %
# Train Accuracy epoch 189, loss 722.1732447147369 %
# Train Accuracy epoch 190, loss 732.6095259189606 %
#
#  Test Accuracy  330.22900390625 %
# Train Accuracy epoch 191, loss 732.2225105762482 %
# Train Accuracy epoch 192, loss 742.1349139213562 %
# Train Accuracy epoch 193, loss 727.9082901477814 %
# Train Accuracy epoch 194, loss 743.8694276809692 %
# Train Accuracy epoch 195, loss 718.0405099391937 %
# Train Accuracy epoch 196, loss 721.9711909294128 %
# Train Accuracy epoch 197, loss 725.4474437236786 %
# Train Accuracy epoch 198, loss 733.2226395606995 %
# Train Accuracy epoch 199, loss 737.2754831314087 %
# Train Accuracy epoch 200, loss 723.0749108791351 %
#
#  Test Accuracy  330.7469482421875 %
# Train Accuracy epoch 201, loss 717.6319389343262 %
# Train Accuracy epoch 202, loss 733.510931968689 %
# Train Accuracy epoch 203, loss 723.3606888055801 %
# Train Accuracy epoch 204, loss 728.3009655475616 %
# Train Accuracy epoch 205, loss 738.062607049942 %
# Train Accuracy epoch 206, loss 729.8552341461182 %
# Train Accuracy epoch 207, loss 713.2863616943359 %
# Train Accuracy epoch 208, loss 741.1362736225128 %
# Train Accuracy epoch 209, loss 724.0280857086182 %
# Train Accuracy epoch 210, loss 720.7243187427521 %
#
#  Test Accuracy  329.38531494140625 %
# Score! 11.086886740319523
# saved! 11.086886740319523
# Train Accuracy epoch 211, loss 734.3123393058777 %
# Train Accuracy epoch 212, loss 719.3124086856842 %
# Train Accuracy epoch 213, loss 719.1152431964874 %
# Train Accuracy epoch 214, loss 729.9702849388123 %
# Train Accuracy epoch 215, loss 722.5353956222534 %
# Train Accuracy epoch 216, loss 732.6860566139221 %
# Train Accuracy epoch 217, loss 722.3588695526123 %
# Train Accuracy epoch 218, loss 740.8892896175385 %
# Train Accuracy epoch 219, loss 726.16486287117 %
# Train Accuracy epoch 220, loss 729.5023851394653 %
#
#  Test Accuracy  330.762451171875 %
# Train Accuracy epoch 221, loss 720.0388445854187 %
# Train Accuracy epoch 222, loss 715.2760198116302 %
# Train Accuracy epoch 223, loss 719.6841480731964 %
# Train Accuracy epoch 224, loss 722.6100442409515 %
# Train Accuracy epoch 225, loss 709.6075600385666 %
# Train Accuracy epoch 226, loss 715.7282431125641 %
# Train Accuracy epoch 227, loss 732.9248974323273 %
# Train Accuracy epoch 228, loss 712.1085970401764 %
# Train Accuracy epoch 229, loss 721.8934168815613 %
# Train Accuracy epoch 230, loss 717.7661879062653 %
#
#  Test Accuracy  327.187255859375 %
# Score! 10.977932372505283
# saved! 10.977932372505283
# Train Accuracy epoch 231, loss 724.6004593372345 %
# Train Accuracy epoch 232, loss 717.571875333786 %
# Train Accuracy epoch 233, loss 723.3745687007904 %
# Train Accuracy epoch 234, loss 709.78191447258 %
# Train Accuracy epoch 235, loss 712.1160497665405 %
# Train Accuracy epoch 236, loss 727.918253660202 %
# Train Accuracy epoch 237, loss 714.3345844745636 %
# Train Accuracy epoch 238, loss 712.5029919147491 %
# Train Accuracy epoch 239, loss 718.5128197669983 %
# Train Accuracy epoch 240, loss 729.9084000587463 %
#
#  Test Accuracy  326.80242919921875 %
# Score! 11.016885496657572
# saved! 11.016885496657572
# Train Accuracy epoch 241, loss 723.5934607982635 %
# Train Accuracy epoch 242, loss 716.8951396942139 %
# Train Accuracy epoch 243, loss 722.5163836479187 %
# Train Accuracy epoch 244, loss 711.0762927532196 %
# Train Accuracy epoch 245, loss 721.9486818313599 %
# Train Accuracy epoch 246, loss 710.3439285755157 %
# Train Accuracy epoch 247, loss 710.4040198326111 %
# Train Accuracy epoch 248, loss 721.10906291008 %
# Train Accuracy epoch 249, loss 715.5983374118805 %
# Train Accuracy epoch 250, loss 733.8898992538452 %
#
#  Test Accuracy  329.0037536621094 %
# Train Accuracy epoch 251, loss 700.3384602069855 %
# Train Accuracy epoch 252, loss 726.3896024227142 %
# Train Accuracy epoch 253, loss 697.7591969966888 %
# Train Accuracy epoch 254, loss 693.7357904911041 %
# Train Accuracy epoch 255, loss 711.3119509220123 %
# Train Accuracy epoch 256, loss 712.2583661079407 %
# Train Accuracy epoch 257, loss 715.7353701591492 %
# Train Accuracy epoch 258, loss 712.0351006984711 %
# Train Accuracy epoch 259, loss 713.7821779251099 %
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-1f22914bf569> in <module>()
#      20
#      21
# ---> 22     current_score = train_darknet_net(sentinel_dataset_train,sentinel_dataset_test, fold_count)
#      23     scores.append(current_score)
#      24     fold_count += 1
#
# <ipython-input-17-043319b64b0e> in train_darknet_net(sentinel_dataset_train, sentinel_dataset_test, fold_count)
#      30
#      31         model.train()
# ---> 32         for i_batch, sample_batched in enumerate(train_dataset_loader):
#      33             image = sample_batched[0].cuda().float()
#      34             image = image.permute(0,3,2,1)/255
#
# /usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     343
#     344     def __next__(self):
# --> 345         data = self._next_data()
#     346         self._num_yielded += 1
#     347         if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     383     def _next_data(self):
#     384         index = self._next_index()  # may raise StopIteration
# --> 385         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     386         if self._pin_memory:
#     387             data = _utils.pin_memory.pin_memory(data)
#
# /usr/local/lib/python3.6/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.6/dist-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# <ipython-input-14-cb9d37d89117> in __getitem__(self, idx)
#      82
#      83         #random rotate
# ---> 84         image = ndimage.rotate(image, random.randint(0,359), axes = [0,1],reshape=False)
#      85
#      86         # random zoom
#
# /usr/local/lib/python3.6/dist-packages/scipy/ndimage/interpolation.py in rotate(input, angle, axes, reshape, output, order, mode, cval, prefilter)
#     742             oa = output[coordinates]
#     743             affine_transform(ia, rot_matrix, offset, out_plane_shape,
# --> 744                              oa, order, mode, cval, prefilter)
#     745
#     746     return output
#
# /usr/local/lib/python3.6/dist-packages/scipy/ndimage/interpolation.py in affine_transform(input, matrix, offset, output_shape, output, order, mode, cval, prefilter)
#     484     else:
#     485         _nd_image.geometric_transform(filtered, None, None, matrix, offset,
# --> 486                                       output, order, mode, cval, None, None)
#     487     return output
#     488
#
# KeyboardInterrupt:

# %%
start_time = time.time()

scores = []
cv = KFold(n_splits=5, random_state=42, shuffle=True)
fold_count = 0
for train_index, test_index in cv.split(sentinel_frame, None):
    print('Fold')
    train, test  = sentinel_frame.iloc[train_index], sentinel_frame.iloc[test_index]

    sentinel_dataset_train = SentinelDataset(data=train, root_dir='satellite/')
    sentinel_dataset_test = SentinelDataset(data=test, root_dir='satellite/')

    train_dataset_loader = torch.utils.data.DataLoader(dataset=sentinel_dataset_train,
                                                    batch_size=20,
                                                    shuffle=False)
    
    test_dataset_loader = torch.utils.data.DataLoader(dataset=sentinel_dataset_test,
                                                    batch_size=20,
                                                    shuffle=False)
    

    current_score = train_darknet_net(sentinel_dataset_train,sentinel_dataset_test, fold_count)
    scores.append(current_score)
    fold_count += 1
print(scores)
print( sum(scores) / len(scores) )
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Fold
# 77
# 37
# 40
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-1f22914bf569> in <module>()
#      20
#      21
# ---> 22     current_score = train_darknet_net(sentinel_dataset_train,sentinel_dataset_test, fold_count)
#      23     scores.append(current_score)
#      24     fold_count += 1
#
# <ipython-input-24-6f146b4aae88> in train_darknet_net(sentinel_dataset_train, sentinel_dataset_test, fold_count)
#       2     model = Sentinel_net(categorical_embedding_sizes,len(numerical_columns),1)
#       3     parse_yolo_weights(model, "/content/drive/My Drive/Colab/mosquito/darknet53.conv.74")
# ----> 4     model = model.cuda()
#       5     model.train()
#       6
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in cuda(self, device)
#     305             Module: self
#     306         """
# --> 307         return self._apply(lambda t: t.cuda(device))
#     308
#     309     def cpu(self):
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in _apply(self, fn)
#     201     def _apply(self, fn):
#     202         for module in self.children():
# --> 203             module._apply(fn)
#     204
#     205         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in _apply(self, fn)
#     201     def _apply(self, fn):
#     202         for module in self.children():
# --> 203             module._apply(fn)
#     204
#     205         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in _apply(self, fn)
#     201     def _apply(self, fn):
#     202         for module in self.children():
# --> 203             module._apply(fn)
#     204
#     205         def compute_should_use_set_data(tensor, tensor_applied):
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in _apply(self, fn)
#     223                 # `with torch.no_grad():`
#     224                 with torch.no_grad():
# --> 225                     param_applied = fn(param)
#     226                 should_use_set_data = compute_should_use_set_data(param, param_applied)
#     227                 if should_use_set_data:
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in <lambda>(t)
#     305             Module: self
#     306         """
# --> 307         return self._apply(lambda t: t.cuda(device))
#     308
#     309     def cpu(self):
#
# KeyboardInterrupt:

# %%
start_time = time.time()

scores = []
cv = KFold(n_splits=5, random_state=42, shuffle=True)
fold_count = 0
for train_index, test_index in cv.split(sentinel_frame, None):
    print('Fold')
    train, test  = sentinel_frame.iloc[train_index], sentinel_frame.iloc[test_index]

    sentinel_dataset_train = SentinelDataset(data=train, root_dir='satellite/')
    sentinel_dataset_test = SentinelDataset(data=test, root_dir='satellite/')

    train_dataset_loader = torch.utils.data.DataLoader(dataset=sentinel_dataset_train,
                                                    batch_size=20,
                                                    shuffle=False)
    
    test_dataset_loader = torch.utils.data.DataLoader(dataset=sentinel_dataset_test,
                                                    batch_size=20,
                                                    shuffle=False)
    

    current_score = train_darknet_net(sentinel_dataset_train,sentinel_dataset_test, fold_count)
    scores.append(current_score)
    fold_count += 1
print(scores)
print( sum(scores) / len(scores) )
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Fold
# module_list.12.linear.weight
# module_list.12.linear.bias
# module_list.12.batch_norm.weight
# module_list.12.batch_norm.bias
# module_list.13.linear.weight
# module_list.13.linear.bias
# module_list.13.batch_norm.weight
# module_list.13.batch_norm.bias
# layers.0.weight
# layers.0.bias
# layers.3.weight
# layers.3.bias
# layers.6.weight
# layers.6.bias
# mix_layers.0.weight
# mix_layers.0.bias
# mix_layers.3.weight
# mix_layers.3.bias
# mix_layers.6.weight
# mix_layers.6.bias
# all_embeddings.0.weight
# all_embeddings.1.weight
# all_embeddings.2.weight
# all_embeddings.3.weight
# all_embeddings.4.weight
# all_embeddings.5.weight
# all_embeddings.6.weight
# all_embeddings.7.weight
# Train Accuracy epoch 0, loss 917.8039646148682 %
#
#  Test Accuracy  361.946533203125 %
# Score! 12.262513709362642
# saved! 12.262513709362642
# Train Accuracy epoch 1, loss 882.2332735061646 %
# Train Accuracy epoch 2, loss 861.7378170490265 %
# Train Accuracy epoch 3, loss 872.2176065444946 %
# Train Accuracy epoch 4, loss 849.3758852481842 %
# Train Accuracy epoch 5, loss 856.7084074020386 %
# Train Accuracy epoch 6, loss 852.4438970088959 %
# Train Accuracy epoch 7, loss 840.2494909763336 %
# Train Accuracy epoch 8, loss 847.9263923168182 %
# Train Accuracy epoch 9, loss 834.4357125759125 %
# Train Accuracy epoch 10, loss 819.7578172683716 %
#
#  Test Accuracy  373.9471435546875 %
# Train Accuracy epoch 11, loss 808.8943264484406 %
# Train Accuracy epoch 12, loss 806.5500345230103 %
# Train Accuracy epoch 13, loss 809.9790163040161 %
# Train Accuracy epoch 14, loss 798.3553504943848 %
# Train Accuracy epoch 15, loss 791.4588170051575 %
# Train Accuracy epoch 16, loss 775.8157185316086 %
# Train Accuracy epoch 17, loss 781.0351412296295 %
# Train Accuracy epoch 18, loss 765.3970501422882 %
# Train Accuracy epoch 19, loss 774.8394989967346 %
# Fold
# module_list.12.linear.weight
# module_list.12.linear.bias
# module_list.12.batch_norm.weight
# module_list.12.batch_norm.bias
# module_list.13.linear.weight
# module_list.13.linear.bias
# module_list.13.batch_norm.weight
# module_list.13.batch_norm.bias
# layers.0.weight
# layers.0.bias
# layers.3.weight
# layers.3.bias
# layers.6.weight
# layers.6.bias
# mix_layers.0.weight
# mix_layers.0.bias
# mix_layers.3.weight
# mix_layers.3.bias
# mix_layers.6.weight
# mix_layers.6.bias
# all_embeddings.0.weight
# all_embeddings.1.weight
# all_embeddings.2.weight
# all_embeddings.3.weight
# all_embeddings.4.weight
# all_embeddings.5.weight
# all_embeddings.6.weight
# all_embeddings.7.weight
# Train Accuracy epoch 0, loss 983.4988331794739 %
#
#  Test Accuracy  203.24855041503906 %
# Score! 9.771239133234378
# saved! 9.771239133234378
# Train Accuracy epoch 1, loss 931.6756086349487 %
# Train Accuracy epoch 2, loss 938.4388308525085 %
# Train Accuracy epoch 3, loss 928.4975972175598 %
# Train Accuracy epoch 4, loss 912.4987418651581 %
# Train Accuracy epoch 5, loss 892.7871716022491 %
# Train Accuracy epoch 6, loss 890.8812952041626 %
# Train Accuracy epoch 7, loss 884.6873450279236 %
# Train Accuracy epoch 8, loss 886.4930682182312 %
# Train Accuracy epoch 9, loss 894.8853471279144 %
# Train Accuracy epoch 10, loss 892.4798114299774 %
#
#  Test Accuracy  200.77081298828125 %
# Score! 9.644130906646634
# saved! 9.644130906646634
# Train Accuracy epoch 11, loss 868.085563659668 %
# Train Accuracy epoch 12, loss 851.1943020820618 %
# Train Accuracy epoch 13, loss 859.4096345901489 %
# Train Accuracy epoch 14, loss 864.217175245285 %
# Train Accuracy epoch 15, loss 845.1018221378326 %
# Train Accuracy epoch 16, loss 839.8886439800262 %
# Train Accuracy epoch 17, loss 820.8697562217712 %
# Train Accuracy epoch 18, loss 827.9995276927948 %
# Train Accuracy epoch 19, loss 838.0207641124725 %
# Fold
# module_list.12.linear.weight
# module_list.12.linear.bias
# module_list.12.batch_norm.weight
# module_list.12.batch_norm.bias
# module_list.13.linear.weight
# module_list.13.linear.bias
# module_list.13.batch_norm.weight
# module_list.13.batch_norm.bias
# layers.0.weight
# layers.0.bias
# layers.3.weight
# layers.3.bias
# layers.6.weight
# layers.6.bias
# mix_layers.0.weight
# mix_layers.0.bias
# mix_layers.3.weight
# mix_layers.3.bias
# mix_layers.6.weight
# mix_layers.6.bias
# all_embeddings.0.weight
# all_embeddings.1.weight
# all_embeddings.2.weight
# all_embeddings.3.weight
# all_embeddings.4.weight
# all_embeddings.5.weight
# all_embeddings.6.weight
# all_embeddings.7.weight
# Train Accuracy epoch 0, loss 961.0334980487823 %
#
#  Test Accuracy  258.4783935546875 %
# Score! 11.024136857338894
# saved! 11.024136857338894
# Train Accuracy epoch 1, loss 912.4958593845367 %
# Train Accuracy epoch 2, loss 903.2853300571442 %
# Train Accuracy epoch 3, loss 898.8216822147369 %
# Train Accuracy epoch 4, loss 882.7752411365509 %
# Train Accuracy epoch 5, loss 865.8155958652496 %
# Train Accuracy epoch 6, loss 877.0412828922272 %
# Train Accuracy epoch 7, loss 866.569002866745 %
# Train Accuracy epoch 8, loss 879.8166782855988 %
# Train Accuracy epoch 9, loss 862.8260712623596 %
# Train Accuracy epoch 10, loss 863.4682972431183 %
#
#  Test Accuracy  251.13339233398438 %
# Score! 10.566683238229635
# saved! 10.566683238229635
# Train Accuracy epoch 11, loss 851.1882607936859 %
# Train Accuracy epoch 12, loss 839.803948879242 %
# Train Accuracy epoch 13, loss 836.6942236423492 %
# Train Accuracy epoch 14, loss 835.0481221675873 %
# Train Accuracy epoch 15, loss 828.97301030159 %
# Train Accuracy epoch 16, loss 821.3435642719269 %
# Train Accuracy epoch 17, loss 828.9036498069763 %
# Train Accuracy epoch 18, loss 809.5701014995575 %
# Train Accuracy epoch 19, loss 805.2091896533966 %
# Fold
# module_list.12.linear.weight
# module_list.12.linear.bias
# module_list.12.batch_norm.weight
# module_list.12.batch_norm.bias
# module_list.13.linear.weight
# module_list.13.linear.bias
# module_list.13.batch_norm.weight
# module_list.13.batch_norm.bias
# layers.0.weight
# layers.0.bias
# layers.3.weight
# layers.3.bias
# layers.6.weight
# layers.6.bias
# mix_layers.0.weight
# mix_layers.0.bias
# mix_layers.3.weight
# mix_layers.3.bias
# mix_layers.6.weight
# mix_layers.6.bias
# all_embeddings.0.weight
# all_embeddings.1.weight
# all_embeddings.2.weight
# all_embeddings.3.weight
# all_embeddings.4.weight
# all_embeddings.5.weight
# all_embeddings.6.weight
# all_embeddings.7.weight
# Train Accuracy epoch 0, loss 934.3998458385468 %
#
#  Test Accuracy  272.83319091796875 %
# Score! 13.328989242563154
# saved! 13.328989242563154
# Train Accuracy epoch 1, loss 892.6741392612457 %
# Train Accuracy epoch 2, loss 886.5807790756226 %
# Train Accuracy epoch 3, loss 879.618928194046 %
# Train Accuracy epoch 4, loss 872.8997416496277 %
# Train Accuracy epoch 5, loss 863.724773645401 %
# Train Accuracy epoch 6, loss 862.6703822612762 %
# Train Accuracy epoch 7, loss 863.6288163661957 %
# Train Accuracy epoch 8, loss 839.2878801822662 %
# Train Accuracy epoch 9, loss 856.3389825820923 %
# Train Accuracy epoch 10, loss 845.8344833850861 %
#
#  Test Accuracy  260.5611877441406 %
# Score! 12.825513094073475
# saved! 12.825513094073475
# Train Accuracy epoch 11, loss 848.065404176712 %
# Train Accuracy epoch 12, loss 822.2232813835144 %
# Train Accuracy epoch 13, loss 815.7810499668121 %
# Train Accuracy epoch 14, loss 814.5489492416382 %
# Train Accuracy epoch 15, loss 822.6686248779297 %
# Train Accuracy epoch 16, loss 803.0290367603302 %
# Train Accuracy epoch 17, loss 803.982652425766 %
# Train Accuracy epoch 18, loss 796.7262628078461 %
# Train Accuracy epoch 19, loss 787.4648003578186 %
# Fold
# module_list.12.linear.weight
# module_list.12.linear.bias
# module_list.12.batch_norm.weight
# module_list.12.batch_norm.bias
# module_list.13.linear.weight
# module_list.13.linear.bias
# module_list.13.batch_norm.weight
# module_list.13.batch_norm.bias
# layers.0.weight
# layers.0.bias
# layers.3.weight
# layers.3.bias
# layers.6.weight
# layers.6.bias
# mix_layers.0.weight
# mix_layers.0.bias
# mix_layers.3.weight
# mix_layers.3.bias
# mix_layers.6.weight
# mix_layers.6.bias
# all_embeddings.0.weight
# all_embeddings.1.weight
# all_embeddings.2.weight
# all_embeddings.3.weight
# all_embeddings.4.weight
# all_embeddings.5.weight
# all_embeddings.6.weight
# all_embeddings.7.weight
# Train Accuracy epoch 0, loss 998.0022792816162 %
#
#  Test Accuracy  201.47071838378906 %
# Score! 9.729058552791576
# saved! 9.729058552791576
# Train Accuracy epoch 1, loss 942.4069850444794 %
# Train Accuracy epoch 2, loss 926.4067184925079 %
# Train Accuracy epoch 3, loss 920.1866352558136 %
# Train Accuracy epoch 4, loss 933.1317617893219 %
# Train Accuracy epoch 5, loss 916.5468044281006 %
# Train Accuracy epoch 6, loss 914.5604028701782 %
# Train Accuracy epoch 7, loss 901.7314841747284 %
# Train Accuracy epoch 8, loss 882.0008022785187 %
# Train Accuracy epoch 9, loss 889.3001284599304 %
# Train Accuracy epoch 10, loss 884.5266501903534 %
#
#  Test Accuracy  184.27760314941406 %
# Score! 8.97691133057717
# saved! 8.97691133057717
# Train Accuracy epoch 11, loss 877.8913748264313 %
# Train Accuracy epoch 12, loss 875.444370508194 %
# Train Accuracy epoch 13, loss 871.2339222431183 %
# Train Accuracy epoch 14, loss 856.0132954120636 %
# Train Accuracy epoch 15, loss 850.0648617744446 %
# Train Accuracy epoch 16, loss 852.0477502346039 %
# Train Accuracy epoch 17, loss 844.0090868473053 %
# Train Accuracy epoch 18, loss 827.794796705246 %
# Train Accuracy epoch 19, loss 835.4452424049377 %
# [12.262513709362642, 9.644130906646634, 10.566683238229635, 12.825513094073475, 8.97691133057717]
# 10.855150455777911
# --- 14570.614512681961 seconds ---

# %%
def train_darknet_net(sentinel_dataset_train,sentinel_dataset_test, fold_count):
    model = Sentinel_net(categorical_embedding_sizes,len(numerical_columns),1)
    parse_yolo_weights(model, "/content/drive/My Drive/Colab/mosquito/darknet53.conv.74")
    model = model.cuda()
    model.train()

    # criterion = torch.nn.MSELoss(size_average = True) 
    criterion = torch.nn.L1Loss()

    params_dict = dict(model.named_parameters())
    params = []
    base_lr = 0.0001

    for key, value in params_dict.items():
        if value.requires_grad:
          print(key)
          if 'weight' in key:
              params += [{'params':value, 'weight_decay':4e-3}]
          else:
              params += [{'params':value, 'weight_decay':0.0}]

    optimizer = torch.optim.RMSprop(params, lr=base_lr, alpha=0.99, eps=1e-08, weight_decay=0, momentum=0.9, centered=False)

    epochs = 21
    min_eval = sys.maxsize
    current_score = 0

    for epoch in range(0,epochs):
        loss_sum = 0
        
        model.train()
        for i_batch, sample_batched in enumerate(train_dataset_loader):
            image = sample_batched[0].cuda().float()
            image = image.permute(0,3,2,1)/255
            cat_tensor = sample_batched[1].squeeze().cuda()
            num_tensor = sample_batched[2].squeeze().cuda().float()

            #print('image shape ', image.shape,'cat_tensor shape ', cat_tensor.shape,'num_tensor shape ', num_tensor.shape)

            y_pred = model(image, cat_tensor, num_tensor)
            y = sample_batched[3].cuda().float()

            loss = criterion(y_pred, y) 
            loss.backward() 
            loss_sum += loss.item()
            optimizer.step() 
            optimizer.zero_grad() 

        model.eval()
        print('Train Accuracy epoch {}, loss {} %'.format(epoch, loss_sum))

        with torch.no_grad():

            if epoch % 10 == 0:
                model.eval()
                eval_loss_sum = 0 
                result_pred = []
                result_act = []
                with torch.no_grad():
                    y2 = None
                    y_pred2 = None
                    for i_batch2, sample_batched2 in enumerate(test_dataset_loader):

                        image2 = sample_batched2[0].cuda().float()
                        image2 = image2.permute(0,3,2,1)/255
                        cat_tensor2 = sample_batched2[1].squeeze().cuda()
                        num_tensor2 = sample_batched2[2].squeeze().cuda().float()
                        #print('test shape ', image.shape,'test shape ', cat_tensor.shape,'test shape ', num_tensor.shape)

                        y_pred2 = model(image2,cat_tensor2,num_tensor2)
                        y2 = sample_batched2[3].cuda().float()
                        eval_loss_sum += criterion(y_pred2, y2) 
                        result_pred += y_pred2.tolist()
                        result_act += y2.tolist()
                    
                    print('')
                    print(' Test Accuracy  {} %'.format( eval_loss_sum))


                    if eval_loss_sum < min_eval:
                        current_score = mean_absolute_error(result_pred, result_act)
                        print("Score!" ,current_score )
                        min_eval = eval_loss_sum
                        print("saved!" ,current_score )
                        torch.save({'iter': epoch,
                          'model_state_dict': model.state_dict(),
                          'optimizer_state_dict': optimizer.state_dict(),
                          'best_ac': min_eval,
                          },
                          os.path.join('/content/drive/My Drive/Colab/Mosquito_Berkeley/Approach4/best_approach' + str(fold_count) + '.ckpt'))


    return current_score

# %%
start_time = time.time()

scores = []
cv = KFold(n_splits=5, random_state=42, shuffle=True)
fold_count = 0
for train_index, test_index in cv.split(sentinel_frame, None):
    print('Fold')
    train, test  = sentinel_frame.iloc[train_index], sentinel_frame.iloc[test_index]

    sentinel_dataset_train = SentinelDataset(data=train, root_dir='satellite/')
    sentinel_dataset_test = SentinelDataset(data=test, root_dir='satellite/')

    train_dataset_loader = torch.utils.data.DataLoader(dataset=sentinel_dataset_train,
                                                    batch_size=20,
                                                    shuffle=False)
    
    test_dataset_loader = torch.utils.data.DataLoader(dataset=sentinel_dataset_test,
                                                    batch_size=20,
                                                    shuffle=False)
    

    current_score = train_darknet_net(sentinel_dataset_train,sentinel_dataset_test, fold_count)
    scores.append(current_score)
    fold_count += 1
print(scores)
print( sum(scores) / len(scores) )
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Fold
# module_list.12.linear.weight
# module_list.12.linear.bias
# module_list.12.batch_norm.weight
# module_list.12.batch_norm.bias
# module_list.13.linear.weight
# module_list.13.linear.bias
# module_list.13.batch_norm.weight
# module_list.13.batch_norm.bias
# layers.0.weight
# layers.0.bias
# layers.3.weight
# layers.3.bias
# layers.6.weight
# layers.6.bias
# mix_layers.0.weight
# mix_layers.0.bias
# mix_layers.3.weight
# mix_layers.3.bias
# mix_layers.6.weight
# mix_layers.6.bias
# all_embeddings.0.weight
# all_embeddings.1.weight
# all_embeddings.2.weight
# all_embeddings.3.weight
# all_embeddings.4.weight
# all_embeddings.5.weight
# all_embeddings.6.weight
# all_embeddings.7.weight
# Train Accuracy epoch 0, loss 928.6311287879944 %
#
#  Test Accuracy  363.0462951660156 %
# Score! 12.32189939684338
# saved! 12.32189939684338
# Train Accuracy epoch 1, loss 879.2619230747223 %
# Train Accuracy epoch 2, loss 859.0278186798096 %
# Train Accuracy epoch 3, loss 858.4214730262756 %
# Train Accuracy epoch 4, loss 847.9573132991791 %
# Train Accuracy epoch 5, loss 836.3053402900696 %
# Train Accuracy epoch 6, loss 851.117671251297 %
# Train Accuracy epoch 7, loss 837.2739679813385 %
# Train Accuracy epoch 8, loss 844.7265388965607 %
# Train Accuracy epoch 9, loss 841.3202404975891 %
# Train Accuracy epoch 10, loss 819.7254569530487 %
#
#  Test Accuracy  362.69439697265625 %
# Score! 12.307088139616413
# saved! 12.307088139616413
# Train Accuracy epoch 11, loss 826.8208396434784 %
# Train Accuracy epoch 12, loss 814.547768831253 %
# Train Accuracy epoch 13, loss 802.0706412792206 %
# Train Accuracy epoch 14, loss 797.9750633239746 %
# Train Accuracy epoch 15, loss 802.8822264671326 %
# Train Accuracy epoch 16, loss 792.3330705165863 %
# Train Accuracy epoch 17, loss 789.7712666988373 %
# Train Accuracy epoch 18, loss 784.8818137645721 %
# Train Accuracy epoch 19, loss 781.2702932357788 %
# Train Accuracy epoch 20, loss 775.5848038196564 %
#
#  Test Accuracy  352.3663635253906 %
# Score! 11.897666358359066
# saved! 11.897666358359066
# Fold
# module_list.12.linear.weight
# module_list.12.linear.bias
# module_list.12.batch_norm.weight
# module_list.12.batch_norm.bias
# module_list.13.linear.weight
# module_list.13.linear.bias
# module_list.13.batch_norm.weight
# module_list.13.batch_norm.bias
# layers.0.weight
# layers.0.bias
# layers.3.weight
# layers.3.bias
# layers.6.weight
# layers.6.bias
# mix_layers.0.weight
# mix_layers.0.bias
# mix_layers.3.weight
# mix_layers.3.bias
# mix_layers.6.weight
# mix_layers.6.bias
# all_embeddings.0.weight
# all_embeddings.1.weight
# all_embeddings.2.weight
# all_embeddings.3.weight
# all_embeddings.4.weight
# all_embeddings.5.weight
# all_embeddings.6.weight
# all_embeddings.7.weight
# Train Accuracy epoch 0, loss 1000.0689532756805 %
#
#  Test Accuracy  196.7728271484375 %
# Score! 9.528574425791517
# saved! 9.528574425791517
# Train Accuracy epoch 1, loss 923.5103752613068 %
# Train Accuracy epoch 2, loss 931.3102886676788 %
# Train Accuracy epoch 3, loss 916.8432314395905 %
# Train Accuracy epoch 4, loss 920.3756213188171 %
# Train Accuracy epoch 5, loss 898.3959894180298 %
# Train Accuracy epoch 6, loss 918.5294480323792 %
# Train Accuracy epoch 7, loss 900.4574956893921 %
# Train Accuracy epoch 8, loss 874.336038351059 %
# Train Accuracy epoch 9, loss 888.6054379940033 %
# Train Accuracy epoch 10, loss 874.1702976226807 %
#
#  Test Accuracy  210.41445922851562 %
# Train Accuracy epoch 11, loss 876.3432266712189 %
# Train Accuracy epoch 12, loss 849.819194316864 %
# Train Accuracy epoch 13, loss 859.1518890857697 %
# Train Accuracy epoch 14, loss 833.6535792350769 %
# Train Accuracy epoch 15, loss 844.9940376281738 %
# Train Accuracy epoch 16, loss 838.5486340522766 %
# Train Accuracy epoch 17, loss 854.8839426040649 %
# Train Accuracy epoch 18, loss 842.5996427536011 %
# Train Accuracy epoch 19, loss 828.8175473213196 %
# Train Accuracy epoch 20, loss 843.0299615859985 %
#
#  Test Accuracy  191.18978881835938 %
# Score! 9.090929145577514
# saved! 9.090929145577514
# Fold
# module_list.12.linear.weight
# module_list.12.linear.bias
# module_list.12.batch_norm.weight
# module_list.12.batch_norm.bias
# module_list.13.linear.weight
# module_list.13.linear.bias
# module_list.13.batch_norm.weight
# module_list.13.batch_norm.bias
# layers.0.weight
# layers.0.bias
# layers.3.weight
# layers.3.bias
# layers.6.weight
# layers.6.bias
# mix_layers.0.weight
# mix_layers.0.bias
# mix_layers.3.weight
# mix_layers.3.bias
# mix_layers.6.weight
# mix_layers.6.bias
# all_embeddings.0.weight
# all_embeddings.1.weight
# all_embeddings.2.weight
# all_embeddings.3.weight
# all_embeddings.4.weight
# all_embeddings.5.weight
# all_embeddings.6.weight
# all_embeddings.7.weight
# Train Accuracy epoch 0, loss 947.7613866329193 %
#
#  Test Accuracy  267.2843322753906 %
# Score! 11.347669083468707
# saved! 11.347669083468707
# Train Accuracy epoch 1, loss 901.5031816959381 %
# Train Accuracy epoch 2, loss 880.8046555519104 %
# Train Accuracy epoch 3, loss 903.0100932121277 %
# Train Accuracy epoch 4, loss 882.1363799571991 %
# Train Accuracy epoch 5, loss 877.5288369655609 %
# Train Accuracy epoch 6, loss 864.8692004680634 %
# Train Accuracy epoch 7, loss 876.1665019989014 %
# Train Accuracy epoch 8, loss 877.9202365875244 %
# Train Accuracy epoch 9, loss 864.2688870429993 %
# Train Accuracy epoch 10, loss 857.0632402896881 %
#
#  Test Accuracy  247.02359008789062 %
# Score! 10.389600637223985
# saved! 10.389600637223985
# Train Accuracy epoch 11, loss 845.2604613304138 %
# Train Accuracy epoch 12, loss 846.8776769638062 %
# Train Accuracy epoch 13, loss 843.7306759357452 %
# Train Accuracy epoch 14, loss 831.0803196430206 %
# Train Accuracy epoch 15, loss 831.5663850307465 %
# Train Accuracy epoch 16, loss 828.5286312103271 %
# Train Accuracy epoch 17, loss 817.3178322315216 %
# Train Accuracy epoch 18, loss 826.6962194442749 %
# Train Accuracy epoch 19, loss 817.3083765506744 %
# Train Accuracy epoch 20, loss 801.9336397647858 %
#
#  Test Accuracy  230.44883728027344 %
# Score! 9.68948566707564
# saved! 9.68948566707564
# Fold
# module_list.12.linear.weight
# module_list.12.linear.bias
# module_list.12.batch_norm.weight
# module_list.12.batch_norm.bias
# module_list.13.linear.weight
# module_list.13.linear.bias
# module_list.13.batch_norm.weight
# module_list.13.batch_norm.bias
# layers.0.weight
# layers.0.bias
# layers.3.weight
# layers.3.bias
# layers.6.weight
# layers.6.bias
# mix_layers.0.weight
# mix_layers.0.bias
# mix_layers.3.weight
# mix_layers.3.bias
# mix_layers.6.weight
# mix_layers.6.bias
# all_embeddings.0.weight
# all_embeddings.1.weight
# all_embeddings.2.weight
# all_embeddings.3.weight
# all_embeddings.4.weight
# all_embeddings.5.weight
# all_embeddings.6.weight
# all_embeddings.7.weight
# Train Accuracy epoch 0, loss 927.308497428894 %
#
#  Test Accuracy  256.1329040527344 %
# Score! 12.55652912182383
# saved! 12.55652912182383
# Train Accuracy epoch 1, loss 876.5761992931366 %
# Train Accuracy epoch 2, loss 885.7404079437256 %
# Train Accuracy epoch 3, loss 864.7482354640961 %
# Train Accuracy epoch 4, loss 860.4296326637268 %
# Train Accuracy epoch 5, loss 861.3430109024048 %
# Train Accuracy epoch 6, loss 857.0138871669769 %
# Train Accuracy epoch 7, loss 844.7534337043762 %
# Train Accuracy epoch 8, loss 864.1418352127075 %
# Train Accuracy epoch 9, loss 841.8595685958862 %
# Train Accuracy epoch 10, loss 828.1579401493073 %
#
#  Test Accuracy  243.64256286621094 %
# Score! 11.976176888045698
# saved! 11.976176888045698
# Train Accuracy epoch 11, loss 832.3507215976715 %
# Train Accuracy epoch 12, loss 827.0245959758759 %
# Train Accuracy epoch 13, loss 813.3311808109283 %
# Train Accuracy epoch 14, loss 822.7683815956116 %
