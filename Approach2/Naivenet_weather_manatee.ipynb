# %%
# Load the Drive helper and mount
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import argparse
import yaml
import time
import datetime
import cv2
import numpy as np
import pandas as pd
import random

from skimage import io, transform
import matplotlib.pyplot as plt
from scipy.ndimage import zoom
from scipy import ndimage, misc

import torch
import torch.utils.data
from torch import nn, optim
from torch.nn import functional as F
from torchvision import datasets, transforms, utils
from torchvision.utils import save_image
from torch.utils.data import Dataset, DataLoader
import torchvision
import torch
from torch.autograd import Variable
import torch.optim as optim
from sklearn.metrics import mean_absolute_error

from google.colab import drive
import os
import warnings
from collections import defaultdict
from sklearn.model_selection import KFold
import time
from scipy import stats
import sys

# %%
categorical_columns = ['species', 'attractant','trap_type']
numerical_columns = ['collection_date_start', 'collection_date_end', 'GPS_lat', 'GPS_lon']

weather_columns = ['sunriseTime', 'sunsetTime', 'moonPhase', 
                     'precipIntensity', 'precipIntensityMax', 'precipProbability', 'temperatureHigh', 'temperatureHighTime',
                     'temperatureLow', 'temperatureLowTime', 'apparentTemperatureHigh', 'apparentTemperatureHighTime',
                     'apparentTemperatureLow', 'apparentTemperatureLowTime', 'dewPoint', 'humidity', 'pressure', 'windSpeed', 'windGust', 
                     'windGustTime', 'windBearing', 'cloudCover', 'uvIndex', 'uvIndexTime','visibility', 'temperatureMin',
                     'temperatureMinTime', 'temperatureMax', 'temperatureMaxTime', 'apparentTemperatureMin','apparentTemperatureMinTime', 'apparentTemperatureMax',
                     'apparentTemperatureMaxTime','time']

for i in range(1,15):
    for item in weather_columns:
        numerical_columns.append(item + str(i))

print(numerical_columns)
# Out:
# ['collection_date_start', 'collection_date_end', 'GPS_lat', 'GPS_lon', 'sunriseTime1', 'sunsetTime1', 'moonPhase1', 'precipIntensity1', 'precipIntensityMax1', 'precipProbability1', 'temperatureHigh1', 'temperatureHighTime1', 'temperatureLow1', 'temperatureLowTime1', 'apparentTemperatureHigh1', 'apparentTemperatureHighTime1', 'apparentTemperatureLow1', 'apparentTemperatureLowTime1', 'dewPoint1', 'humidity1', 'pressure1', 'windSpeed1', 'windGust1', 'windGustTime1', 'windBearing1', 'cloudCover1', 'uvIndex1', 'uvIndexTime1', 'visibility1', 'temperatureMin1', 'temperatureMinTime1', 'temperatureMax1', 'temperatureMaxTime1', 'apparentTemperatureMin1', 'apparentTemperatureMinTime1', 'apparentTemperatureMax1', 'apparentTemperatureMaxTime1', 'time1', 'sunriseTime2', 'sunsetTime2', 'moonPhase2', 'precipIntensity2', 'precipIntensityMax2', 'precipProbability2', 'temperatureHigh2', 'temperatureHighTime2', 'temperatureLow2', 'temperatureLowTime2', 'apparentTemperatureHigh2', 'apparentTemperatureHighTime2', 'apparentTemperatureLow2', 'apparentTemperatureLowTime2', 'dewPoint2', 'humidity2', 'pressure2', 'windSpeed2', 'windGust2', 'windGustTime2', 'windBearing2', 'cloudCover2', 'uvIndex2', 'uvIndexTime2', 'visibility2', 'temperatureMin2', 'temperatureMinTime2', 'temperatureMax2', 'temperatureMaxTime2', 'apparentTemperatureMin2', 'apparentTemperatureMinTime2', 'apparentTemperatureMax2', 'apparentTemperatureMaxTime2', 'time2', 'sunriseTime3', 'sunsetTime3', 'moonPhase3', 'precipIntensity3', 'precipIntensityMax3', 'precipProbability3', 'temperatureHigh3', 'temperatureHighTime3', 'temperatureLow3', 'temperatureLowTime3', 'apparentTemperatureHigh3', 'apparentTemperatureHighTime3', 'apparentTemperatureLow3', 'apparentTemperatureLowTime3', 'dewPoint3', 'humidity3', 'pressure3', 'windSpeed3', 'windGust3', 'windGustTime3', 'windBearing3', 'cloudCover3', 'uvIndex3', 'uvIndexTime3', 'visibility3', 'temperatureMin3', 'temperatureMinTime3', 'temperatureMax3', 'temperatureMaxTime3', 'apparentTemperatureMin3', 'apparentTemperatureMinTime3', 'apparentTemperatureMax3', 'apparentTemperatureMaxTime3', 'time3', 'sunriseTime4', 'sunsetTime4', 'moonPhase4', 'precipIntensity4', 'precipIntensityMax4', 'precipProbability4', 'temperatureHigh4', 'temperatureHighTime4', 'temperatureLow4', 'temperatureLowTime4', 'apparentTemperatureHigh4', 'apparentTemperatureHighTime4', 'apparentTemperatureLow4', 'apparentTemperatureLowTime4', 'dewPoint4', 'humidity4', 'pressure4', 'windSpeed4', 'windGust4', 'windGustTime4', 'windBearing4', 'cloudCover4', 'uvIndex4', 'uvIndexTime4', 'visibility4', 'temperatureMin4', 'temperatureMinTime4', 'temperatureMax4', 'temperatureMaxTime4', 'apparentTemperatureMin4', 'apparentTemperatureMinTime4', 'apparentTemperatureMax4', 'apparentTemperatureMaxTime4', 'time4', 'sunriseTime5', 'sunsetTime5', 'moonPhase5', 'precipIntensity5', 'precipIntensityMax5', 'precipProbability5', 'temperatureHigh5', 'temperatureHighTime5', 'temperatureLow5', 'temperatureLowTime5', 'apparentTemperatureHigh5', 'apparentTemperatureHighTime5', 'apparentTemperatureLow5', 'apparentTemperatureLowTime5', 'dewPoint5', 'humidity5', 'pressure5', 'windSpeed5', 'windGust5', 'windGustTime5', 'windBearing5', 'cloudCover5', 'uvIndex5', 'uvIndexTime5', 'visibility5', 'temperatureMin5', 'temperatureMinTime5', 'temperatureMax5', 'temperatureMaxTime5', 'apparentTemperatureMin5', 'apparentTemperatureMinTime5', 'apparentTemperatureMax5', 'apparentTemperatureMaxTime5', 'time5', 'sunriseTime6', 'sunsetTime6', 'moonPhase6', 'precipIntensity6', 'precipIntensityMax6', 'precipProbability6', 'temperatureHigh6', 'temperatureHighTime6', 'temperatureLow6', 'temperatureLowTime6', 'apparentTemperatureHigh6', 'apparentTemperatureHighTime6', 'apparentTemperatureLow6', 'apparentTemperatureLowTime6', 'dewPoint6', 'humidity6', 'pressure6', 'windSpeed6', 'windGust6', 'windGustTime6', 'windBearing6', 'cloudCover6', 'uvIndex6', 'uvIndexTime6', 'visibility6', 'temperatureMin6', 'temperatureMinTime6', 'temperatureMax6 ...

# %%
sentinel_frame = pd.read_csv('/content/drive/My Drive/BerkeleyResults/Approach2/Manatee_w.csv')


sentinel_frame["collection_date_start"]= pd.to_datetime(sentinel_frame["collection_date_start"])
sentinel_frame["collection_date_end"]= pd.to_datetime(sentinel_frame["collection_date_end"])
# sentinel_frame["DIFF_DAYS"] = (sentinel_frame["collection_date_end"] - sentinel_frame["collection_date_start"]).dt.days
sentinel_frame["collection_date_start"]= sentinel_frame["collection_date_start"].dt.week
sentinel_frame["collection_date_end"]= sentinel_frame["collection_date_end"].dt.week

for category in categorical_columns:
    sentinel_frame[category] = sentinel_frame[category].astype('category')
    # print( sentinel_frame[category].dtype)
    # sentinel_frame[category] = pd.Categorical(sentinel_frame[category]).codes

categorical_column_sizes = [len(sentinel_frame[column].cat.categories) for column in categorical_columns]
categorical_embedding_sizes = [(col_size, min(50, (col_size+1)//2)) for col_size in categorical_column_sizes]

for col in numerical_columns:
    sentinel_frame[col] = (sentinel_frame[col] - sentinel_frame[col].mean()) / (sentinel_frame[col].max() - sentinel_frame[col].min())
    sentinel_frame[col] = sentinel_frame[col].fillna(0)
    
def get_categorical_tensor(in_frame, categories):
    categorical_data = np.stack([in_frame[col].cat.codes.values for col in categories], 1)
    categorical_data = torch.tensor(categorical_data, dtype=torch.int64)

    return categorical_data

def get_numerical_tensor(in_frame, numerical_columns):
    numerical_data = np.stack([in_frame[col].values for col in numerical_columns], 1)
    numerical_data = torch.tensor(numerical_data, dtype=torch.float)
    return numerical_data
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (54,57,58,92,95,96,130,133,134,168,171,172,206,209,210,244,247,248,282,285,286,320,323,324,358,361,362,396,399,400,434,437,438,472,475,476,510,513,514,548,551,552) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# 0        15
# 1        15
# 2        15
# 3        15
# 4        15
#          ..
# 12842    49
# 12843    49
# 12844    49
# 12845    49
# 12846    49
# Name: collection_date_start, Length: 12847, dtype: int64

# %%
# cor = sentinel_frame.corr(method='kendall')

# x = cor["TOTAL"].sort_values(ascending=False)
pd.set_option('display.max_rows', 99999)
print(sentinel_frame.columns[sentinel_frame.isna().any()].tolist()
)
# Out:
# ['icon1', 'precipIntensityMaxTime1', 'precipType1', 'summary1', 'icon2', 'precipIntensityMaxTime2', 'precipType2', 'summary2', 'icon3', 'precipIntensityMaxTime3', 'precipType3', 'summary3', 'icon4', 'precipIntensityMaxTime4', 'precipType4', 'summary4', 'icon5', 'precipIntensityMaxTime5', 'precipType5', 'summary5', 'icon6', 'precipIntensityMaxTime6', 'precipType6', 'summary6', 'icon7', 'precipIntensityMaxTime7', 'precipType7', 'summary7', 'icon8', 'precipIntensityMaxTime8', 'precipType8', 'summary8', 'icon9', 'precipIntensityMaxTime9', 'precipType9', 'summary9', 'icon10', 'precipIntensityMaxTime10', 'precipType10', 'summary10', 'icon11', 'precipIntensityMaxTime11', 'precipType11', 'summary11', 'icon12', 'precipIntensityMaxTime12', 'precipType12', 'summary12', 'icon13', 'precipIntensityMaxTime13', 'precipType13', 'summary13', 'icon14', 'precipIntensityMaxTime14', 'precipType14', 'summary14']

# %%
cor = sentinel_frame.corr(method='spearman')

x = cor["sample_count"].sort_values(ascending=False)
pd.set_option('display.max_rows', len(x))

print(x)
# Out:
# sample_count                     1.000000
# GPS_lat                          0.184298
# Unnamed: 0                       0.093059
# collection_date_end              0.092332
# collection_date_start            0.089155
# GPS_lon                          0.059531
# precipProbability1               0.050818
# temperatureMin14                 0.015105
# temperatureMin8                  0.015105
# temperatureMin3                  0.015105
# temperatureMin12                 0.015105
# temperatureMin7                  0.015105
# temperatureMin4                  0.015105
# temperatureMin10                 0.015105
# temperatureMin6                  0.015105
# temperatureMin13                 0.015105
# temperatureMin11                 0.015105
# temperatureMin5                  0.015105
# temperatureMin1                  0.014747
# temperatureMin2                  0.014747
# dewPoint12                       0.013476
# dewPoint13                       0.013476
# dewPoint10                       0.013476
# dewPoint11                       0.013476
# dewPoint4                        0.013476
# dewPoint8                        0.013476
# dewPoint7                        0.013476
# dewPoint14                       0.013476
# dewPoint9                        0.013476
# dewPoint6                        0.013476
# dewPoint3                        0.013476
# dewPoint5                        0.013476
# pressure1                        0.013186
# pressure2                        0.013186
# dewPoint2                        0.013111
# dewPoint1                        0.013111
# pressure12                       0.012794
# pressure13                       0.012794
# pressure3                        0.012794
# pressure14                       0.012794
# pressure4                        0.012794
# pressure10                       0.012794
# pressure8                        0.012794
# pressure6                        0.012794
# pressure11                       0.012794
# pressure9                        0.012794
# pressure5                        0.012794
# pressure7                        0.012794
# apparentTemperatureMin4          0.012599
# apparentTemperatureMin3          0.012599
# apparentTemperatureMin5          0.012599
# apparentTemperatureMin14         0.012599
# apparentTemperatureMin6          0.012599
# apparentTemperatureMin10         0.012599
# apparentTemperatureMin12         0.012599
# apparentTemperatureMin11         0.012599
# apparentTemperatureMin8          0.012599
# apparentTemperatureMin13         0.012599
# apparentTemperatureMin7          0.012599
# apparentTemperatureMin9          0.012599
# apparentTemperatureMin2          0.012240
# apparentTemperatureMin1          0.012240
# windBearing2                     0.006794
# windBearing1                     0.006794
# windBearing9                     0.006394
# windBearing6                     0.006394
# windBearing3                     0.006394
# windBearing12                    0.006394
# windBearing11                    0.006394
# windBearing8                     0.006394
# windBearing10                    0.006394
# windBearing14                    0.006394
# windBearing5                     0.006394
# windBearing4                     0.006394
# windBearing7                     0.006394
# windBearing13                    0.006394
# apparentTemperatureMax8          0.004788
# apparentTemperatureMax6          0.004788
# apparentTemperatureMax4          0.004788
# apparentTemperatureMax5          0.004788
# apparentTemperatureMax3          0.004788
# apparentTemperatureMax7          0.004788
# apparentTemperatureMax13         0.004788
# apparentTemperatureMax12         0.004788
# apparentTemperatureMax14         0.004788
# apparentTemperatureMax11         0.004788
# apparentTemperatureMax9          0.004788
# apparentTemperatureMax10         0.004788
# apparentTemperatureHigh14        0.004745
# apparentTemperatureHigh5         0.004745
# apparentTemperatureHigh13        0.004745
# apparentTemperatureHigh3         0.004745
# apparentTemperatureHigh6         0.004745
# apparentTemperatureHigh4         0.004745
# apparentTemperatureHigh8         0.004745
# apparentTemperatureHigh12        0.004745
# apparentTemperatureHigh10        0.004745
# apparentTemperatureHigh9         0.004745
# apparentTemperatureHigh7         0.004745
# apparentTemperatureHigh11        0.004745
# apparentTemperatureMax1          0.004412
# apparentTemperatureMax2          0.004412
# apparentTemperatureHigh2         0.004369
# apparentTemperatureHigh1         0.004369
# apparentTemperatureLow1          0.004274
# apparentTemperatureMaxTime9     -0.000617
# apparentTemperatureMaxTime12    -0.000617
# apparentTemperatureMaxTime3     -0.000617
# apparentTemperatureMaxTime11    -0.000617
# apparentTemperatureMaxTime10    -0.000617
# apparentTemperatureMaxTime8     -0.000617
# apparentTemperatureMaxTime14    -0.000617
# apparentTemperatureMaxTime13    -0.000617
# apparentTemperatureMaxTime4     -0.000617
# apparentTemperatureMaxTime6     -0.000617
# temperatureHighTime6            -0.000652
# temperatureHighTime4            -0.000652
# temperatureHighTime7            -0.000652
# temperatureHighTime9            -0.000652
# temperatureHighTime3            -0.000652
# temperatureHighTime8            -0.000652
# temperatureHighTime12           -0.000652
# temperatureHighTime11           -0.000652
# temperatureHighTime13           -0.000652
# temperatureHighTime10           -0.000652
# temperatureHighTime5            -0.000652
# temperatureHighTime14           -0.000652
# temperatureMaxTime12            -0.000665
# temperatureMaxTime7             -0.000665
# temperatureMaxTime4             -0.000665
# temperatureMaxTime11            -0.000665
# temperatureMaxTime10            -0.000665
# temperatureMaxTime3             -0.000665
# temperatureMaxTime5             -0.000665
# temperatureMaxTime13            -0.000665
# temperatureMaxTime14            -0.000665
# temperatureMaxTime6             -0.000665
# temperatureMaxTime9             -0.000665
# temperatureMaxTime8             -0.000665
# time9                           -0.000803
# time6                           -0.000803
# time13                          -0.000803
# time8                           -0.000803
# time5                           -0.000803
# time7                           -0.000803
# time14                          -0.000803
# time12                          -0.000803
# time11                          -0.000803
# time3                           -0.000803
# time10                          -0.000803
# time4                           -0.000803
# sunriseTime4                    -0.000854
# sunriseTime14                   -0.000854
# sunriseTime9                    -0.000854
# sunriseTime13                   -0.000854
# sunriseTime3                    -0.000854
# sunriseTime10                   -0.000854
# sunriseTime6                    -0.000854
# sunriseTime7                    -0.000854
# sunriseTime12                   -0.000854
# sunriseTime11                   -0.000854
# sunriseTime5                    -0.000854
# sunriseTime8                    -0.000854
# sunsetTime1                     -0.000975
# sunsetTime2                     -0.000975
# windGustTime2                   -0.000998
# windGustTime1                   -0.000998
# apparentTemperatureHighTime2    -0.001001
# apparentTemperatureHighTime1    -0.001001
# apparentTemperatureMaxTime2     -0.001014
# apparentTemperatureMaxTime1     -0.001014
# temperatureHighTime2            -0.001055
# temperatureHighTime1            -0.001055
# temperatureMaxTime1             -0.001068
# temperatureMaxTime2             -0.001068
# time1                           -0.001206
# time2                           -0.001206
# temperatureLowTime1             -0.001208
# temperatureLowTime2             -0.001208
# apparentTemperatureLowTime2     -0.001212
# apparentTemperatureLowTime1     -0.001212
# sunriseTime2                    -0.001250
# sunriseTime1                    -0.001250
# uvIndexTime2                    -0.001318
# uvIndexTime1                    -0.001318
# precipIntensityMaxTime1         -0.002054
# precipIntensityMaxTime2         -0.002054
# temperatureMinTime10            -0.009568
# temperatureMinTime3             -0.009568
# temperatureMinTime4             -0.009568
# temperatureMinTime13            -0.009568
# temperatureMinTime11            -0.009568
# temperatureMinTime9             -0.009568
# temperatureMinTime8             -0.009568
# temperatureMinTime5             -0.009568
# temperatureMinTime6             -0.009568
# temperatureMinTime14            -0.009568
# temperatureMinTime12            -0.009568
# temperatureMinTime7             -0.009568
# apparentTemperatureMinTime13    -0.009655
# apparentTemperatureMinTime14    -0.009655
# apparentTemperatureMinTime10    -0.009655
# apparentTemperatureMinTime8     -0.009655
# apparentTemperatureMinTime9     -0.009655
# apparentTemperatureMinTime6     -0.009655
# apparentTemperatureMinTime4     -0.009655
# apparentTemperatureMinTime3     -0.009655
# apparentTemperatureMinTime11    -0.009655
# apparentTemperatureMinTime12    -0.009655
# apparentTemperatureMinTime7     -0.009655
# apparentTemperatureMinTime5     -0.009655
# temperatureMinTime1             -0.009972
# temperatureMinTime2             -0.009972
# apparentTemperatureMinTime1     -0.010060
# apparentTemperatureMinTime2     -0.010060
# uvIndexTime6                    -0.011620
# uvIndexTime9                    -0.011620
# uvIndexTime8                    -0.011620
# uvIndexTime3                    -0.011620
# uvIndexTime13                   -0.011620
# uvIndexTime10                   -0.011620
# uvIndexTime12                   -0.011620
# uvIndexTime5                    -0.011620
# uvIndexTime11                   -0.011620
# uvIndexTime4                    -0.011620
# uvIndexTime7                    -0.011620
# uvIndexTime14                   -0.011620
# moonPhase10                     -0.030659
# moonPhase7                      -0.030659
# moonPhase6                      -0.030659
# moonPhase4                      -0.030659
# moonPhase8                      -0.030659
# moonPhase14                     -0.030659
# moonPhase9                      -0.030659
# moonPhase13                     -0.030659
# moonPhase12                     -0.030659
# moonPhase11                     -0.030659
# moonPhase3                      -0.030659
# moonPhase5                      -0.030659
# moonPhase1                      -0.031071
# moonPhase2                      -0.031071
# uvIndex14                       -0.044320
# uvIndex4                        -0.044320
# uvIndex9                        -0.044320
# uvIndex6                        -0.044320
# uvIndex5                        -0.044320
# uvIndex12                       -0.044320
# uvIndex8                        -0.044320
# uvIndex3                        -0.044320
# uvIndex11                       -0.044320
# uvIndex7                        -0.044320
# uvIndex10                       -0.044320
# uvIndex13                       -0.044320
# uvIndex1                        -0.044711
# uvIndex2                        -0.044711
# visibility3                     -0.050231
# visibility4                     -0.050231
# visibility12                    -0.050231
# visibility13                    -0.050231
# visibility11                    -0.050231
# visibility9                     -0.050231
# visibility8                     -0.050231
# visibility10                    -0.050231
# visibility7                     -0.050231
# visibility6                     -0.050231
# visibility14                    -0.050231
# visibility5                     -0.050231
# visibility1                     -0.050632
# visibility2                     -0.050632
# temperatureMax4                 -0.072107
# temperatureMax14                -0.072107
# temperatureMax9                 -0.072107
# temperatureMax8                 -0.072107
# temperatureMax6                 -0.072107
# temperatureMax12                -0.072107
# temperatureMax13                -0.072107
# temperatureMax7                 -0.072107
# temperatureMax3                 -0.072107
# temperatureMax5                 -0.072107
# temperatureMax10                -0.072107
# temperatureMax11                -0.072107
# temperatureMax2                 -0.075955
# temperatureMax1                 -0.075955
# temperatureHigh2                -0.078766
# temperatureHigh1                -0.078766
# temperatureHigh7                -0.079179
# temperatureHigh6                -0.079179
# temperatureHigh3                -0.079179
# temperatureHigh11               -0.079179
# temperatureHigh8                -0.079179
# temperatureHigh13               -0.079179
# temperatureHigh9                -0.079179
# temperatureHigh5                -0.079179
# temperatureHigh10               -0.079179
# temperatureHigh14               -0.079179
# temperatureHigh4                -0.079179
# temperatureHigh12               -0.079179
# trap_number                           NaN
# trap_duration                         NaN
# Name: sample_count, dtype: float64

# %%
cor = sentinel_frame.corr(method='pearson')

x = cor["sample_count"].sort_values(ascending=False)
pd.set_option('display.max_rows', len(x))

print(x)
# Out:
# sample_count                     1.000000
# GPS_lat                          0.078418
# Unnamed: 0                       0.062921
# collection_date_end              0.062376
# collection_date_start            0.060080
# windSpeed2                       0.025957
# windSpeed1                       0.025957
# windSpeed14                      0.025809
# windSpeed5                       0.025809
# windSpeed7                       0.025809
# windSpeed10                      0.025809
# windSpeed12                      0.025809
# windSpeed13                      0.025809
# windSpeed9                       0.025809
# windSpeed3                       0.025809
# windSpeed8                       0.025809
# windSpeed4                       0.025809
# windSpeed11                      0.025809
# windSpeed6                       0.025809
# temperatureLow1                  0.016410
# temperatureLow2                  0.016410
# temperatureLow5                  0.016349
# temperatureLow8                  0.016349
# temperatureLow7                  0.016349
# temperatureLow12                 0.016349
# temperatureLow13                 0.016349
# temperatureLow6                  0.016349
# temperatureLow10                 0.016349
# temperatureLow3                  0.016349
# temperatureLow4                  0.016349
# temperatureLow11                 0.016349
# temperatureLow14                 0.016349
# temperatureLow9                  0.016349
# apparentTemperatureLow2          0.016060
# apparentTemperatureLow1          0.016060
# apparentTemperatureLow12         0.016023
# apparentTemperatureLow4          0.016023
# apparentTemperatureLow11         0.016023
# apparentTemperatureLow9          0.016023
# apparentTemperatureLow10         0.016023
# apparentTemperatureLow3          0.016023
# apparentTemperatureLow8          0.016023
# apparentTemperatureLow14         0.016023
# apparentTemperatureLow13         0.016023
# apparentTemperatureLow6          0.016023
# apparentTemperatureLow7          0.016023
# apparentTemperatureLow5          0.016023
# cloudCover2                      0.013171
# cloudCover1                      0.013171
# cloudCover13                     0.013074
# cloudCover6                      0.013074
# cloudCover12                     0.013074
# cloudCover8                      0.013074
# cloudCover3                      0.013074
# cloudCover7                      0.013074
# cloudCover14                     0.013074
# cloudCover9                      0.013074
# cloudCover4                      0.013074
# cloudCover10                     0.013074
# cloudCover5                      0.013074
# cloudCover11                     0.013074
# humidity13                       0.012857
# humidity7                        0.012857
# humidity14                       0.012857
# humidity6                        0.012857
# humidity12                       0.012857
# humidity8                        0.012857
# humidity9                        0.012857
# humidity5                        0.012857
# humidity3                        0.012857
# humidity4                        0.012857
# humidity11                       0.012857
# humidity10                       0.012857
# humidity1                        0.012849
# humidity2                        0.012849
# dewPoint7                        0.011337
# dewPoint6                        0.011337
# dewPoint12                       0.011337
# dewPoint11                       0.011337
# dewPoint4                        0.011337
# dewPoint9                        0.011337
# dewPoint10                       0.011337
# dewPoint5                        0.011337
# dewPoint8                        0.011337
# dewPoint13                       0.011337
# dewPoint3                        0.011337
# dewPoint14                       0.011337
# temperatureMin6                  0.011337
# temperatureMin9                  0.011337
# temperatureMin10                 0.011337
# temperatureMin13                 0.011337
# temperatureMin12                 0.011337
# temperatureMin5                  0.011337
# apparentTemperatureMaxTime9     -0.000494
# apparentTemperatureMaxTime14    -0.000494
# temperatureHighTime9            -0.000499
# temperatureHighTime3            -0.000499
# temperatureHighTime10           -0.000499
# temperatureHighTime5            -0.000499
# temperatureHighTime8            -0.000499
# temperatureHighTime11           -0.000499
# temperatureHighTime6            -0.000499
# temperatureHighTime13           -0.000499
# temperatureHighTime4            -0.000499
# temperatureHighTime12           -0.000499
# temperatureHighTime7            -0.000499
# temperatureHighTime14           -0.000499
# apparentTemperatureHighTime6    -0.000505
# apparentTemperatureHighTime3    -0.000505
# apparentTemperatureHighTime7    -0.000505
# apparentTemperatureHighTime4    -0.000505
# apparentTemperatureHighTime5    -0.000505
# apparentTemperatureHighTime8    -0.000505
# apparentTemperatureHighTime9    -0.000505
# apparentTemperatureHighTime11   -0.000505
# apparentTemperatureHighTime14   -0.000505
# apparentTemperatureHighTime10   -0.000505
# apparentTemperatureHighTime12   -0.000505
# apparentTemperatureHighTime13   -0.000505
# temperatureLowTime6             -0.000509
# temperatureLowTime8             -0.000509
# temperatureLowTime11            -0.000509
# temperatureLowTime7             -0.000509
# temperatureLowTime12            -0.000509
# temperatureLowTime10            -0.000509
# temperatureLowTime5             -0.000509
# temperatureLowTime13            -0.000509
# temperatureLowTime3             -0.000509
# temperatureLowTime14            -0.000509
# temperatureLowTime4             -0.000509
# temperatureLowTime9             -0.000509
# apparentTemperatureLowTime13    -0.000511
# apparentTemperatureLowTime5     -0.000511
# apparentTemperatureLowTime9     -0.000511
# apparentTemperatureLowTime10    -0.000511
# apparentTemperatureLowTime7     -0.000511
# apparentTemperatureLowTime6     -0.000511
# apparentTemperatureLowTime12    -0.000511
# apparentTemperatureLowTime3     -0.000511
# apparentTemperatureLowTime11    -0.000511
# apparentTemperatureLowTime14    -0.000511
# apparentTemperatureLowTime8     -0.000511
# apparentTemperatureLowTime4     -0.000511
# sunsetTime13                    -0.000515
# sunsetTime7                     -0.000515
# sunsetTime3                     -0.000515
# sunsetTime12                    -0.000515
# sunsetTime9                     -0.000515
# sunsetTime4                     -0.000515
# sunsetTime6                     -0.000515
# sunsetTime11                    -0.000515
# sunsetTime5                     -0.000515
# sunsetTime10                    -0.000515
# sunsetTime8                     -0.000515
# sunsetTime14                    -0.000515
# time4                           -0.000515
# time3                           -0.000515
# time11                          -0.000515
# time5                           -0.000515
# time10                          -0.000515
# time8                           -0.000515
# time6                           -0.000515
# time9                           -0.000515
# time7                           -0.000515
# time13                          -0.000515
# time14                          -0.000515
# time12                          -0.000515
# sunriseTime7                    -0.000516
# sunriseTime11                   -0.000516
# sunriseTime3                    -0.000516
# sunriseTime14                   -0.000516
# sunriseTime9                    -0.000516
# sunriseTime6                    -0.000516
# sunriseTime13                   -0.000516
# sunriseTime5                    -0.000516
# sunriseTime12                   -0.000516
# sunriseTime8                    -0.000516
# sunriseTime10                   -0.000516
# sunriseTime4                    -0.000516
# uvIndexTime11                   -0.000543
# uvIndexTime4                    -0.000543
# uvIndexTime13                   -0.000543
# uvIndexTime5                    -0.000543
# uvIndexTime12                   -0.000543
# uvIndexTime14                   -0.000543
# uvIndexTime6                    -0.000543
# uvIndexTime3                    -0.000543
# uvIndexTime7                    -0.000543
# uvIndexTime10                   -0.000543
# uvIndexTime9                    -0.000543
# uvIndexTime8                    -0.000543
# temperatureMinTime8             -0.000556
# temperatureMinTime14            -0.000556
# temperatureMinTime3             -0.000556
# temperatureMinTime11            -0.000556
# temperatureMinTime7             -0.000556
# temperatureMinTime10            -0.000556
# temperatureMinTime4             -0.000556
# temperatureMinTime9             -0.000556
# temperatureMinTime5             -0.000556
# temperatureMinTime13            -0.000556
# temperatureMinTime12            -0.000556
# temperatureMinTime6             -0.000556
# apparentTemperatureMinTime7     -0.000584
# apparentTemperatureMinTime5     -0.000584
# apparentTemperatureMinTime3     -0.000584
# apparentTemperatureMinTime12    -0.000584
# apparentTemperatureMinTime10    -0.000584
# apparentTemperatureMinTime8     -0.000584
# apparentTemperatureMinTime9     -0.000584
# apparentTemperatureMinTime14    -0.000584
# apparentTemperatureMinTime13    -0.000584
# apparentTemperatureMinTime6     -0.000584
# apparentTemperatureMinTime11    -0.000584
# apparentTemperatureMinTime4     -0.000584
# windGustTime2                   -0.000650
# windGustTime1                   -0.000650
# temperatureMaxTime1             -0.000661
# temperatureMaxTime2             -0.000661
# apparentTemperatureMaxTime1     -0.000667
# apparentTemperatureMaxTime2     -0.000667
# temperatureHighTime2            -0.000672
# temperatureHighTime1            -0.000672
# apparentTemperatureHighTime2    -0.000677
# apparentTemperatureHighTime1    -0.000677
# temperatureLowTime1             -0.000682
# temperatureLowTime2             -0.000682
# apparentTemperatureLowTime2     -0.000685
# apparentTemperatureLowTime1     -0.000685
# sunsetTime1                     -0.000687
# sunsetTime2                     -0.000687
# time2                           -0.000688
# time1                           -0.000688
# sunriseTime1                    -0.000688
# sunriseTime2                    -0.000688
# uvIndexTime2                    -0.000716
# uvIndexTime1                    -0.000716
# temperatureMinTime1             -0.000728
# temperatureMinTime2             -0.000728
# apparentTemperatureMinTime1     -0.000755
# apparentTemperatureMinTime2     -0.000755
# windBearing2                    -0.001358
# windBearing1                    -0.001358
# windBearing8                    -0.001562
# windBearing14                   -0.001562
# windBearing10                   -0.001562
# windBearing12                   -0.001562
# windBearing6                    -0.001562
# windBearing7                    -0.001562
# windBearing4                    -0.001562
# windBearing3                    -0.001562
# windBearing13                   -0.001562
# windBearing9                    -0.001562
# windBearing5                    -0.001562
# windBearing11                   -0.001562
# precipIntensityMax1             -0.002850
# precipIntensityMax2             -0.002850
# precipIntensityMax11            -0.002916
# precipIntensityMax3             -0.002916
# precipIntensityMax14            -0.002916
# precipIntensityMax8             -0.002916
# precipIntensityMax7             -0.002916
# precipIntensityMax13            -0.002916
# precipIntensityMax9             -0.002916
# precipIntensityMax5             -0.002916
# precipIntensityMax6             -0.002916
# precipIntensityMax12            -0.002916
# precipIntensityMax10            -0.002916
# precipIntensityMax4             -0.002916
# precipIntensity2                -0.003516
# precipIntensity1                -0.003516
# precipIntensity14               -0.003574
# precipIntensity4                -0.003574
# temperatureHigh7                -0.012972
# temperatureHigh14               -0.012972
# temperatureHigh8                -0.012972
# temperatureHigh2                -0.013135
# temperatureHigh1                -0.013135
# temperatureMax12                -0.014317
# temperatureMax4                 -0.014317
# temperatureMax10                -0.014317
# temperatureMax11                -0.014317
# temperatureMax7                 -0.014317
# temperatureMax5                 -0.014317
# temperatureMax13                -0.014317
# temperatureMax6                 -0.014317
# temperatureMax9                 -0.014317
# temperatureMax14                -0.014317
# temperatureMax8                 -0.014317
# temperatureMax3                 -0.014317
# temperatureMax1                 -0.014491
# temperatureMax2                 -0.014491
# GPS_lon                         -0.027955
# visibility14                    -0.029726
# visibility7                     -0.029726
# visibility9                     -0.029726
# visibility13                    -0.029726
# visibility4                     -0.029726
# visibility12                    -0.029726
# visibility11                    -0.029726
# visibility5                     -0.029726
# visibility10                    -0.029726
# visibility6                     -0.029726
# visibility3                     -0.029726
# visibility8                     -0.029726
# visibility2                     -0.029816
# visibility1                     -0.029816
# trap_number                           NaN
# trap_duration                         NaN
# DIFF_DAYS                             NaN
# Name: sample_count, dtype: float64

# %%
class Flatten(torch.nn.Module):
    def forward(self, x):
        return x.view(x.size()[0], -1)

class Swish(torch.autograd.Function):
    @staticmethod
    def forward(ctx, i):
        result = i * torch.sigmoid(i)
        ctx.save_for_backward(i)
        return result

    @staticmethod
    def backward(ctx, grad_output):
        i = ctx.saved_tensors[0]
        sigmoid_i = torch.sigmoid(i)
        return grad_output * (sigmoid_i * (1 + i * (1 - sigmoid_i)))
    
class SwishM(nn.Module):
    def forward(self, input_tensor):
        return Swish.apply(input_tensor)
        
def create_neural_modules(embedding_size, num_numerical_cols, output_size, hidden_size, dropout):
    all_layers = []
    num_categorical_cols = sum((nf for ni, nf in embedding_size))
    input_size = num_categorical_cols + num_numerical_cols

    all_layers.append(nn.Linear(input_size, hidden_size))
    all_layers.append(nn.LeakyReLU())
    all_layers.append(nn.BatchNorm1d(hidden_size))
    all_layers.append(nn.Dropout(dropout))

    all_layers.append(nn.Linear(hidden_size, hidden_size))
    all_layers.append(nn.LeakyReLU())
    all_layers.append(nn.BatchNorm1d(hidden_size))
    all_layers.append(nn.Dropout(dropout))

    all_layers.append(nn.Linear(hidden_size, output_size))
    all_layers.append(nn.ReLU())

    return nn.Sequential(*all_layers)

class Sentinel_net(nn.Module):

    def __init__(self, embedding_size, num_numerical_cols, output_size, dropout, hidden_size):
        super(Sentinel_net, self).__init__()
        self.layers = create_neural_modules(embedding_size, num_numerical_cols, output_size, hidden_size, dropout)
        self.all_embeddings = nn.ModuleList([nn.Embedding(ni, nf) for ni, nf in embedding_size])
        self.embedding_dropout = nn.Dropout(dropout)
        self.batch_norm_num = nn.BatchNorm1d(num_numerical_cols)

    def forward(self, x_categorical, x_numerical):

        embeddings = []
        for i, e in enumerate(self.all_embeddings):
            embeddings.append(e(x_categorical[:, i]))
        y = torch.cat(embeddings, 1)
        y = self.embedding_dropout(y)
        x_numerical = self.batch_norm_num(x_numerical)
        y = torch.cat([y, x_numerical], 1)
        y = self.layers(y)

        return y

# %%
def train_shallow_net(train_c_t,test_c_t,train_n_t,test_n_t,outputs_train,outputs_test, dropout, hidden_size, lr):
    model = Sentinel_net(categorical_embedding_sizes, train_n_t.shape[1], 1, dropout, hidden_size)
    model.train().cuda()

    criterion = torch.nn.MSELoss(reduction='mean') 
    params_dict = dict(model.named_parameters())
    params = []
    best = sys.maxsize
    r_value = 0
    std_err = 0
    
    for key, value in params_dict.items():
        if 'weight' in key and 'layers' in key:
            params += [{'params':value, 'weight_decay':4e-3}]
        else:
            params += [{'params':value, 'weight_decay':0.0}]

    optimizer = torch.optim.RMSprop(params, lr=lr, alpha=0.99, eps=1e-08, weight_decay=0, momentum=0.9, centered=False)
    epoch = 0

    for i in range(1, 1000):
        y_pred = model(train_c_t, train_n_t)
        loss = criterion(y_pred.squeeze(), outputs_train)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        model.eval()
        with torch.no_grad():
            y_pred2 = model(test_c_t, test_n_t)
            c_out, c_pred = outputs_test.cpu().detach().numpy(), y_pred2.cpu().detach().numpy().squeeze()
            current_score = mean_absolute_error(c_out, c_pred)
            if current_score < best:
                best = current_score
                m, b, r_value, p_value, std_err = stats.linregress(c_out,c_pred)

            model.train()
    
    #print('MAE = ',current_score, 'r2 = ',r_value, 'SE = ',std_err)
    return best, r_value, std_err

# %%
start_time = time.time()
learning = [0.01, 0.001, 0.0001] 
best_score_k_fold = sys.maxsize

print('2 Layers Architecture')

for dropout in range(0,7):
    dropout = round(dropout*.1, 2) 
    for hidden_size in range(50, 150, 10):
        for lr in learning: 

            scores, r_values, std_errors = [], [], []
            cv = KFold(n_splits=5, random_state=42, shuffle=True)
            foldc = 1
            for train_index, test_index in cv.split(sentinel_frame, None):
                #print('Fold ', foldc, end =" ") 
                train, test  = sentinel_frame.iloc[train_index], sentinel_frame.iloc[test_index]

                train_c_t = get_categorical_tensor(train, categorical_columns).cuda()
                test_c_t = get_categorical_tensor(test, categorical_columns).cuda()
                train_n_t = get_numerical_tensor(train, numerical_columns).cuda()
                test_n_t = get_numerical_tensor(test, numerical_columns).cuda()

                outputs_train = torch.tensor(train['sample_count'].values).flatten().type(torch.FloatTensor).cuda()
                outputs_test = torch.tensor(test['sample_count'].values).flatten().type(torch.FloatTensor).cuda()

                best_fold_score, best_r_value, best_std_error = train_shallow_net(train_c_t,test_c_t,train_n_t,test_n_t,outputs_train,outputs_test, dropout, hidden_size, lr)
                scores.append(best_fold_score)
                r_values.append(best_r_value)
                std_errors.append(best_std_error)
                foldc += 1
            #print(scores)
            current_score = sum(scores) / len(scores)
            print('MAE = ', current_score ,'r2 = ', sum(r_values) / len(r_values) ,'SE = ', sum(std_errors) / len(std_errors),'lr = ', lr,'hz = ', hidden_size, 'dr = ', dropout )
            if current_score < best_score_k_fold:
                best_score_k_fold = current_score
                print('Best so far', best_score_k_fold)
                print('')


print("--- %s seconds ---" % (time.time() - start_time))
# Out:
#
# MAE =  164.30760192871094 r2 =  0.6786038395606608 SE =  0.007057932166710625 lr =  0.01 hz =  100 dr =  0.6
# MAE =  163.71983947753907 r2 =  0.6919300226449163 SE =  0.007801314978479671 lr =  0.001 hz =  100 dr =  0.6
# MAE =  178.72272338867188 r2 =  0.5374556174062453 SE =  0.0013842268398891655 lr =  0.0001 hz =  100 dr =  0.6
# MAE =  162.4137725830078 r2 =  0.6815175611669326 SE =  0.0074732455209348975 lr =  0.01 hz =  110 dr =  0.6
# MAE =  162.9256103515625 r2 =  0.6948060570088666 SE =  0.007582250720770031 lr =  0.001 hz =  110 dr =  0.6
# MAE =  178.48673095703126 r2 =  0.537144243627309 SE =  0.0014350959005666394 lr =  0.0001 hz =  110 dr =  0.6
# MAE =  164.78412475585938 r2 =  0.6920784499882513 SE =  0.007685271617820867 lr =  0.01 hz =  120 dr =  0.6
# MAE =  164.09113464355468 r2 =  0.6936164622565457 SE =  0.007508074329645278 lr =  0.001 hz =  120 dr =  0.6
# MAE =  178.3236083984375 r2 =  0.5311335374207798 SE =  0.0014562561940588143 lr =  0.0001 hz =  120 dr =  0.6
# MAE =  161.559912109375 r2 =  0.6904108407860767 SE =  0.007916708069700363 lr =  0.01 hz =  130 dr =  0.6
# MAE =  163.6830627441406 r2 =  0.691763259148006 SE =  0.007389453774626962 lr =  0.001 hz =  130 dr =  0.6
# MAE =  177.3781311035156 r2 =  0.5228816982239209 SE =  0.00151161291654699 lr =  0.0001 hz =  130 dr =  0.6
# MAE =  163.1356964111328 r2 =  0.6799726907786707 SE =  0.0073096580937522995 lr =  0.01 hz =  140 dr =  0.6
# MAE =  162.08834228515624 r2 =  0.7020411586689617 SE =  0.0076357742753223375 lr =  0.001 hz =  140 dr =  0.6
# MAE =  177.6109619140625 r2 =  0.5372640531758979 SE =  0.001566320397336176 lr =  0.0001 hz =  140 dr =  0.6
# --- 14430.852492809296 seconds ---

# %%
class Flatten(torch.nn.Module):
    def forward(self, x):
        return x.view(x.size()[0], -1)

class Swish(torch.autograd.Function):
    @staticmethod
    def forward(ctx, i):
        result = i * torch.sigmoid(i)
        ctx.save_for_backward(i)
        return result

    @staticmethod
    def backward(ctx, grad_output):
        i = ctx.saved_tensors[0]
        sigmoid_i = torch.sigmoid(i)
        return grad_output * (sigmoid_i * (1 + i * (1 - sigmoid_i)))
    
class SwishM(nn.Module):
    def forward(self, input_tensor):
        return Swish.apply(input_tensor)
        
def create_neural_modules(embedding_size, num_numerical_cols, output_size, hidden_size, dropout):
    all_layers = []
    num_categorical_cols = sum((nf for ni, nf in embedding_size))
    input_size = num_categorical_cols + num_numerical_cols
    all_layers.append(nn.Linear(input_size, hidden_size))
    all_layers.append(nn.LeakyReLU())
    all_layers.append(nn.BatchNorm1d(hidden_size))
    all_layers.append(nn.Dropout(dropout))

    all_layers.append(nn.Linear(hidden_size, hidden_size))
    all_layers.append(nn.LeakyReLU())
    all_layers.append(nn.BatchNorm1d(hidden_size))
    all_layers.append(nn.Dropout(dropout))

    all_layers.append(nn.Linear(hidden_size, hidden_size))
    all_layers.append(nn.LeakyReLU())
    all_layers.append(nn.BatchNorm1d(hidden_size))
    all_layers.append(nn.Dropout(dropout))

    all_layers.append(nn.Linear(hidden_size, output_size))
    all_layers.append(nn.ReLU())

    return nn.Sequential(*all_layers)

class Sentinel_net(nn.Module):

    def __init__(self, embedding_size, num_numerical_cols, output_size, dropout, hidden_size):
        super(Sentinel_net, self).__init__()
        self.layers = create_neural_modules(embedding_size, num_numerical_cols, output_size, hidden_size, dropout)
        self.all_embeddings = nn.ModuleList([nn.Embedding(ni, nf) for ni, nf in embedding_size])
        self.embedding_dropout = nn.Dropout(dropout)
        self.batch_norm_num = nn.BatchNorm1d(num_numerical_cols)

    def forward(self, x_categorical, x_numerical):

        embeddings = []
        for i, e in enumerate(self.all_embeddings):
            embeddings.append(e(x_categorical[:, i]))
        y = torch.cat(embeddings, 1)
        y = self.embedding_dropout(y)
        x_numerical = self.batch_norm_num(x_numerical)
        y = torch.cat([y, x_numerical], 1)
        y = self.layers(y)

        return y

# %%
start_time = time.time()
learning = [0.01, 0.001, 0.0001] 
best_score_k_fold = sys.maxsize

print('3 Layers Architecture')

for dropout in range(0,7):
    dropout = round(dropout*.1, 2) 
    for hidden_size in range(50, 150, 10):
        for lr in learning: 

            scores, r_values, std_errors = [], [], []
            cv = KFold(n_splits=5, random_state=42, shuffle=True)
            foldc = 1
            for train_index, test_index in cv.split(sentinel_frame, None):
                #print('Fold ', foldc, end =" ") 
                train, test  = sentinel_frame.iloc[train_index], sentinel_frame.iloc[test_index]

                train_c_t = get_categorical_tensor(train, categorical_columns).cuda()
                test_c_t = get_categorical_tensor(test, categorical_columns).cuda()
                train_n_t = get_numerical_tensor(train, numerical_columns).cuda()
                test_n_t = get_numerical_tensor(test, numerical_columns).cuda()

                outputs_train = torch.tensor(train['TOTAL'].values).flatten().type(torch.FloatTensor).cuda()
                outputs_test = torch.tensor(test['TOTAL'].values).flatten().type(torch.FloatTensor).cuda()

                best_fold_score, best_r_value, best_std_error = train_shallow_net(train_c_t,test_c_t,train_n_t,test_n_t,outputs_train,outputs_test, dropout, hidden_size, lr)
                scores.append(best_fold_score)
                r_values.append(best_r_value)
                std_errors.append(best_std_error)
                foldc += 1
            #print(scores)
            current_score = sum(scores) / len(scores)
            print('MAE = ', current_score ,'r2 = ', sum(r_values) / len(r_values) ,'SE = ', sum(std_errors) / len(std_errors),'lr = ', lr,'hz = ', hidden_size, 'dr = ', dropout )
            if current_score < best_score_k_fold:
                best_score_k_fold = current_score
                print('Best so far', best_score_k_fold)
                print('')


print("--- %s seconds ---" % (time.time() - start_time))

# %%
class Flatten(torch.nn.Module):
    def forward(self, x):
        return x.view(x.size()[0], -1)

class Swish(torch.autograd.Function):
    @staticmethod
    def forward(ctx, i):
        result = i * torch.sigmoid(i)
        ctx.save_for_backward(i)
        return result

    @staticmethod
    def backward(ctx, grad_output):
        i = ctx.saved_tensors[0]
        sigmoid_i = torch.sigmoid(i)
        return grad_output * (sigmoid_i * (1 + i * (1 - sigmoid_i)))
    
class SwishM(nn.Module):
    def forward(self, input_tensor):
        return Swish.apply(input_tensor)
        
def create_neural_modules(embedding_size, num_numerical_cols, output_size, hidden_size, dropout):
    all_layers = []
    num_categorical_cols = sum((nf for ni, nf in embedding_size))
    input_size = num_categorical_cols + num_numerical_cols
    all_layers.append(nn.Linear(input_size, hidden_size))
    all_layers.append(nn.LeakyReLU())
    all_layers.append(nn.BatchNorm1d(hidden_size))
    all_layers.append(nn.Dropout(dropout))

    all_layers.append(nn.Linear(hidden_size, hidden_size))
    all_layers.append(nn.LeakyReLU())
    all_layers.append(nn.BatchNorm1d(hidden_size))
    all_layers.append(nn.Dropout(dropout))

    all_layers.append(nn.Linear(hidden_size, hidden_size))
    all_layers.append(nn.LeakyReLU())
    all_layers.append(nn.BatchNorm1d(hidden_size))
    all_layers.append(nn.Dropout(dropout))
    
    all_layers.append(nn.Linear(hidden_size, hidden_size))
    all_layers.append(nn.LeakyReLU())
    all_layers.append(nn.BatchNorm1d(hidden_size))
    all_layers.append(nn.Dropout(dropout))

    all_layers.append(nn.Linear(hidden_size, output_size))
    all_layers.append(nn.ReLU())

    return nn.Sequential(*all_layers)

class Sentinel_net(nn.Module):

    def __init__(self, embedding_size, num_numerical_cols, output_size, dropout, hidden_size):
        super(Sentinel_net, self).__init__()
        self.layers = create_neural_modules(embedding_size, num_numerical_cols, output_size, hidden_size, dropout)
        self.all_embeddings = nn.ModuleList([nn.Embedding(ni, nf) for ni, nf in embedding_size])
        self.embedding_dropout = nn.Dropout(dropout)
        self.batch_norm_num = nn.BatchNorm1d(num_numerical_cols)

    def forward(self, x_categorical, x_numerical):

        embeddings = []
        for i, e in enumerate(self.all_embeddings):
            embeddings.append(e(x_categorical[:, i]))
        y = torch.cat(embeddings, 1)
        y = self.embedding_dropout(y)
        x_numerical = self.batch_norm_num(x_numerical)
        y = torch.cat([y, x_numerical], 1)
        y = self.layers(y)

        return y

# %%
start_time = time.time()
learning = [0.01, 0.001, 0.0001] 
best_score_k_fold = sys.maxsize

print('4 Layers Architecture')

for dropout in range(0,7):
    dropout = round(dropout*.1, 2) 
    for hidden_size in range(50, 150, 10):
        for lr in learning: 

            scores, r_values, std_errors = [], [], []
            cv = KFold(n_splits=5, random_state=42, shuffle=True)
            foldc = 1
            for train_index, test_index in cv.split(sentinel_frame, None):
                #print('Fold ', foldc, end =" ") 
                train, test  = sentinel_frame.iloc[train_index], sentinel_frame.iloc[test_index]

                train_c_t = get_categorical_tensor(train, categorical_columns).cuda()
                test_c_t = get_categorical_tensor(test, categorical_columns).cuda()
                train_n_t = get_numerical_tensor(train, numerical_columns).cuda()
                test_n_t = get_numerical_tensor(test, numerical_columns).cuda()

                outputs_train = torch.tensor(train['TOTAL'].values).flatten().type(torch.FloatTensor).cuda()
                outputs_test = torch.tensor(test['TOTAL'].values).flatten().type(torch.FloatTensor).cuda()

                best_fold_score, best_r_value, best_std_error = train_shallow_net(train_c_t,test_c_t,train_n_t,test_n_t,outputs_train,outputs_test, dropout, hidden_size, lr)
                scores.append(best_fold_score)
                r_values.append(best_r_value)
                std_errors.append(best_std_error)
                foldc += 1
            #print(scores)
            current_score = sum(scores) / len(scores)
            print('MAE = ', current_score ,'r2 = ', sum(r_values) / len(r_values) ,'SE = ', sum(std_errors) / len(std_errors),'lr = ', lr,'hz = ', hidden_size, 'dr = ', dropout )
            if current_score < best_score_k_fold:
                best_score_k_fold = current_score
                print('Best so far', best_score_k_fold)
                print('')


print("--- %s seconds ---" % (time.time() - start_time))

# %%
categorical_columns = ['summary14']
numerical_columns = ['temperatureLowTime5', 'apparentTemperatureHighTime5', 'apparentTemperatureLow5', 'apparentTemperatureLowTime5']

# %%
sentinel_frame = pd.read_csv('/content/drive/My Drive/Colab/Mosquito_Berkeley/Approach2/original_mosquito_weather_semi_clean.csv')

sentinel_frame["TRAPSET"]= pd.to_datetime(sentinel_frame["TRAPSET"])
sentinel_frame["TRAPCOLLECT"]= pd.to_datetime(sentinel_frame["TRAPCOLLECT"])
sentinel_frame["DIFF_DAYS"] = (sentinel_frame["TRAPCOLLECT"] - sentinel_frame["TRAPSET"]).dt.days
sentinel_frame["TRAPSET"]= sentinel_frame["TRAPSET"].dt.week
sentinel_frame["TRAPCOLLECT"]= sentinel_frame["TRAPCOLLECT"].dt.week

for category in categorical_columns:
    sentinel_frame[category] = sentinel_frame[category].astype('category')

categorical_column_sizes = [len(sentinel_frame[column].cat.categories) for column in categorical_columns]
categorical_embedding_sizes = [(col_size, min(50, (col_size+1)//2)) for col_size in categorical_column_sizes]

for col in numerical_columns:
    sentinel_frame[col] = (sentinel_frame[col] - sentinel_frame[col].mean()) / (sentinel_frame[col].max() - sentinel_frame[col].min())
    
def get_categorical_tensor(in_frame, categories):
    categorical_data = np.stack([in_frame[col].cat.codes.values for col in categories], 1)
    categorical_data = torch.tensor(categorical_data, dtype=torch.int64)

    return categorical_data

def get_numerical_tensor(in_frame, numerical_columns):
    numerical_data = np.stack([in_frame[col].values for col in numerical_columns], 1)
    numerical_data = torch.tensor(numerical_data, dtype=torch.float)
    return numerical_data

# %%
start_time = time.time()
learning = [0.01, 0.001, 0.0001] 
best_score_k_fold = sys.maxsize

print('4 Layers Architecture')

for dropout in range(2,7):
    dropout = round(dropout*.1, 2) 
    for hidden_size in range(100, 150, 10):
        for lr in learning: 

            scores, r_values, std_errors = [], [], []
            cv = KFold(n_splits=5, random_state=42, shuffle=True)
            foldc = 1
            for train_index, test_index in cv.split(sentinel_frame, None):
                #print('Fold ', foldc, end =" ") 
                train, test  = sentinel_frame.iloc[train_index], sentinel_frame.iloc[test_index]

                train_c_t = get_categorical_tensor(train, categorical_columns).cuda()
                test_c_t = get_categorical_tensor(test, categorical_columns).cuda()
                train_n_t = get_numerical_tensor(train, numerical_columns).cuda()
                test_n_t = get_numerical_tensor(test, numerical_columns).cuda()

                outputs_train = torch.tensor(train['TOTAL'].values).flatten().type(torch.FloatTensor).cuda()
                outputs_test = torch.tensor(test['TOTAL'].values).flatten().type(torch.FloatTensor).cuda()

# ---> 92                 square_avg.mul_(alpha).addcmul_(1 - alpha, grad, grad)
#      93
#      94                 if group['centered']:
#
# KeyboardInterrupt:

# %%
categorical_columns = ['summary14']
numerical_columns = ['uvIndex12', 'apparentTemperatureHighTime5', 'apparentTemperatureLow5', 'apparentTemperatureLowTime5',
                     'dewPoint5', 'humidity5', 'apparentTemperatureHigh5', 'temperatureLow5', 'sunriseTime5']

# %%
sentinel_frame = pd.read_csv('/content/drive/My Drive/Colab/Mosquito_Berkeley/Approach2/original_mosquito_weather_semi_clean.csv')

sentinel_frame["TRAPSET"]= pd.to_datetime(sentinel_frame["TRAPSET"])
sentinel_frame["TRAPCOLLECT"]= pd.to_datetime(sentinel_frame["TRAPCOLLECT"])
sentinel_frame["DIFF_DAYS"] = (sentinel_frame["TRAPCOLLECT"] - sentinel_frame["TRAPSET"]).dt.days
sentinel_frame["TRAPSET"]= sentinel_frame["TRAPSET"].dt.week
sentinel_frame["TRAPCOLLECT"]= sentinel_frame["TRAPCOLLECT"].dt.week

for category in categorical_columns:
    sentinel_frame[category] = sentinel_frame[category].astype('category')

categorical_column_sizes = [len(sentinel_frame[column].cat.categories) for column in categorical_columns]
categorical_embedding_sizes = [(col_size, min(50, (col_size+1)//2)) for col_size in categorical_column_sizes]

for col in numerical_columns:
    sentinel_frame[col] = (sentinel_frame[col] - sentinel_frame[col].mean()) / (sentinel_frame[col].max() - sentinel_frame[col].min())
    
def get_categorical_tensor(in_frame, categories):
    categorical_data = np.stack([in_frame[col].cat.codes.values for col in categories], 1)
    categorical_data = torch.tensor(categorical_data, dtype=torch.int64)

    return categorical_data

def get_numerical_tensor(in_frame, numerical_columns):
    numerical_data = np.stack([in_frame[col].values for col in numerical_columns], 1)
    numerical_data = torch.tensor(numerical_data, dtype=torch.float)
    return numerical_data

# %%
start_time = time.time()
learning = [0.01, 0.001, 0.0001] 
best_score_k_fold = sys.maxsize

print('4 Layers Architecture')

for dropout in range(2,7):
    dropout = round(dropout*.1, 2) 
    for hidden_size in range(100, 150, 10):
        for lr in learning: 

            scores, r_values, std_errors = [], [], []
            cv = KFold(n_splits=5, random_state=42, shuffle=True)
            foldc = 1
            for train_index, test_index in cv.split(sentinel_frame, None):
                #print('Fold ', foldc, end =" ") 
                train, test  = sentinel_frame.iloc[train_index], sentinel_frame.iloc[test_index]

                train_c_t = get_categorical_tensor(train, categorical_columns).cuda()
                test_c_t = get_categorical_tensor(test, categorical_columns).cuda()
                train_n_t = get_numerical_tensor(train, numerical_columns).cuda()
                test_n_t = get_numerical_tensor(test, numerical_columns).cuda()

                outputs_train = torch.tensor(train['TOTAL'].values).flatten().type(torch.FloatTensor).cuda()
                outputs_test = torch.tensor(test['TOTAL'].values).flatten().type(torch.FloatTensor).cuda()

                best_fold_score, best_r_value, best_std_error = train_shallow_net(train_c_t,test_c_t,train_n_t,test_n_t,outputs_train,outputs_test, dropout, hidden_size, lr)
                scores.append(best_fold_score)
                r_values.append(best_r_value)
                std_errors.append(best_std_error)
                foldc += 1
            #print(scores)
            current_score = sum(scores) / len(scores)
            print('MAE = ', current_score ,'r2 = ', sum(r_values) / len(r_values) ,'SE = ', sum(std_errors) / len(std_errors),'lr = ', lr,'hz = ', hidden_size, 'dr = ', dropout )
            if current_score < best_score_k_fold:
                best_score_k_fold = current_score
                print('Best so far', best_score_k_fold)
                print('')


print("--- %s seconds ---" % (time.time() - start_time))
# Out:
#
# MAE =  11.029851150512695 r2 =  0.19678216404427035 SE =  0.009232629430743124 lr =  0.01 hz =  130 dr =  0.6
# MAE =  11.73517303466797 r2 =  0.2386992746661684 SE =  0.012334846524572216 lr =  0.001 hz =  130 dr =  0.6
# MAE =  11.52035732269287 r2 =  0.15557874631514815 SE =  0.007088560565776182 lr =  0.0001 hz =  130 dr =  0.6
# MAE =  10.946706581115723 r2 =  0.23561996782516736 SE =  0.012428876569212714 lr =  0.01 hz =  140 dr =  0.6
# MAE =  11.631863021850586 r2 =  0.2503214681424709 SE =  0.014187816823762509 lr =  0.001 hz =  140 dr =  0.6
# MAE =  11.710348510742188 r2 =  0.10909531149495318 SE =  0.006326435005061204 lr =  0.0001 hz =  140 dr =  0.6
# --- 2416.2690646648407 seconds ---

# %%
categorical_columns = ['TRAPTYPE', 'ATTRACTANTSUSED', 'SETTIMEOFDAY', 'COLLECTTIMEOFDAY', 'GENUS', 'SPECIES', 'TRAPID','TRAPSITE']
numerical_columns = ['LATITUDE', 'LONGITUDE', 'TRAPSET', 'YEAR','TRAPCOLLECT','TRAPSET','TRAPCOLLECT', 'DIFF_DAYS','TOTAL']

weather_columns = ['sunriseTime', 'sunsetTime', 'moonPhase', 
                     'precipIntensity', 'precipIntensityMax', 'precipProbability', 'temperatureHigh', 'temperatureHighTime',
                     'temperatureLow', 'temperatureLowTime', 'apparentTemperatureHigh', 'apparentTemperatureHighTime',
                     'apparentTemperatureLow', 'apparentTemperatureLowTime', 'dewPoint', 'humidity', 'pressure', 'windSpeed', 'windGust', 
                     'windGustTime', 'windBearing', 'cloudCover', 'uvIndex', 'uvIndexTime','visibility', 'temperatureMin',
                     'temperatureMinTime', 'temperatureMax', 'temperatureMaxTime', 'apparentTemperatureMin','apparentTemperatureMinTime', 'apparentTemperatureMax',
                     'apparentTemperatureMaxTime','time']

for i in range(1,15):
    for item in weather_columns:
        numerical_columns.append(item + str(i))

print(numerical_columns)
# Out:
# ['LATITUDE', 'LONGITUDE', 'TRAPSET', 'YEAR', 'TRAPCOLLECT', 'TRAPSET', 'TRAPCOLLECT', 'DIFF_DAYS', 'TOTAL', 'sunriseTime1', 'sunsetTime1', 'moonPhase1', 'precipIntensity1', 'precipIntensityMax1', 'precipProbability1', 'temperatureHigh1', 'temperatureHighTime1', 'temperatureLow1', 'temperatureLowTime1', 'apparentTemperatureHigh1', 'apparentTemperatureHighTime1', 'apparentTemperatureLow1', 'apparentTemperatureLowTime1', 'dewPoint1', 'humidity1', 'pressure1', 'windSpeed1', 'windGust1', 'windGustTime1', 'windBearing1', 'cloudCover1', 'uvIndex1', 'uvIndexTime1', 'visibility1', 'temperatureMin1', 'temperatureMinTime1', 'temperatureMax1', 'temperatureMaxTime1', 'apparentTemperatureMin1', 'apparentTemperatureMinTime1', 'apparentTemperatureMax1', 'apparentTemperatureMaxTime1', 'time1', 'sunriseTime2', 'sunsetTime2', 'moonPhase2', 'precipIntensity2', 'precipIntensityMax2', 'precipProbability2', 'temperatureHigh2', 'temperatureHighTime2', 'temperatureLow2', 'temperatureLowTime2', 'apparentTemperatureHigh2', 'apparentTemperatureHighTime2', 'apparentTemperatureLow2', 'apparentTemperatureLowTime2', 'dewPoint2', 'humidity2', 'pressure2', 'windSpeed2', 'windGust2', 'windGustTime2', 'windBearing2', 'cloudCover2', 'uvIndex2', 'uvIndexTime2', 'visibility2', 'temperatureMin2', 'temperatureMinTime2', 'temperatureMax2', 'temperatureMaxTime2', 'apparentTemperatureMin2', 'apparentTemperatureMinTime2', 'apparentTemperatureMax2', 'apparentTemperatureMaxTime2', 'time2', 'sunriseTime3', 'sunsetTime3', 'moonPhase3', 'precipIntensity3', 'precipIntensityMax3', 'precipProbability3', 'temperatureHigh3', 'temperatureHighTime3', 'temperatureLow3', 'temperatureLowTime3', 'apparentTemperatureHigh3', 'apparentTemperatureHighTime3', 'apparentTemperatureLow3', 'apparentTemperatureLowTime3', 'dewPoint3', 'humidity3', 'pressure3', 'windSpeed3', 'windGust3', 'windGustTime3', 'windBearing3', 'cloudCover3', 'uvIndex3', 'uvIndexTime3', 'visibility3', 'temperatureMin3', 'temperatureMinTime3', 'temperatureMax3', 'temperatureMaxTime3', 'apparentTemperatureMin3', 'apparentTemperatureMinTime3', 'apparentTemperatureMax3', 'apparentTemperatureMaxTime3', 'time3', 'sunriseTime4', 'sunsetTime4', 'moonPhase4', 'precipIntensity4', 'precipIntensityMax4', 'precipProbability4', 'temperatureHigh4', 'temperatureHighTime4', 'temperatureLow4', 'temperatureLowTime4', 'apparentTemperatureHigh4', 'apparentTemperatureHighTime4', 'apparentTemperatureLow4', 'apparentTemperatureLowTime4', 'dewPoint4', 'humidity4', 'pressure4', 'windSpeed4', 'windGust4', 'windGustTime4', 'windBearing4', 'cloudCover4', 'uvIndex4', 'uvIndexTime4', 'visibility4', 'temperatureMin4', 'temperatureMinTime4', 'temperatureMax4', 'temperatureMaxTime4', 'apparentTemperatureMin4', 'apparentTemperatureMinTime4', 'apparentTemperatureMax4', 'apparentTemperatureMaxTime4', 'time4', 'sunriseTime5', 'sunsetTime5', 'moonPhase5', 'precipIntensity5', 'precipIntensityMax5', 'precipProbability5', 'temperatureHigh5', 'temperatureHighTime5', 'temperatureLow5', 'temperatureLowTime5', 'apparentTemperatureHigh5', 'apparentTemperatureHighTime5', 'apparentTemperatureLow5', 'apparentTemperatureLowTime5', 'dewPoint5', 'humidity5', 'pressure5', 'windSpeed5', 'windGust5', 'windGustTime5', 'windBearing5', 'cloudCover5', 'uvIndex5', 'uvIndexTime5', 'visibility5', 'temperatureMin5', 'temperatureMinTime5', 'temperatureMax5', 'temperatureMaxTime5', 'apparentTemperatureMin5', 'apparentTemperatureMinTime5', 'apparentTemperatureMax5', 'apparentTemperatureMaxTime5', 'time5', 'sunriseTime6', 'sunsetTime6', 'moonPhase6', 'precipIntensity6', 'precipIntensityMax6', 'precipProbability6', 'temperatureHigh6', 'temperatureHighTime6', 'temperatureLow6', 'temperatureLowTime6', 'apparentTemperatureHigh6', 'apparentTemperatureHighTime6', 'apparentTemperatureLow6', 'apparentTemperatureLowTime6', 'dewPoint6', 'humidity6', 'pressure6', 'windSpeed6', 'windGust6', 'windGustTime6', 'windBearing6', 'cloudCover6', 'uvIndex6', 'uvIndexTime6', 'visibility6', 'temperatureMin6', 't ...

# %%
from sklearn.datasets import load_boston
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE
from sklearn.linear_model import RidgeCV, LassoCV, Ridge, Lasso

sentinel_frame = pd.read_csv('/content/drive/My Drive/Colab/Mosquito_Berkeley/Approach2/original_mosquito_weather_semi_clean.csv')
sentinel_frame["TRAPSET"]= pd.to_datetime(sentinel_frame["TRAPSET"])
sentinel_frame["TRAPCOLLECT"]= pd.to_datetime(sentinel_frame["TRAPCOLLECT"])
sentinel_frame["DIFF_DAYS"] = (sentinel_frame["TRAPCOLLECT"] - sentinel_frame["TRAPSET"]).dt.days
sentinel_frame["TRAPSET"]= sentinel_frame["TRAPSET"].dt.week
sentinel_frame["TRAPCOLLECT"]= sentinel_frame["TRAPCOLLECT"].dt.week

for category in categorical_columns:
    sentinel_frame[category] = sentinel_frame[category].astype('category')

categorical_column_sizes = [len(sentinel_frame[column].cat.categories) for column in categorical_columns]
categorical_embedding_sizes = [(col_size, min(50, (col_size+1)//2)) for col_size in categorical_column_sizes]

#Using Pearson Correlation
cor = sentinel_frame.corr(method='spearman')


for col in numerical_columns:
    sentinel_frame[col] = (sentinel_frame[col] - sentinel_frame[col].mean()) / (sentinel_frame[col].max() - sentinel_frame[col].min())
    
def get_categorical_tensor(in_frame, categories):
    categorical_data = np.stack([in_frame[col].cat.codes.values for col in categories], 1)
    categorical_data = torch.tensor(categorical_data, dtype=torch.int64)

    return categorical_data

def get_numerical_tensor(in_frame, numerical_columns):
    numerical_data = np.stack([in_frame[col].values for col in numerical_columns], 1)
    numerical_data = torch.tensor(numerical_data, dtype=torch.float)
    return numerical_data

# %%
cor = sentinel_frame.corr(method='spearman')

x = cor["TOTAL"].sort_values(ascending=False)
pd.set_option('display.max_rows', len(x))

print(x)
# Out:
# TOTAL                            1.000000
# uvIndex12                        0.171735
# uvIndex5                         0.132725
# uvIndex6                         0.128913
# uvIndex10                        0.113827
# uvIndex14                        0.109167
# uvIndex13                        0.107372
# uvIndex11                        0.105819
# temperatureMax12                 0.099281
# temperatureHigh12                0.098960
# temperatureHigh13                0.098953
# temperatureMax13                 0.098278
# precipIntensity13                0.093832
# apparentTemperatureHigh13        0.092073
# uvIndex4                         0.091778
# uvIndex9                         0.090533
# apparentTemperatureMax13         0.089983
# temperatureLow12                 0.087704
# uvIndex2                         0.086321
# DIFF_DAYS                        0.086045
# windBearing14                    0.085944
# apparentTemperatureLow12         0.084777
# temperatureMin13                 0.080017
# apparentTemperatureMin13         0.078204
# windBearing13                    0.077274
# apparentTemperatureHigh12        0.069991
# apparentTemperatureMax12         0.069865
# windBearing6                     0.066330
# precipIntensityMax13             0.064291
# uvIndex7                         0.063487
# temperatureMax11                 0.058387
# temperatureHigh11                0.058226
# windBearing5                     0.054006
# temperatureHigh10                0.050953
# temperatureMax10                 0.050952
# uvIndex3                         0.049408
# uvIndex8                         0.048134
# pressure10                       0.045882
# temperatureMax14                 0.045325
# temperatureHigh14                0.044913
# moonPhase2                       0.042825
# windGust14                       0.042264
# temperatureMin11                 0.042103
# uvIndex1                         0.041520
# moonPhase3                       0.041394
# windGust4                        0.040299
# temperatureMin14                 0.040065
# windBearing12                    0.038848
# apparentTemperatureMin14         0.038275
# temperatureLow10                 0.037870
# apparentTemperatureMin11         0.037764
# temperatureMin12                 0.037403
# temperatureLow13                 0.036686
# temperatureLow11                 0.035857
# apparentTemperatureLow13         0.035041
# apparentTemperatureMin12         0.034288
# apparentTemperatureLow10         0.033201
# windGust13                       0.033180
# apparentTemperatureLow11         0.032957
# windGust3                        0.032374
# apparentTemperatureHigh11        0.031694
# apparentTemperatureMax11         0.031600
# moonPhase8                       0.031238
# windBearing4                     0.029880
# apparentTemperatureMax10         0.029277
# apparentTemperatureHigh10        0.029208
# windBearing2                     0.028908
# moonPhase1                       0.027719
# LATITUDE                         0.026432
# temperatureLow14                 0.025209
# windGust12                       0.025091
# temperatureHigh6                 0.024585
# apparentTemperatureHigh14        0.024288
# windSpeed13                      0.024279
# temperatureMax6                  0.024135
# apparentTemperatureMax14         0.024116
# pressure9                        0.023994
# apparentTemperatureLow14         0.023462
# windBearing7                     0.022870
# dewPoint13                       0.022156
# temperatureHigh9                 0.022017
# temperatureMax9                  0.020911
# windSpeed3                       0.019957
# moonPhase7                       0.019944
# cloudCover8                      0.019473
# temperatureHigh1                 0.019097
# windGust7                        0.018894
# moonPhase6                       0.018843
# pressure3                        0.018378
# temperatureMax2                  0.017701
# windBearing11                    0.017516
# temperatureMax1                  0.016575
# windGust6                        0.015945
# temperatureHigh5                 0.014736
# temperatureHigh2                 0.014581
# temperatureMin10                 0.014575
# temperatureMax5                  0.013936
# moonPhase14                      0.013552
# temperatureMin2                  0.011721
# windBearing9                     0.011274
# apparentTemperatureMin10         0.010833
# apparentTemperatureHigh9         0.009782
# apparentTemperatureMin2          0.009611
# temperatureHigh8                 0.008818
# apparentTemperatureMax9          0.008122
# precipIntensityMax8              0.007924
# temperatureMin9                  0.007771
# windGust10                       0.007311
# temperatureLow9                  0.007260
# apparentTemperatureMin9          0.007189
# precipProbability8               0.006595
# temperatureMax8                  0.006111
# moonPhase4                       0.004805
# temperatureHigh4                 0.004776
# temperatureLow1                  0.004752
# windSpeed10                      0.004457
# windSpeed14                      0.004098
# apparentTemperatureLow1          0.003958
# apparentTemperatureHigh6         0.003905
# temperatureMax3                  0.003876
# cloudCover3                      0.003685
# pressure11                       0.002997
# temperatureMax4                  0.002963
# apparentTemperatureMax6          0.002420
# windSpeed4                       0.002160
# apparentTemperatureLow9          0.002043
# moonPhase9                       0.001880
# apparentTemperatureHigh1         0.001316
# windSpeed6                       0.000898
# precipIntensityMax3              0.000880
# apparentTemperatureMin6          0.000242
# pressure2                        0.000237
# temperatureMin6                  0.000097
# precipProbability4              -0.000167
# apparentTemperatureMax2         -0.000446
# cloudCover1                     -0.000546
# temperatureLow5                 -0.000664
# moonPhase10                     -0.000912
# apparentTemperatureLow5         -0.000932
# apparentTemperatureMax1         -0.001199
# pressure8                       -0.001714
# apparentTemperatureHigh8        -0.001731
# apparentTemperatureHigh2        -0.001907
# temperatureHigh3                -0.002053
# apparentTemperatureLow8         -0.002079
# moonPhase13                     -0.003027
# temperatureLow8                 -0.003247
# apparentTemperatureMin8         -0.003590
# precipIntensityMax5             -0.003767
# windGust1                       -0.003936
# windBearing10                   -0.004188
# apparentTemperatureMax8         -0.004263
# windSpeed8                      -0.004308
# temperatureMax7                 -0.004437
# windSpeed5                      -0.004579
# windGust11                      -0.005030
# temperatureMin8                 -0.005194
# apparentTemperatureLow7         -0.005243
# temperatureLow3                 -0.005305
# dewPoint12                      -0.005476
# temperatureHigh7                -0.005508
# precipProbability3              -0.005765
# windSpeed7                      -0.005827
# precipIntensity3                -0.005850
# moonPhase5                      -0.005918
# apparentTemperatureHigh5        -0.006163
# apparentTemperatureMax5         -0.006914
# temperatureLow7                 -0.006989
# apparentTemperatureLow3         -0.007586
# precipIntensity6                -0.007929
# temperatureMin4                 -0.008356
# windBearing1                    -0.008812
# windSpeed11                     -0.008885
# apparentTemperatureHigh4        -0.008945
# windGust8                       -0.009148
# apparentTemperatureMax3         -0.010103
# pressure7                       -0.010240
# apparentTemperatureMax4         -0.010434
# cloudCover7                     -0.010500
# precipIntensity5                -0.010571
# apparentTemperatureMin4         -0.010929
# windSpeed1                      -0.011140
# windSpeed12                     -0.012013
# windSpeed9                      -0.012459
# windGust5                       -0.012699
# temperatureLow2                 -0.013491
# precipProbability13             -0.013670
# apparentTemperatureHigh3        -0.015040
# temperatureMin3                 -0.015216
# windBearing3                    -0.015501
# precipIntensityMax6             -0.016734
# precipIntensityMax1             -0.016861
# temperatureLow4                 -0.017947
# cloudCover2                     -0.017991
# cloudCover9                     -0.018346
# apparentTemperatureLow2         -0.018921
# windSpeed2                      -0.019409
# precipIntensity8                -0.019612
# apparentTemperatureMin3         -0.019807
# apparentTemperatureLow4         -0.020046
# moonPhase12                     -0.020187
# precipIntensity1                -0.020380
# apparentTemperatureMin1         -0.020475
# temperatureMin5                 -0.021278
# dewPoint11                      -0.021326
# dewPoint1                       -0.021399
# dewPoint9                       -0.021552
# cloudCover4                     -0.021712
# dewPoint10                      -0.022122
# windGust9                       -0.022190
# temperatureMin1                 -0.023267
# dewPoint14                      -0.023409
# apparentTemperatureMin5         -0.023528
# pressure4                       -0.023855
# precipProbability14             -0.024042
# precipProbability5              -0.024182
# dewPoint8                       -0.024959
# cloudCover10                    -0.026534
# precipIntensityMax12            -0.026747
# apparentTemperatureMin7         -0.026757
# temperatureMin7                 -0.026807
# cloudCover11                    -0.026843
# dewPoint2                       -0.026847
# precipIntensity12               -0.026878
# apparentTemperatureMax7         -0.027141
# apparentTemperatureHigh7        -0.027368
# apparentTemperatureLow6         -0.028361
# temperatureLow6                 -0.028365
# pressure1                       -0.028413
# precipIntensityMax9             -0.028724
# windGust2                       -0.029342
# moonPhase11                     -0.032465
# precipProbability9              -0.033866
# dewPoint3                       -0.035698
# precipIntensityMax2             -0.037923
# precipIntensity7                -0.038604
# precipIntensityMax14            -0.038923
# precipIntensity4                -0.039054
# precipProbability1              -0.039697
# precipIntensityMax7             -0.039774
# visibility6                     -0.040732
# windBearing8                    -0.042641
# humidity1                       -0.043700
# cloudCover5                     -0.043949
# cloudCover13                    -0.044407
# precipProbability6              -0.045041
# precipIntensity14               -0.045521
# precipProbability11             -0.046253
# dewPoint4                       -0.046316
# humidity8                       -0.046548
# visibility1                     -0.048318
# precipProbability2              -0.048454
# precipProbability7              -0.048961
# YEAR                            -0.050582
# visibility2                     -0.051732
# precipIntensity11               -0.051758
# precipIntensity2                -0.051774
# precipIntensityMax4             -0.051925
# precipIntensity10               -0.052051
# precipIntensity9                -0.052987
# dewPoint5                       -0.054408
# cloudCover14                    -0.054913
# visibility5                     -0.055351
# precipIntensityMax11            -0.056155
# visibility14                    -0.057333
# visibility13                    -0.058052
# visibility10                    -0.058531
# precipIntensityMax10            -0.058710
# humidity3                       -0.059418
# dewPoint7                       -0.060187
# dewPoint6                       -0.060603
# pressure5                       -0.061739
# cloudCover6                     -0.063272
# precipProbability12             -0.065427
# precipProbability10             -0.067086
# pressure6                       -0.068326
# visibility7                     -0.069083
# apparentTemperatureMinTime13    -0.069294
# temperatureMinTime13            -0.069298
# apparentTemperatureMinTime6     -0.069330
# apparentTemperatureMaxTime1     -0.069333
# windGustTime8                   -0.069335
# apparentTemperatureMaxTime11    -0.069335
# temperatureMaxTime10            -0.069336
# windGustTime1                   -0.069337
# apparentTemperatureMaxTime8     -0.069339
# temperatureMaxTime11            -0.069340
# temperatureMinTime4             -0.069340
# apparentTemperatureMinTime4     -0.069340
# apparentTemperatureMaxTime4     -0.069342
# temperatureHighTime10           -0.069343
# apparentTemperatureMaxTime10    -0.069344
# windGustTime10                  -0.069344
# apparentTemperatureMaxTime9     -0.069345
# temperatureMaxTime4             -0.069345
# temperatureMinTime6             -0.069345
# temperatureMaxTime1             -0.069346
# windGustTime7                   -0.069347
# apparentTemperatureHighTime1    -0.069347
# windGustTime14                  -0.069347
# apparentTemperatureLowTime13    -0.069347
# temperatureMaxTime9             -0.069348
# apparentTemperatureMaxTime5     -0.069348
# apparentTemperatureHighTime10   -0.069348
# temperatureMaxTime8             -0.069348
# temperatureLowTime13            -0.069348
# apparentTemperatureHighTime8    -0.069349
# sunsetTime14                    -0.069349
# sunsetTime13                    -0.069350
# sunsetTime12                    -0.069350
# sunsetTime11                    -0.069350
# apparentTemperatureHighTime9    -0.069350
# sunsetTime10                    -0.069350
# sunsetTime9                     -0.069351
# sunsetTime8                     -0.069351
# sunsetTime7                     -0.069351
# uvIndexTime2                    -0.069351
# temperatureHighTime9            -0.069351
# apparentTemperatureMaxTime12    -0.069352
# apparentTemperatureHighTime5    -0.069352
# sunsetTime6                     -0.069352
# sunsetTime5                     -0.069352
# sunsetTime4                     -0.069352
# sunsetTime3                     -0.069352
# uvIndexTime1                    -0.069353
# temperatureMaxTime5             -0.069353
# sunsetTime2                     -0.069353
# sunsetTime1                     -0.069353
# apparentTemperatureHighTime11   -0.069354
# temperatureMaxTime12            -0.069354
# windGustTime12                  -0.069354
# uvIndexTime9                    -0.069355
# uvIndexTime10                   -0.069356
# apparentTemperatureMaxTime13    -0.069356
# temperatureMinTime3             -0.069356
# temperatureHighTime11           -0.069356
# apparentTemperatureMinTime3     -0.069356
# apparentTemperatureHighTime4    -0.069357
# temperatureLowTime1             -0.069358
# temperatureHighTime8            -0.069358
# apparentTemperatureLowTime1     -0.069358
# apparentTemperatureMaxTime6     -0.069358
# temperatureHighTime1            -0.069358
# uvIndexTime7                    -0.069359
# uvIndexTime8                    -0.069359
# windGustTime13                  -0.069359
# temperatureHighTime4            -0.069359
# uvIndexTime3                    -0.069359
# apparentTemperatureLowTime9     -0.069360
# temperatureLowTime9             -0.069360
# windGustTime4                   -0.069361
# apparentTemperatureHighTime12   -0.069361
# temperatureMaxTime6             -0.069361
# apparentTemperatureLowTime5     -0.069361
# windGustTime3                   -0.069362
# apparentTemperatureLowTime2     -0.069362
# uvIndexTime14                   -0.069362
# temperatureLowTime12            -0.069362
# apparentTemperatureLowTime7     -0.069362
# temperatureHighTime6            -0.069362
# temperatureHighTime5            -0.069362
# time11                          -0.069362
# time12                          -0.069362
# time3                           -0.069362
# time1                           -0.069362
# time13                          -0.069362
# time2                           -0.069362
# time14                          -0.069362
# time10                          -0.069362
# time8                           -0.069362
# time6                           -0.069362
# time5                           -0.069362
# time9                           -0.069362
# time7                           -0.069362
# time4                           -0.069362
# temperatureLowTime6             -0.069363
# uvIndexTime5                    -0.069363
# temperatureLowTime2             -0.069363
# apparentTemperatureMinTime2     -0.069363
# temperatureLowTime5             -0.069363
# apparentTemperatureMinTime14    -0.069363
# apparentTemperatureLowTime6     -0.069363
# temperatureLowTime7             -0.069363
# apparentTemperatureHighTime6    -0.069363
# apparentTemperatureLowTime11    -0.069363
# temperatureHighTime12           -0.069363
# uvIndexTime13                   -0.069363
# apparentTemperatureLowTime12    -0.069364
# temperatureMinTime14            -0.069364
# temperatureLowTime11            -0.069364
# temperatureLowTime14            -0.069364
# apparentTemperatureMinTime8     -0.069364
# temperatureHighTime2            -0.069364
# uvIndexTime11                   -0.069365
# apparentTemperatureMaxTime2     -0.069365
# apparentTemperatureLowTime14    -0.069365
# apparentTemperatureLowTime8     -0.069365
# apparentTemperatureMinTime5     -0.069365
# uvIndexTime6                    -0.069365
# temperatureLowTime8             -0.069366
# apparentTemperatureHighTime2    -0.069366
# uvIndexTime4                    -0.069366
# apparentTemperatureHighTime3    -0.069367
# windGustTime5                   -0.069367
# temperatureMinTime8             -0.069367
# temperatureHighTime14           -0.069367
# temperatureHighTime3            -0.069368
# temperatureHighTime7            -0.069368
# apparentTemperatureHighTime14   -0.069368
# temperatureMaxTime14            -0.069369
# apparentTemperatureMaxTime14    -0.069369
# temperatureMaxTime2             -0.069370
# uvIndexTime12                   -0.069370
# temperatureMaxTime13            -0.069370
# temperatureLowTime3             -0.069370
# temperatureMaxTime7             -0.069370
# apparentTemperatureLowTime4     -0.069370
# apparentTemperatureHighTime7    -0.069371
# apparentTemperatureLowTime3     -0.069371
# windGustTime2                   -0.069371
# windGustTime11                  -0.069371
# sunriseTime1                    -0.069372
# apparentTemperatureMinTime12    -0.069372
# sunriseTime2                    -0.069372
# sunriseTime3                    -0.069372
# sunriseTime4                    -0.069372
# sunriseTime5                    -0.069372
# sunriseTime6                    -0.069372
# apparentTemperatureHighTime13   -0.069372
# sunriseTime7                    -0.069373
# sunriseTime8                    -0.069373
# sunriseTime9                    -0.069373
# sunriseTime10                   -0.069373
# sunriseTime11                   -0.069373
# sunriseTime12                   -0.069373
# temperatureLowTime4             -0.069373
# sunriseTime13                   -0.069373
# sunriseTime14                   -0.069373
# windGustTime6                   -0.069374
# apparentTemperatureMaxTime7     -0.069374
# temperatureLowTime10            -0.069375
# apparentTemperatureLowTime10    -0.069375
# temperatureMinTime5             -0.069377
# temperatureHighTime13           -0.069377
# apparentTemperatureMinTime1     -0.069379
# apparentTemperatureMinTime11    -0.069379
# temperatureMinTime11            -0.069379
# temperatureMinTime1             -0.069379
# apparentTemperatureMaxTime3     -0.069381
# temperatureMaxTime3             -0.069383
# temperatureMinTime2             -0.069389
# temperatureMinTime12            -0.069389
# temperatureMinTime7             -0.069389
# apparentTemperatureMinTime7     -0.069390
# apparentTemperatureMinTime10    -0.069397
# temperatureMinTime10            -0.069397
# windGustTime9                   -0.069397
# apparentTemperatureMinTime9     -0.069404
# temperatureMinTime9             -0.069424
# humidity4                       -0.069903
# humidity9                       -0.070688
# visibility11                    -0.074880
# LONGITUDE                       -0.075739
# visibility12                    -0.076183
# pressure12                      -0.078293
# visibility3                     -0.079858
# humidity2                       -0.080573
# visibility9                     -0.081274
# cloudCover12                    -0.082945
# visibility8                     -0.085895
# visibility4                     -0.095690
# humidity5                       -0.096306
# humidity10                      -0.097845
# humidity7                       -0.098761
# humidity13                      -0.099768
# pressure14                      -0.107131
# humidity11                      -0.111332
# TRAPCOLLECT                     -0.121963
# TRAPSET                         -0.121963
# TRAPCOLLECT                     -0.121963
# TRAPSET                         -0.121963
# humidity14                      -0.126383
# humidity12                      -0.128479
# humidity6                       -0.139156
# pressure13                      -0.144033
# Name: TOTAL, dtype: float64

# %%
x = cor["TOTAL"].sort_values(ascending=False)
pd.set_option('display.max_rows', len(x))

print(x)
# Out:
# TOTAL                            1.000000
# DIFF_DAYS                        0.149163
# uvIndex13                        0.089484
# uvIndex5                         0.085399
# uvIndex12                        0.084473
# OBJECTID                         0.076821
# uvIndex6                         0.062301
# uvIndex9                         0.061502
# windBearing4                     0.059807
# uvIndex11                        0.055301
# windBearing5                     0.053272
# uvIndex14                        0.053087
# uvIndex4                         0.051399
# temperatureHigh13                0.050853
# temperatureMax13                 0.050343
# windBearing13                    0.049621
# uvIndex10                        0.048761
# uvIndex2                         0.043029
# apparentTemperatureHigh13        0.041406
# pressure10                       0.041327
# cloudCover8                      0.040797
# apparentTemperatureMax13         0.039625
# moonPhase14                      0.033368
# windBearing6                     0.030774
# moonPhase10                      0.029718
# uvIndex3                         0.027724
# windBearing12                    0.026004
# temperatureMax12                 0.025768
# uvIndex7                         0.025173
# temperatureHigh12                0.025002
# uvIndex1                         0.022099
# moonPhase2                       0.021128
# windBearing11                    0.021114
# temperatureLow12                 0.019378
# cloudCover7                      0.019137
# precipProbability4               0.018774
# moonPhase13                      0.018554
# moonPhase3                       0.017683
# LONGITUDE                        0.017647
# X                                0.017647
# moonPhase12                      0.017448
# apparentTemperatureLow12         0.016881
# apparentTemperatureMax12         0.016819
# apparentTemperatureHigh12        0.016612
# pressure9                        0.016072
# temperatureMin13                 0.015739
# temperatureHigh14                0.015490
# temperatureMax14                 0.015182
# windGust6                        0.015075
# precipIntensityMax4              0.015005
# apparentTemperatureMin13         0.014579
# precipProbability8               0.013230
# temperatureHigh10                0.012005
# temperatureMax10                 0.011598
# cloudCover1                      0.010998
# moonPhase9                       0.010883
# humidity8                        0.010263
# windGust4                        0.009452
# moonPhase1                       0.009251
# windGust5                        0.008202
# precipIntensity4                 0.007345
# apparentTemperatureHigh14        0.006168
# apparentTemperatureMax14         0.005750
# moonPhase11                      0.005270
# windGust3                        0.003781
# cloudCover4                      0.003708
# temperatureLow14                 0.002834
# temperatureMin10                 0.002196
# uvIndex8                         0.002102
# humidity1                        0.001912
# cloudCover10                     0.001854
# apparentTemperatureLow14         0.001420
# precipIntensityMax8              0.000610
# temperatureLow11                 0.000387
# cloudCover11                    -0.000015
# windBearing2                    -0.000108
# cloudCover9                     -0.000131
# windBearing14                   -0.000245
# cloudCover3                     -0.000499
# apparentTemperatureMin10        -0.001216
# apparentTemperatureLow11        -0.001228
# moonPhase8                      -0.001231
# windSpeed4                      -0.001370
# precipIntensity8                -0.001499
# windGust11                      -0.001703
# windBearing9                    -0.002198
# precipIntensityMax12            -0.002203
# apparentTemperatureMax10        -0.002599
# moonPhase7                      -0.002701
# windBearing3                    -0.002776
# apparentTemperatureHigh10       -0.003032
# apparentTemperatureMin14        -0.003262
# temperatureMin14                -0.003266
# cloudCover2                     -0.003408
# temperatureHigh11               -0.003607
# temperatureMax11                -0.003614
# pressure8                       -0.003723
# temperatureMax2                 -0.003848
# Y                               -0.004742
# LATITUDE                        -0.004742
# temperatureHigh2                -0.005023
# cloudCover12                    -0.005349
# pressure7                       -0.005629
# temperatureMin12                -0.005775
# temperatureLow13                -0.006228
# apparentTemperatureLow13        -0.006465
# pressure11                      -0.006572
# apparentTemperatureMin12        -0.006715
# temperatureLow9                 -0.007745
# temperatureMax9                 -0.007840
# apparentTemperatureHigh9        -0.007965
# moonPhase6                      -0.008021
# apparentTemperatureMax9         -0.008106
# temperatureHigh9                -0.008116
# windGust14                      -0.008386
# temperatureLow10                -0.008933
# windBearing10                   -0.009589
# apparentTemperatureLow10        -0.009959
# apparentTemperatureLow9         -0.010355
# temperatureHigh5                -0.010558
# temperatureMax5                 -0.011179
# windGust10                      -0.011661
# apparentTemperatureMax2         -0.011819
# temperatureMin11                -0.012051
# apparentTemperatureHigh2        -0.012547
# temperatureMin9                 -0.013185
# windGust13                      -0.013477
# apparentTemperatureMin9         -0.013723
# temperatureMax3                 -0.014056
# pressure3                       -0.014182
# visibility5                     -0.014645
# precipProbability1              -0.014895
# windGust2                       -0.015262
# apparentTemperatureMin11        -0.015343
# precipIntensity3                -0.015752
# windSpeed11                     -0.015903
# temperatureHigh3                -0.016230
# visibility6                     -0.016435
# pressure2                       -0.017225
# apparentTemperatureMax11        -0.017439
# dewPoint14                      -0.017569
# windGust12                      -0.017620
# apparentTemperatureHigh11       -0.018063
# temperatureHigh1                -0.018680
# windBearing7                    -0.018730
# visibility10                    -0.018997
# dewPoint13                      -0.019697
# precipProbability12             -0.019742
# windGust7                       -0.019794
# precipIntensity12               -0.019842
# moonPhase4                      -0.020012
# cloudCover14                    -0.020119
# temperatureMax1                 -0.020189
# windSpeed5                      -0.020340
# windGust9                       -0.020519
# precipIntensityMax11            -0.020614
# apparentTemperatureHigh5        -0.021670
# precipIntensityMax1             -0.022149
# windSpeed3                      -0.022214
# temperatureLow8                 -0.022269
# apparentTemperatureMax5         -0.022502
# cloudCover5                     -0.022514
# precipProbability3              -0.022878
# precipIntensityMax3             -0.023106
# apparentTemperatureLow8         -0.023170
# temperatureLow1                 -0.023305
# apparentTemperatureHigh1        -0.023471
# precipProbability11             -0.023555
# precipIntensityMax5             -0.023685
# apparentTemperatureMax3         -0.024126
# cloudCover13                    -0.024198
# dewPoint12                      -0.024521
# apparentTemperatureMax1         -0.025111
# windBearing1                    -0.025265
# apparentTemperatureLow1         -0.025281
# temperatureMin2                 -0.025424
# precipIntensityMax6             -0.025625
# temperatureHigh4                -0.025771
# temperatureMax4                 -0.026020
# windGust8                       -0.026833
# apparentTemperatureMin2         -0.027229
# dewPoint9                       -0.027478
# apparentTemperatureHigh3        -0.027670
# windSpeed6                      -0.027908
# precipIntensity5                -0.028428
# precipProbability7              -0.028435
# temperatureLow2                 -0.028609
# precipIntensity1                -0.029229
# temperatureLow3                 -0.029250
# precipProbability6              -0.029566
# moonPhase5                      -0.029677
# apparentTemperatureLow3         -0.029752
# cloudCover6                     -0.029892
# apparentTemperatureHigh8        -0.029991
# temperatureHigh6                -0.030084
# temperatureMax6                 -0.030266
# humidity9                       -0.030353
# precipIntensityMax2             -0.030792
# apparentTemperatureMax8         -0.030940
# apparentTemperatureLow2         -0.031230
# humidity2                       -0.031281
# dewPoint1                       -0.031718
# windGust1                       -0.032038
# precipProbability2              -0.032060
# temperatureLow4                 -0.032128
# precipIntensity11               -0.032221
# visibility3                     -0.032247
# temperatureMin3                 -0.032278
# windSpeed10                     -0.032351
# precipIntensity13               -0.032452
# dewPoint2                       -0.032708
# precipIntensityMax13            -0.033453
# apparentTemperatureMax4         -0.033615
# precipIntensity6                -0.033772
# apparentTemperatureHigh4        -0.033909
# precipProbability14             -0.033948
# apparentTemperatureLow4         -0.034054
# temperatureMin4                 -0.034508
# apparentTemperatureMin3         -0.034820
# dewPoint8                       -0.034897
# humidity3                       -0.034987
# precipIntensityMax9             -0.035346
# humidity11                      -0.036049
# dewPoint10                      -0.036745
# visibility2                     -0.036777
# windSpeed12                     -0.037326
# apparentTemperatureMin4         -0.037423
# pressure4                       -0.037629
# temperatureHigh8                -0.037696
# visibility9                     -0.037773
# visibility4                     -0.037776
# humidity4                       -0.038091
# temperatureMax8                 -0.038555
# pressure1                       -0.038557
# precipProbability5              -0.038601
# precipIntensity2                -0.039398
# windSpeed9                      -0.039465
# temperatureLow5                 -0.040032
# temperatureMin6                 -0.040551
# precipIntensityMax14            -0.041978
# temperatureMin5                 -0.042034
# apparentTemperatureMin6         -0.042056
# windSpeed13                     -0.042107
# apparentTemperatureLow5         -0.042342
# humidity7                       -0.042804
# windSpeed2                      -0.043027
# visibility13                    -0.043162
# precipProbability9              -0.043171
# precipProbability13             -0.043196
# apparentTemperatureMin1         -0.043708
# precipIntensity14               -0.044349
# apparentTemperatureMin5         -0.044384
# windSpeed14                     -0.044651
# precipIntensity7                -0.045043
# temperatureMin1                 -0.045077
# precipIntensityMax7             -0.045452
# apparentTemperatureMin8         -0.045782
# apparentTemperatureHigh6        -0.045968
# apparentTemperatureMax6         -0.046135
# dewPoint11                      -0.046170
# dewPoint3                       -0.046331
# temperatureMin8                 -0.046429
# visibility14                    -0.046816
# windBearing8                    -0.046849
# apparentTemperatureLow7         -0.047929
# pressure6                       -0.048343
# humidity12                      -0.048428
# temperatureLow7                 -0.048448
# visibility1                     -0.049322
# precipIntensity9                -0.050623
# visibility7                     -0.051130
# humidity14                      -0.051398
# windSpeed8                      -0.051602
# visibility8                     -0.051888
# humidity10                      -0.051971
# windSpeed7                      -0.056039
# visibility11                    -0.056544
# temperatureMax7                 -0.057499
# temperatureHigh7                -0.058220
# pressure5                       -0.058612
# dewPoint4                       -0.059380
# visibility12                    -0.060331
# pressure14                      -0.060425
# windSpeed1                      -0.065257
# apparentTemperatureMax7         -0.067926
# dewPoint5                       -0.068553
# apparentTemperatureHigh7        -0.068709
# precipIntensityMax10            -0.069029
# precipProbability10             -0.070057
# pressure12                      -0.072683
# precipIntensity10               -0.073286
# humidity13                      -0.074977
# apparentTemperatureLow6         -0.075024
# temperatureLow6                 -0.075134
# humidity5                       -0.077477
# apparentTemperatureMin7         -0.078279
# temperatureMin7                 -0.078612
# dewPoint7                       -0.081263
# pressure13                      -0.082887
# dewPoint6                       -0.087868
# humidity6                       -0.093106
# TRAPCOLLECT                     -0.097486
# TRAPSET                         -0.097486
# precipIntensityMaxTime1         -0.130371
# YEAR                            -0.138450
# apparentTemperatureHighTime1    -0.148195
# apparentTemperatureHighTime11   -0.148246
# apparentTemperatureMaxTime1     -0.148270
# temperatureHighTime11           -0.148296
# temperatureLowTime13            -0.148313
# temperatureMinTime2             -0.148322
# temperatureHighTime1            -0.148323
# apparentTemperatureLowTime13    -0.148325
# apparentTemperatureMaxTime5     -0.148340
# temperatureMinTime14            -0.148358
# apparentTemperatureMaxTime11    -0.148365
# apparentTemperatureLowTime2     -0.148369
# apparentTemperatureMinTime14    -0.148374
# temperatureLowTime2             -0.148391
# temperatureMaxTime10            -0.148401
# apparentTemperatureHighTime5    -0.148405
# temperatureMaxTime1             -0.148411
# temperatureHighTime10           -0.148423
# temperatureHighTime7            -0.148428
# temperatureMaxTime11            -0.148428
# temperatureMaxTime7             -0.148432
# apparentTemperatureMinTime2     -0.148460
# apparentTemperatureMaxTime3     -0.148467
# temperatureMaxTime3             -0.148468
# temperatureMinTime9             -0.148472
# apparentTemperatureMinTime9     -0.148475
# apparentTemperatureLowTime1     -0.148477
# windGustTime8                   -0.148478
# apparentTemperatureHighTime3    -0.148479
# temperatureHighTime3            -0.148490
# temperatureMaxTime14            -0.148498
# temperatureHighTime14           -0.148502
# uvIndexTime5                    -0.148511
# temperatureMaxTime6             -0.148518
# temperatureHighTime6            -0.148522
# windGustTime3                   -0.148534
# temperatureHighTime9            -0.148534
# windGustTime1                   -0.148538
# apparentTemperatureHighTime9    -0.148544
# windGustTime2                   -0.148548
# apparentTemperatureMinTime3     -0.148552
# apparentTemperatureMaxTime10    -0.148555
# temperatureMaxTime9             -0.148561
# uvIndexTime7                    -0.148563
# apparentTemperatureHighTime12   -0.148569
# temperatureLowTime14            -0.148571
# apparentTemperatureMaxTime14    -0.148574
# apparentTemperatureHighTime14   -0.148579
# apparentTemperatureHighTime4    -0.148582
# apparentTemperatureMaxTime12    -0.148584
# temperatureLowTime1             -0.148584
# temperatureLowTime6             -0.148585
# apparentTemperatureHighTime10   -0.148596
# temperatureMinTime12            -0.148598
# temperatureMinTime7             -0.148599
# temperatureMinTime3             -0.148600
# uvIndexTime6                    -0.148607
# temperatureHighTime2            -0.148608
# uvIndexTime3                    -0.148613
# temperatureMinTime5             -0.148614
# temperatureHighTime12           -0.148615
# uvIndexTime1                    -0.148616
# temperatureMaxTime12            -0.148626
# Unnamed: 0                      -0.148629
# apparentTemperatureMaxTime9     -0.148630
# apparentTemperatureLowTime8     -0.148632
# apparentTemperatureHighTime8    -0.148637
# temperatureMaxTime2             -0.148640
# apparentTemperatureMaxTime8     -0.148640
# apparentTemperatureMaxTime4     -0.148645
# apparentTemperatureLowTime4     -0.148650
# temperatureLowTime4             -0.148662
# apparentTemperatureMinTime12    -0.148663
# uvIndexTime14                   -0.148672
# apparentTemperatureMinTime5     -0.148677
# apparentTemperatureLowTime6     -0.148698
# apparentTemperatureMinTime7     -0.148710
# apparentTemperatureLowTime7     -0.148720
# temperatureLowTime3             -0.148720
# apparentTemperatureHighTime6    -0.148725
# windGustTime6                   -0.148729
# uvIndexTime8                    -0.148731
# temperatureLowTime11            -0.148733
# windGustTime12                  -0.148736
# temperatureLowTime8             -0.148737
# apparentTemperatureHighTime7    -0.148738
# apparentTemperatureMaxTime7     -0.148742
# uvIndexTime4                    -0.148746
# temperatureMaxTime4             -0.148747
# apparentTemperatureMaxTime6     -0.148751
# temperatureLowTime7             -0.148755
# temperatureLowTime9             -0.148756
# uvIndexTime13                   -0.148759
# temperatureMinTime4             -0.148762
# uvIndexTime12                   -0.148763
# temperatureHighTime4            -0.148769
# apparentTemperatureLowTime11    -0.148772
# windGustTime7                   -0.148774
# apparentTemperatureHighTime2    -0.148776
# temperatureHighTime13           -0.148778
# windGustTime14                  -0.148799
# temperatureMaxTime13            -0.148800
# apparentTemperatureLowTime14    -0.148803
# apparentTemperatureLowTime3     -0.148811
# temperatureMinTime10            -0.148816
# apparentTemperatureLowTime9     -0.148816
# apparentTemperatureHighTime13   -0.148822
# uvIndexTime2                    -0.148827
# uvIndexTime9                    -0.148845
# apparentTemperatureMaxTime13    -0.148860
# temperatureHighTime5            -0.148862
# temperatureMaxTime8             -0.148863
# uvIndexTime10                   -0.148864
# apparentTemperatureMinTime10    -0.148866
# temperatureMinTime6             -0.148870
# temperatureHighTime8            -0.148872
# apparentTemperatureMinTime4     -0.148876
# apparentTemperatureMinTime6     -0.148883
# temperatureLowTime5             -0.148889
# windGustTime9                   -0.148893
# temperatureMaxTime5             -0.148897
# windGustTime5                   -0.148904
# apparentTemperatureLowTime5     -0.148905
# windGustTime10                  -0.148914
# windGustTime11                  -0.148921
# apparentTemperatureMaxTime2     -0.148928
# temperatureMinTime1             -0.148932
# apparentTemperatureMinTime1     -0.148950
# temperatureMinTime8             -0.148955
# apparentTemperatureMinTime8     -0.148958
# temperatureLowTime12            -0.148959
# apparentTemperatureLowTime10    -0.148963
# windGustTime4                   -0.148966
# apparentTemperatureMinTime11    -0.148983
# windGustTime13                  -0.149056
# uvIndexTime11                   -0.149058
# temperatureMinTime11            -0.149066
# apparentTemperatureLowTime12    -0.149095
# temperatureLowTime10            -0.149099
# temperatureMinTime13            -0.149108
# apparentTemperatureMinTime13    -0.149205
# sunriseTime1                    -0.149224
# sunriseTime9                    -0.149292
# sunriseTime7                    -0.149308
# sunsetTime13                    -0.149314
# sunriseTime2                    -0.149319
# sunriseTime14                   -0.149350
# sunsetTime12                    -0.149369
# sunriseTime3                    -0.149381
# sunsetTime9                     -0.149386
# sunriseTime10                   -0.149391
# time6                           -0.149391
# time5                           -0.149391
# time13                          -0.149391
# time14                          -0.149391
# time9                           -0.149391
# time4                           -0.149391
# time12                          -0.149391
# time10                          -0.149391
# time8                           -0.149391
# time2                           -0.149391
# time11                          -0.149391
# time3                           -0.149391
# time7                           -0.149391
# time1                           -0.149391
# sunriseTime6                    -0.149398
# sunriseTime8                    -0.149408
# sunsetTime10                    -0.149408
# sunriseTime11                   -0.149411
# sunsetTime5                     -0.149416
# sunriseTime4                    -0.149423
# sunriseTime5                    -0.149470
# sunsetTime8                     -0.149474
# sunsetTime2                     -0.149482
# sunsetTime11                    -0.149501
# sunsetTime14                    -0.149505
# sunsetTime3                     -0.149524
# sunsetTime7                     -0.149552
# sunriseTime13                   -0.149554
# sunsetTime6                     -0.149575
# sunsetTime4                     -0.149588
# sunsetTime1                     -0.149614
# sunriseTime12                   -0.149649
# precipIntensityMaxTime14        -0.150438
# precipIntensityMaxTime12        -0.157578
# Name: TOTAL, dtype: float64

# %%
x = cor["TOTAL"].sort_values(ascending=False)
pd.set_option('display.max_rows', len(x))

print(x)
# Out:
# TOTAL                            1.000000
# DIFF_DAYS                        0.176961
# uvIndex13                        0.121731
# uvIndex5                         0.114633
# uvIndex12                        0.114129
# OBJECTID                         0.112038
# windBearing4                     0.087695
# uvIndex6                         0.083453
# uvIndex9                         0.083335
# windBearing5                     0.078345
# uvIndex11                        0.075434
# temperatureHigh13                0.074827
# temperatureMax13                 0.074152
# windBearing13                    0.073341
# uvIndex14                        0.071498
# uvIndex4                         0.069487
# uvIndex10                        0.065802
# apparentTemperatureHigh13        0.059992
# cloudCover8                      0.059768
# pressure10                       0.058898
# uvIndex2                         0.058653
# apparentTemperatureMax13         0.057539
# moonPhase14                      0.047603
# windBearing6                     0.046151
# moonPhase10                      0.042402
# windBearing12                    0.038513
# uvIndex3                         0.037469
# temperatureMax12                 0.037040
# temperatureHigh12                0.036009
# uvIndex7                         0.034460
# windBearing11                    0.030508
# uvIndex1                         0.030121
# moonPhase2                       0.030120
# temperatureLow12                 0.028370
# cloudCover7                      0.027862
# precipProbability4               0.026568
# moonPhase13                      0.026239
# moonPhase3                       0.025265
# moonPhase12                      0.024676
# X                                0.024667
# LONGITUDE                        0.024667
# apparentTemperatureLow12         0.024661
# temperatureMin13                 0.023719
# apparentTemperatureMax12         0.023467
# pressure9                        0.023420
# apparentTemperatureHigh12        0.023186
# temperatureHigh14                0.023042
# temperatureMax14                 0.022715
# apparentTemperatureMin13         0.021909
# precipIntensityMax4              0.021797
# windGust6                        0.020818
# precipProbability8               0.018274
# temperatureHigh10                0.017719
# temperatureMax10                 0.017135
# cloudCover1                      0.016596
# moonPhase9                       0.015292
# humidity8                        0.014348
# windGust4                        0.014151
# moonPhase1                       0.012954
# windGust5                        0.011876
# precipIntensity4                 0.010549
# apparentTemperatureHigh14        0.009542
# apparentTemperatureMax14         0.009083
# moonPhase11                      0.007157
# windGust3                        0.005749
# cloudCover4                      0.005399
# temperatureLow14                 0.003848
# humidity1                        0.003408
# cloudCover10                     0.003244
# temperatureMin10                 0.003197
# uvIndex8                         0.002896
# apparentTemperatureLow14         0.001850
# cloudCover9                      0.000845
# precipIntensityMax8              0.000436
# temperatureLow11                 0.000246
# windBearing2                     0.000152
# windBearing14                    0.000005
# cloudCover3                     -0.000669
# cloudCover11                    -0.000810
# apparentTemperatureLow11        -0.001893
# apparentTemperatureMin10        -0.001923
# moonPhase8                      -0.002100
# windSpeed4                      -0.002106
# precipIntensity8                -0.002502
# windGust11                      -0.002654
# windBearing9                    -0.003614
# apparentTemperatureMax10        -0.003790
# windBearing3                    -0.004000
# precipIntensityMax12            -0.004175
# moonPhase7                      -0.004278
# apparentTemperatureHigh10       -0.004553
# cloudCover2                     -0.004712
# temperatureMin14                -0.004853
# apparentTemperatureMin14        -0.004859
# pressure8                       -0.005249
# temperatureMax2                 -0.005692
# temperatureHigh11               -0.006092
# temperatureMax11                -0.006186
# LATITUDE                        -0.007296
# Y                               -0.007296
# temperatureHigh2                -0.007504
# cloudCover12                    -0.007626
# temperatureMin12                -0.008681
# pressure7                       -0.008723
# temperatureLow13                -0.009223
# pressure11                      -0.009533
# apparentTemperatureLow13        -0.009603
# apparentTemperatureMin12        -0.010006
# temperatureLow9                 -0.011024
# moonPhase6                      -0.011825
# windGust14                      -0.012721
# temperatureMax9                 -0.012893
# apparentTemperatureMax9         -0.012926
# apparentTemperatureHigh9        -0.012991
# temperatureHigh9                -0.013387
# temperatureLow10                -0.013866
# apparentTemperatureLow9         -0.014872
# windBearing10                   -0.015320
# apparentTemperatureLow10        -0.015504
# temperatureHigh5                -0.015814
# temperatureMax5                 -0.016704
# windGust10                      -0.016974
# apparentTemperatureMax2         -0.017191
# apparentTemperatureHigh2        -0.018385
# temperatureMin11                -0.018744
# temperatureMin9                 -0.019022
# temperatureMax3                 -0.019749
# windGust13                      -0.019981
# apparentTemperatureMin9         -0.019984
# pressure3                       -0.020296
# visibility5                     -0.020933
# precipProbability1              -0.021099
# precipIntensity3                -0.021289
# windGust2                       -0.022017
# temperatureHigh3                -0.022903
# apparentTemperatureMin11        -0.023751
# visibility6                     -0.023769
# windSpeed11                     -0.023845
# dewPoint14                      -0.024954
# pressure2                       -0.025191
# windGust12                      -0.025536
# windBearing7                    -0.026725
# temperatureHigh1                -0.027069
# visibility10                    -0.027349
# apparentTemperatureMax11        -0.027432
# precipProbability12             -0.028010
# cloudCover14                    -0.028246
# apparentTemperatureHigh11       -0.028362
# dewPoint13                      -0.028641
# precipIntensity12               -0.028696
# precipIntensityMax11            -0.028981
# moonPhase4                      -0.029101
# temperatureMax1                 -0.029155
# windGust7                       -0.029382
# windSpeed5                      -0.029398
# windGust9                       -0.029418
# precipProbability3              -0.031125
# precipIntensityMax1             -0.031290
# apparentTemperatureHigh5        -0.031398
# precipIntensityMax3             -0.031787
# windSpeed3                      -0.031935
# temperatureLow8                 -0.031945
# apparentTemperatureMax5         -0.032551
# cloudCover5                     -0.032696
# precipIntensityMax5             -0.033203
# apparentTemperatureLow8         -0.033454
# temperatureLow1                 -0.033683
# precipProbability11             -0.033733
# apparentTemperatureMax3         -0.034050
# apparentTemperatureHigh1        -0.034239
# cloudCover13                    -0.034798
# dewPoint12                      -0.035515
# precipIntensityMax6             -0.036161
# temperatureMin2                 -0.036369
# windBearing1                    -0.036402
# apparentTemperatureLow1         -0.036450
# apparentTemperatureMax1         -0.036509
# temperatureHigh4                -0.037014
# temperatureMax4                 -0.037361
# precipIntensity5                -0.039103
# apparentTemperatureMin2         -0.039198
# windGust8                       -0.039289
# apparentTemperatureHigh3        -0.039395
# dewPoint9                       -0.039489
# precipIntensity1                -0.040101
# windSpeed6                      -0.040543
# precipProbability7              -0.040643
# precipProbability6              -0.041608
# temperatureLow2                 -0.041698
# temperatureLow3                 -0.042792
# moonPhase5                      -0.042956
# apparentTemperatureLow3         -0.043601
# humidity9                       -0.043633
# temperatureHigh6                -0.043711
# cloudCover6                     -0.043901
# temperatureMax6                 -0.044091
# apparentTemperatureHigh8        -0.044187
# precipIntensity13               -0.044267
# humidity2                       -0.044336
# precipIntensityMax2             -0.044396
# precipIntensity11               -0.044768
# precipProbability2              -0.045210
# apparentTemperatureLow2         -0.045342
# apparentTemperatureMax8         -0.045489
# dewPoint1                       -0.045626
# temperatureLow4                 -0.046358
# precipIntensity6                -0.046644
# windSpeed10                     -0.046652
# windGust1                       -0.046848
# visibility3                     -0.046949
# temperatureMin3                 -0.047146
# precipIntensityMax13            -0.047269
# dewPoint2                       -0.047530
# precipProbability14             -0.048435
# apparentTemperatureMax4         -0.048454
# apparentTemperatureHigh4        -0.048765
# apparentTemperatureLow4         -0.049207
# humidity3                       -0.049531
# temperatureMin4                 -0.049878
# precipIntensityMax9             -0.050034
# dewPoint8                       -0.050755
# apparentTemperatureMin3         -0.050827
# humidity11                      -0.052968
# dewPoint10                      -0.054068
# visibility4                     -0.054084
# visibility2                     -0.054167
# humidity4                       -0.054261
# apparentTemperatureMin4         -0.054301
# pressure4                       -0.054412
# precipProbability5              -0.054596
# windSpeed12                     -0.054722
# visibility9                     -0.055336
# pressure1                       -0.055373
# temperatureHigh8                -0.055475
# precipIntensity2                -0.055621
# temperatureMax8                 -0.056640
# windSpeed9                      -0.056947
# temperatureLow5                 -0.058561
# temperatureMin6                 -0.059586
# precipProbability9              -0.059930
# precipIntensityMax14            -0.060183
# windSpeed13                     -0.060721
# temperatureMin5                 -0.060977
# precipProbability13             -0.061191
# precipIntensity14               -0.061562
# humidity7                       -0.061574
# apparentTemperatureMin6         -0.061671
# apparentTemperatureLow5         -0.061760
# precipIntensity7                -0.062627
# visibility13                    -0.062678
# windSpeed2                      -0.062752
# apparentTemperatureMin1         -0.063352
# precipIntensityMax7             -0.064386
# apparentTemperatureMin5         -0.064440
# temperatureMin1                 -0.065268
# windSpeed14                     -0.065853
# apparentTemperatureHigh6        -0.066528
# visibility14                    -0.066880
# apparentTemperatureMin8         -0.066884
# apparentTemperatureMax6         -0.066938
# dewPoint11                      -0.067100
# dewPoint3                       -0.067134
# temperatureMin8                 -0.067637
# windBearing8                    -0.068603
# precipIntensity9                -0.069751
# humidity12                      -0.070229
# apparentTemperatureLow7         -0.070266
# pressure6                       -0.070329
# temperatureLow7                 -0.070936
# visibility1                     -0.071259
# humidity14                      -0.073086
# visibility7                     -0.073314
# humidity10                      -0.074214
# windSpeed8                      -0.074974
# visibility8                     -0.075469
# windSpeed7                      -0.081129
# visibility11                    -0.082297
# temperatureMax7                 -0.083891
# pressure5                       -0.084955
# temperatureHigh7                -0.085041
# dewPoint4                       -0.086539
# visibility12                    -0.087146
# pressure14                      -0.087851
# windSpeed1                      -0.095126
# precipIntensityMax10            -0.096051
# precipProbability10             -0.096917
# apparentTemperatureMax7         -0.098672
# dewPoint5                       -0.099141
# precipIntensity10               -0.099734
# apparentTemperatureHigh7        -0.099926
# pressure12                      -0.104240
# humidity13                      -0.107040
# temperatureLow6                 -0.108580
# apparentTemperatureLow6         -0.108625
# humidity5                       -0.110113
# apparentTemperatureMin7         -0.112981
# temperatureMin7                 -0.113306
# dewPoint7                       -0.118238
# pressure13                      -0.118337
# dewPoint6                       -0.126592
# humidity6                       -0.133075
# TRAPCOLLECT                     -0.141028
# TRAPSET                         -0.141028
# YEAR                            -0.171453
# precipIntensityMaxTime1         -0.187186
# temperatureMinTime2             -0.212708
# apparentTemperatureHighTime1    -0.212735
# apparentTemperatureHighTime11   -0.212755
# temperatureHighTime11           -0.212766
# temperatureLowTime13            -0.212782
# apparentTemperatureLowTime13    -0.212793
# temperatureMinTime14            -0.212807
# apparentTemperatureMaxTime1     -0.212808
# apparentTemperatureMinTime9     -0.212816
# apparentTemperatureLowTime2     -0.212821
# temperatureLowTime2             -0.212825
# apparentTemperatureMinTime14    -0.212838
# apparentTemperatureMaxTime11    -0.212845
# apparentTemperatureMinTime2     -0.212868
# temperatureMaxTime11            -0.212876
# temperatureHighTime1            -0.212883
# temperatureMaxTime10            -0.212897
# temperatureMinTime9             -0.212900
# apparentTemperatureMaxTime5     -0.212902
# apparentTemperatureMaxTime3     -0.212912
# temperatureMaxTime3             -0.212917
# uvIndexTime7                    -0.212928
# uvIndexTime5                    -0.212929
# apparentTemperatureLowTime1     -0.212938
# windGustTime8                   -0.212949
# apparentTemperatureMinTime3     -0.212953
# temperatureHighTime7            -0.212965
# windGustTime2                   -0.212966
# temperatureHighTime10           -0.212970
# uvIndexTime14                   -0.212976
# temperatureMaxTime1             -0.212978
# temperatureMaxTime7             -0.212978
# temperatureHighTime3            -0.212987
# apparentTemperatureHighTime3    -0.212988
# apparentTemperatureHighTime5    -0.212994
# temperatureMinTime3             -0.213004
# uvIndexTime1                    -0.213008
# temperatureMaxTime14            -0.213021
# temperatureLowTime1             -0.213024
# temperatureHighTime14           -0.213026
# temperatureHighTime6            -0.213050
# apparentTemperatureHighTime12   -0.213053
# apparentTemperatureMaxTime10    -0.213056
# apparentTemperatureMaxTime12    -0.213061
# temperatureMaxTime6             -0.213067
# uvIndexTime6                    -0.213075
# temperatureMinTime5             -0.213081
# uvIndexTime8                    -0.213081
# temperatureHighTime2            -0.213082
# temperatureHighTime9            -0.213083
# uvIndexTime3                    -0.213085
# temperatureMaxTime9             -0.213102
# apparentTemperatureHighTime9    -0.213106
# temperatureMaxTime2             -0.213106
# apparentTemperatureMaxTime14    -0.213125
# apparentTemperatureLowTime8     -0.213126
# apparentTemperatureHighTime4    -0.213128
# windGustTime3                   -0.213130
# apparentTemperatureHighTime14   -0.213132
# temperatureMaxTime12            -0.213143
# apparentTemperatureHighTime10   -0.213144
# temperatureLowTime14            -0.213144
# temperatureMinTime12            -0.213158
# apparentTemperatureMaxTime4     -0.213161
# temperatureHighTime12           -0.213161
# apparentTemperatureMinTime5     -0.213171
# windGustTime1                   -0.213171
# temperatureLowTime6             -0.213175
# temperatureMinTime7             -0.213190
# apparentTemperatureLowTime4     -0.213197
# sunriseTime1                    -0.213199
# apparentTemperatureMaxTime9     -0.213202
# uvIndexTime13                   -0.213222
# temperatureLowTime4             -0.213224
# apparentTemperatureMinTime12    -0.213238
# apparentTemperatureMaxTime8     -0.213243
# apparentTemperatureHighTime8    -0.213254
# temperatureMinTime4             -0.213262
# temperatureMaxTime4             -0.213280
# apparentTemperatureMinTime7     -0.213280
# apparentTemperatureLowTime6     -0.213285
# time9                           -0.213285
# time11                          -0.213285
# time14                          -0.213285
# time5                           -0.213285
# time6                           -0.213285
# time2                           -0.213285
# time7                           -0.213285
# time13                          -0.213285
# time4                           -0.213285
# time3                           -0.213285
# time10                          -0.213285
# time8                           -0.213285
# time12                          -0.213285
# time1                           -0.213285
# temperatureLowTime3             -0.213292
# windGustTime12                  -0.213295
# apparentTemperatureLowTime7     -0.213298
# temperatureLowTime8             -0.213310
# temperatureLowTime9             -0.213312
# temperatureHighTime13           -0.213316
# apparentTemperatureHighTime7    -0.213318
# sunriseTime9                    -0.213331
# apparentTemperatureMaxTime7     -0.213332
# sunriseTime7                    -0.213334
# temperatureLowTime7             -0.213334
# apparentTemperatureMinTime6     -0.213335
# temperatureMinTime10            -0.213344
# apparentTemperatureHighTime6    -0.213346
# sunriseTime2                    -0.213355
# temperatureMaxTime13            -0.213357
# uvIndexTime12                   -0.213359
# uvIndexTime4                    -0.213362
# temperatureHighTime4            -0.213369
# temperatureMinTime6             -0.213371
# windGustTime9                   -0.213373
# apparentTemperatureLowTime9     -0.213378
# temperatureLowTime11            -0.213378
# uvIndexTime10                   -0.213379
# apparentTemperatureHighTime2    -0.213385
# apparentTemperatureMaxTime6     -0.213392
# sunriseTime3                    -0.213405
# sunriseTime14                   -0.213409
# apparentTemperatureHighTime13   -0.213412
# uvIndexTime9                    -0.213422
# sunriseTime10                   -0.213423
# sunsetTime12                    -0.213425
# apparentTemperatureMinTime10    -0.213426
# apparentTemperatureLowTime5     -0.213427
# apparentTemperatureLowTime14    -0.213430
# windGustTime6                   -0.213430
# apparentTemperatureLowTime11    -0.213431
# windGustTime11                  -0.213432
# uvIndexTime2                    -0.213434
# apparentTemperatureLowTime3     -0.213434
# windGustTime5                   -0.213439
# windGustTime7                   -0.213439
# sunriseTime8                    -0.213443
# Unnamed: 0                      -0.213445
# apparentTemperatureMinTime4     -0.213451
# sunsetTime9                     -0.213465
# temperatureLowTime5             -0.213471
# sunriseTime11                   -0.213472
# apparentTemperatureMaxTime13    -0.213475
# sunsetTime13                    -0.213486
# sunriseTime4                    -0.213493
# temperatureMinTime8             -0.213510
# sunriseTime6                    -0.213511
# apparentTemperatureMaxTime2     -0.213535
# apparentTemperatureMinTime8     -0.213545
# temperatureHighTime5            -0.213548
# apparentTemperatureMinTime11    -0.213549
# sunsetTime5                     -0.213550
# temperatureMinTime1             -0.213552
# apparentTemperatureMinTime1     -0.213552
# temperatureMaxTime8             -0.213554
# windGustTime14                  -0.213558
# temperatureMaxTime5             -0.213561
# sunsetTime10                    -0.213564
# temperatureHighTime8            -0.213576
# apparentTemperatureLowTime10    -0.213578
# windGustTime4                   -0.213589
# sunriseTime5                    -0.213591
# temperatureLowTime12            -0.213597
# sunsetTime2                     -0.213610
# sunsetTime11                    -0.213618
# windGustTime10                  -0.213650
# sunsetTime8                     -0.213656
# temperatureMinTime11            -0.213665
# sunsetTime14                    -0.213674
# uvIndexTime11                   -0.213698
# sunriseTime13                   -0.213699
# temperatureMinTime13            -0.213719
# apparentTemperatureLowTime12    -0.213741
# sunsetTime7                     -0.213750
# sunsetTime3                     -0.213755
# windGustTime13                  -0.213765
# temperatureLowTime10            -0.213779
# sunriseTime12                   -0.213790
# sunsetTime1                     -0.213792
# sunsetTime6                     -0.213810
# sunsetTime4                     -0.213819
# apparentTemperatureMinTime13    -0.213837
# precipIntensityMaxTime14        -0.215804
# precipIntensityMaxTime12        -0.226061
# Name: TOTAL, dtype: float64

# %%
# categorical_columns = ['TRAPTYPE', 'ATTRACTANTSUSED', 'SETTIMEOFDAY', 'COLLECTTIMEOFDAY', 'GENUS', 'SPECIES', 'TRAPID','TRAPSITE']
# numerical_columns = ['precipIntensityMaxTime12', 'precipIntensityMaxTime14', 'apparentTemperatureMinTime13', 'sunsetTime4','sunsetTime6',
#                      'sunsetTime1','sunriseTime12','temperatureLowTime10', 'windGustTime13', 'sunsetTime3',
#                      'DIFF_DAYS', 'uvIndex13', 'uvIndex5', 'uvIndex12']

categorical_columns = ['TRAPTYPE', 'ATTRACTANTSUSED', 'SETTIMEOFDAY', 'COLLECTTIMEOFDAY', 'GENUS', 'SPECIES', 'TRAPID','TRAPSITE']
numerical_columns = ['LATITUDE', 'LONGITUDE', 'TRAPSET', 'YEAR','TRAPCOLLECT','TRAPSET','TRAPCOLLECT', 'DIFF_DAYS']

weather_columns = ['sunriseTime', 'sunsetTime', 'moonPhase', 
                     'precipIntensity', 'precipIntensityMax', 'precipProbability', 'temperatureHigh', 'temperatureHighTime',
                     'temperatureLow', 'temperatureLowTime', 'apparentTemperatureHigh', 'apparentTemperatureHighTime',
                     'apparentTemperatureLow', 'apparentTemperatureLowTime', 'dewPoint', 'humidity', 'pressure', 'windSpeed', 'windGust', 
                     'windGustTime', 'windBearing', 'cloudCover', 'uvIndex', 'uvIndexTime','visibility', 'temperatureMin',
                     'temperatureMinTime', 'temperatureMax', 'temperatureMaxTime', 'apparentTemperatureMin','apparentTemperatureMinTime', 'apparentTemperatureMax',
                     'apparentTemperatureMaxTime','time']

for i in range(1,2):
    for item in weather_columns:
        numerical_columns.append(item + str(14))

print(numerical_columns)
# Out:
# ['LATITUDE', 'LONGITUDE', 'TRAPSET', 'YEAR', 'TRAPCOLLECT', 'TRAPSET', 'TRAPCOLLECT', 'DIFF_DAYS', 'sunriseTime14', 'sunsetTime14', 'moonPhase14', 'precipIntensity14', 'precipIntensityMax14', 'precipProbability14', 'temperatureHigh14', 'temperatureHighTime14', 'temperatureLow14', 'temperatureLowTime14', 'apparentTemperatureHigh14', 'apparentTemperatureHighTime14', 'apparentTemperatureLow14', 'apparentTemperatureLowTime14', 'dewPoint14', 'humidity14', 'pressure14', 'windSpeed14', 'windGust14', 'windGustTime14', 'windBearing14', 'cloudCover14', 'uvIndex14', 'uvIndexTime14', 'visibility14', 'temperatureMin14', 'temperatureMinTime14', 'temperatureMax14', 'temperatureMaxTime14', 'apparentTemperatureMin14', 'apparentTemperatureMinTime14', 'apparentTemperatureMax14', 'apparentTemperatureMaxTime14', 'time14']

# %%
sentinel_frame = pd.read_csv('/content/drive/My Drive/Colab/Mosquito_Berkeley/Approach2/original_mosquito_weather_semi_clean.csv')

sentinel_frame["TRAPSET"]= pd.to_datetime(sentinel_frame["TRAPSET"])
sentinel_frame["TRAPCOLLECT"]= pd.to_datetime(sentinel_frame["TRAPCOLLECT"])
sentinel_frame["DIFF_DAYS"] = (sentinel_frame["TRAPCOLLECT"] - sentinel_frame["TRAPSET"]).dt.days
sentinel_frame["TRAPSET"]= sentinel_frame["TRAPSET"].dt.week
sentinel_frame["TRAPCOLLECT"]= sentinel_frame["TRAPCOLLECT"].dt.week

for category in categorical_columns:
    sentinel_frame[category] = sentinel_frame[category].astype('category')

categorical_column_sizes = [len(sentinel_frame[column].cat.categories) for column in categorical_columns]
categorical_embedding_sizes = [(col_size, min(50, (col_size+1)//2)) for col_size in categorical_column_sizes]

for col in numerical_columns:
    sentinel_frame[col] = (sentinel_frame[col] - sentinel_frame[col].mean()) / (sentinel_frame[col].max() - sentinel_frame[col].min())
    
def get_categorical_tensor(in_frame, categories):
    categorical_data = np.stack([in_frame[col].cat.codes.values for col in categories], 1)
    categorical_data = torch.tensor(categorical_data, dtype=torch.int64)

    return categorical_data

def get_numerical_tensor(in_frame, numerical_columns):
    numerical_data = np.stack([in_frame[col].values for col in numerical_columns], 1)
    numerical_data = torch.tensor(numerical_data, dtype=torch.float)
    return numerical_data

# %%
class Flatten(torch.nn.Module):
    def forward(self, x):
        return x.view(x.size()[0], -1)

class Swish(torch.autograd.Function):
    @staticmethod
    def forward(ctx, i):
        result = i * torch.sigmoid(i)
        ctx.save_for_backward(i)
        return result

    @staticmethod
    def backward(ctx, grad_output):
        i = ctx.saved_tensors[0]
        sigmoid_i = torch.sigmoid(i)
        return grad_output * (sigmoid_i * (1 + i * (1 - sigmoid_i)))
    
class SwishM(nn.Module):
    def forward(self, input_tensor):
        return Swish.apply(input_tensor)
        
def create_neural_modules(embedding_size, num_numerical_cols, output_size, hidden_size, dropout):
    all_layers = []
    num_categorical_cols = sum((nf for ni, nf in embedding_size))
    input_size = num_categorical_cols + num_numerical_cols
    all_layers.append(nn.Linear(input_size, hidden_size))
    all_layers.append(nn.LeakyReLU())
    all_layers.append(nn.BatchNorm1d(hidden_size))
    all_layers.append(nn.Dropout(dropout))

    all_layers.append(nn.Linear(hidden_size, hidden_size))
    all_layers.append(nn.LeakyReLU())
    all_layers.append(nn.BatchNorm1d(hidden_size))
    all_layers.append(nn.Dropout(dropout))

    all_layers.append(nn.Linear(hidden_size, hidden_size))
    all_layers.append(nn.LeakyReLU())
    all_layers.append(nn.BatchNorm1d(hidden_size))
    all_layers.append(nn.Dropout(dropout))

    all_layers.append(nn.Linear(hidden_size, output_size))
    all_layers.append(nn.ReLU())

    return nn.Sequential(*all_layers)

class Sentinel_net(nn.Module):

    def __init__(self, embedding_size, num_numerical_cols, output_size, dropout, hidden_size):
        super(Sentinel_net, self).__init__()
        self.layers = create_neural_modules(embedding_size, num_numerical_cols, output_size, hidden_size, dropout)
        self.all_embeddings = nn.ModuleList([nn.Embedding(ni, nf) for ni, nf in embedding_size])
        self.embedding_dropout = nn.Dropout(dropout)
        self.batch_norm_num = nn.BatchNorm1d(num_numerical_cols)

    def forward(self, x_categorical, x_numerical):

        embeddings = []
        for i, e in enumerate(self.all_embeddings):
            embeddings.append(e(x_categorical[:, i]))
        y = torch.cat(embeddings, 1)
        y = self.embedding_dropout(y)
        x_numerical = self.batch_norm_num(x_numerical)
        y = torch.cat([y, x_numerical], 1)
        y = self.layers(y)

        return y

# %%
def train_shallow_net(train_c_t,test_c_t,train_n_t,test_n_t,outputs_train,outputs_test, dropout, hidden_size, lr):
    model = Sentinel_net(categorical_embedding_sizes, train_n_t.shape[1], 1, dropout, hidden_size)
    model.train().cuda()

    criterion = torch.nn.MSELoss(reduction='mean') 
    params_dict = dict(model.named_parameters())
    params = []
    best = sys.maxsize
    r_value = 0
    std_err = 0
    
    for key, value in params_dict.items():
        if 'weight' in key and 'layers' in key:
            params += [{'params':value, 'weight_decay':4e-3}]
        else:
            params += [{'params':value, 'weight_decay':0.0}]

    optimizer = torch.optim.RMSprop(params, lr=lr, alpha=0.99, eps=1e-08, weight_decay=0, momentum=0.9, centered=False)
    epoch = 0

    for i in range(1, 1000):
        y_pred = model(train_c_t, train_n_t)
        loss = criterion(y_pred.squeeze(), outputs_train)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        model.eval()
        with torch.no_grad():
            y_pred2 = model(test_c_t, test_n_t)
            c_out, c_pred = outputs_test.cpu().detach().numpy(), y_pred2.cpu().detach().numpy().squeeze()
            current_score = mean_absolute_error(c_out, c_pred)
            if current_score < best:
                best = current_score
                m, b, r_value, p_value, std_err = stats.linregress(c_out,c_pred)

            model.train()
    
    #print('MAE = ',current_score, 'r2 = ',r_value, 'SE = ',std_err)
    return best, r_value, std_err

# %%
start_time = time.time()
learning = [0.01, 0.001, 0.0001] 
best_score_k_fold = sys.maxsize

print('4 Layers Architecture')

for dropout in range(2,7):
    dropout = round(dropout*.1, 2) 
    for hidden_size in range(100, 150, 10):
        for lr in learning:  

            scores, r_values, std_errors = [], [], []
            cv = KFold(n_splits=5, random_state=42, shuffle=True)
            foldc = 1
            for train_index, test_index in cv.split(sentinel_frame, None):
                #print('Fold ', foldc, end =" ") 
                train, test  = sentinel_frame.iloc[train_index], sentinel_frame.iloc[test_index]

                train_c_t = get_categorical_tensor(train, categorical_columns).cuda()
                test_c_t = get_categorical_tensor(test, categorical_columns).cuda()
                train_n_t = get_numerical_tensor(train, numerical_columns).cuda()
                test_n_t = get_numerical_tensor(test, numerical_columns).cuda()

                outputs_train = torch.tensor(train['TOTAL'].values).flatten().type(torch.FloatTensor).cuda()
                outputs_test = torch.tensor(test['TOTAL'].values).flatten().type(torch.FloatTensor).cuda()

                best_fold_score, best_r_value, best_std_error = train_shallow_net(train_c_t,test_c_t,train_n_t,test_n_t,outputs_train,outputs_test, dropout, hidden_size, lr)
                scores.append(best_fold_score)
                r_values.append(best_r_value)
                std_errors.append(best_std_error)
                foldc += 1
            #print(scores)
            current_score = sum(scores) / len(scores)
            print('MAE = ', current_score ,'r2 = ', sum(r_values) / len(r_values) ,'SE = ', sum(std_errors) / len(std_errors),'lr = ', lr,'hz = ', hidden_size, 'dr = ', dropout )
            if current_score < best_score_k_fold:
                best_score_k_fold = current_score
                print('Best so far', best_score_k_fold)
                print('')


print("--- %s seconds ---" % (time.time() - start_time))
# Out:
#
# MAE =  9.780894470214843 r2 =  0.5009070638110588 SE =  0.016941802376405017 lr =  0.01 hz =  140 dr =  0.6
# MAE =  10.032110595703125 r2 =  0.5089128236998067 SE =  0.016833278594140404 lr =  0.001 hz =  140 dr =  0.6
# MAE =  10.805588340759277 r2 =  0.42663048320004265 SE =  0.014785386970905498 lr =  0.0001 hz =  140 dr =  0.6
# --- 3006.194023370743 seconds ---

# %%
start_time = time.time()
learning = [0.01, 0.001, 0.0001] 
best_score_k_fold = sys.maxsize

print('4 Layers Architecture')

for dropout in range(2,7):
    dropout = round(dropout*.1, 2) 
    for hidden_size in range(100, 150, 10):
        for lr in learning:  

            scores, r_values, std_errors = [], [], []
            cv = KFold(n_splits=5, random_state=42, shuffle=True)
            foldc = 1
            for train_index, test_index in cv.split(sentinel_frame, None):
                #print('Fold ', foldc, end =" ") 
                train, test  = sentinel_frame.iloc[train_index], sentinel_frame.iloc[test_index]

                train_c_t = get_categorical_tensor(train, categorical_columns).cuda()
                test_c_t = get_categorical_tensor(test, categorical_columns).cuda()
                train_n_t = get_numerical_tensor(train, numerical_columns).cuda()
                test_n_t = get_numerical_tensor(test, numerical_columns).cuda()

                outputs_train = torch.tensor(train['TOTAL'].values).flatten().type(torch.FloatTensor).cuda()
                outputs_test = torch.tensor(test['TOTAL'].values).flatten().type(torch.FloatTensor).cuda()

                best_fold_score, best_r_value, best_std_error = train_shallow_net(train_c_t,test_c_t,train_n_t,test_n_t,outputs_train,outputs_test, dropout, hidden_size, lr)
                scores.append(best_fold_score)
                r_values.append(best_r_value)
                std_errors.append(best_std_error)
                foldc += 1
            #print(scores)
            current_score = sum(scores) / len(scores)
            print('MAE = ', current_score ,'r2 = ', sum(r_values) / len(r_values) ,'SE = ', sum(std_errors) / len(std_errors),'lr = ', lr,'hz = ', hidden_size, 'dr = ', dropout )
            if current_score < best_score_k_fold:
                best_score_k_fold = current_score
                print('Best so far', best_score_k_fold)
                print('')


print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# 4 Layers Architecture
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-b43904d6ab32> in <module>()
#      25                 outputs_test = torch.tensor(test['TOTAL'].values).flatten().type(torch.FloatTensor).cuda()
#      26
# ---> 27                 best_fold_score, best_r_value, best_std_error = train_shallow_net(train_c_t,test_c_t,train_n_t,test_n_t,outputs_train,outputs_test, dropout, hidden_size, lr)
#      28                 scores.append(best_fold_score)
#      29                 r_values.append(best_r_value)
#
# <ipython-input-18-0af119bd94e1> in train_shallow_net(train_c_t, test_c_t, train_n_t, test_n_t, outputs_train, outputs_test, dropout, hidden_size, lr)
#       3     model.train().cuda()
#       4
# ----> 5     criterion = torch.nn.L1Loss()(reduction='mean')
#       6     params_dict = dict(model.named_parameters())
#       7     params = []
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# TypeError: forward() got an unexpected keyword argument 'reduction'

# %%
numerical_columns = ['pressure13', 'humidity6', 'humidity12', 'humidity14',
                     'humidity11', 'pressure14','uvIndex12', 'uvIndex5',
                     'uvIndex6', 'uvIndex10', 'uvIndex14', 'uvIndex13','uvIndex11','TRAPSET','TRAPCOLLECT']

# %%
sentinel_frame = pd.read_csv('/content/drive/My Drive/Colab/Mosquito_Berkeley/Approach2/original_mosquito_weather_semi_clean.csv')

sentinel_frame["TRAPSET"]= pd.to_datetime(sentinel_frame["TRAPSET"])
sentinel_frame["TRAPCOLLECT"]= pd.to_datetime(sentinel_frame["TRAPCOLLECT"])
sentinel_frame["DIFF_DAYS"] = (sentinel_frame["TRAPCOLLECT"] - sentinel_frame["TRAPSET"]).dt.days
sentinel_frame["TRAPSET"]= sentinel_frame["TRAPSET"].dt.week
sentinel_frame["TRAPCOLLECT"]= sentinel_frame["TRAPCOLLECT"].dt.week

sentinel_frame = sentinel_frame[['pressure13', 'humidity6', 'humidity12', 'humidity14',
                     'humidity11', 'pressure14','uvIndex12', 'uvIndex5',
                     'uvIndex6', 'uvIndex10', 'uvIndex14', 'uvIndex13','uvIndex11','TRAPSET','TRAPCOLLECT',
                     'temperatureMax12', 'temperatureHigh12', 'temperatureHigh13', 'temperatureMax13','precipIntensity13','apparentTemperatureHigh13','TRAPCOLLECT','TOTAL']]

for col in numerical_columns:
    sentinel_frame[col] = (sentinel_frame[col] - sentinel_frame[col].mean()) / (sentinel_frame[col].max() - sentinel_frame[col].min())
    
def get_categorical_tensor(in_frame, categories):
    categorical_data = np.stack([in_frame[col].cat.codes.values for col in categories], 1)
    categorical_data = torch.tensor(categorical_data, dtype=torch.int64)

    return categorical_data

def get_numerical_tensor(in_frame, numerical_columns):
    numerical_data = np.stack([in_frame[col].values for col in numerical_columns], 1)
    numerical_data = torch.tensor(numerical_data, dtype=torch.float)
    return numerical_data

# %%
class Flatten(torch.nn.Module):
    def forward(self, x):
        return x.view(x.size()[0], -1)

        
def create_neural_modules(num_numerical_cols, output_size, hidden_size, dropout):
    all_layers = []
    input_size = num_numerical_cols 
    all_layers.append(nn.Linear(input_size, hidden_size))
    all_layers.append(nn.LeakyReLU())
    all_layers.append(nn.BatchNorm1d(hidden_size))
    all_layers.append(nn.Dropout(dropout))

    all_layers.append(nn.Linear(hidden_size, hidden_size))
    all_layers.append(nn.LeakyReLU())
    all_layers.append(nn.BatchNorm1d(hidden_size))
    all_layers.append(nn.Dropout(dropout))

    all_layers.append(nn.Linear(hidden_size, hidden_size))
    all_layers.append(nn.LeakyReLU())
    all_layers.append(nn.BatchNorm1d(hidden_size))
    all_layers.append(nn.Dropout(dropout))
    
    all_layers.append(nn.Linear(hidden_size, hidden_size))
    all_layers.append(nn.LeakyReLU())
    all_layers.append(nn.BatchNorm1d(hidden_size))
    all_layers.append(nn.Dropout(dropout))

    all_layers.append(nn.Linear(hidden_size, output_size))
    all_layers.append(nn.ReLU())

    return nn.Sequential(*all_layers)

class Sentinel_net(nn.Module):

    def __init__(self, num_numerical_cols, output_size, dropout, hidden_size):
        super(Sentinel_net, self).__init__()
        self.layers = create_neural_modules(num_numerical_cols, output_size, hidden_size, dropout)
        self.batch_norm_num = nn.BatchNorm1d(num_numerical_cols)

    def forward(self, x_numerical):

        x_numerical = self.batch_norm_num(x_numerical)
        x_numerical = self.layers(x_numerical)

        return x_numerical

# %%
def train_shallow_net(train_n_t,test_n_t,outputs_train,outputs_test, dropout, hidden_size, lr):
    model = Sentinel_net(train_n_t.shape[1], 1, dropout, hidden_size)
    model.train().cuda()

    criterion = torch.nn.MSELoss(reduction='mean') 
    params_dict = dict(model.named_parameters())
    params = []
    best = sys.maxsize
    r_value = 0
    std_err = 0
    
    for key, value in params_dict.items():
        if 'weight' in key and 'layers' in key:
            params += [{'params':value, 'weight_decay':4e-3}]
        else:
            params += [{'params':value, 'weight_decay':0.0}]

    optimizer = torch.optim.RMSprop(params, lr=lr, alpha=0.99, eps=1e-08, weight_decay=0, momentum=0.9, centered=False)
    epoch = 0

    for i in range(1, 1000):
        y_pred = model( train_n_t)
        loss = criterion(y_pred.squeeze(), outputs_train)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        model.eval()
        with torch.no_grad():
            y_pred2 = model( test_n_t)
            c_out, c_pred = outputs_test.cpu().detach().numpy(), y_pred2.cpu().detach().numpy().squeeze()
            current_score = mean_absolute_error(c_out, c_pred)
            if current_score < best:
                best = current_score
                m, b, r_value, p_value, std_err = stats.linregress(c_out,c_pred)

            model.train()
    
    #print('MAE = ',current_score, 'r2 = ',r_value, 'SE = ',std_err)
    return best, r_value, std_err

# %%
start_time = time.time()
learning = [0.01, 0.001, 0.0001] 
best_score_k_fold = sys.maxsize

print('4 Layers Architecture')

for dropout in range(2,7):
    dropout = round(dropout*.1, 2) 
    for hidden_size in range(100, 150, 10):
        for lr in learning: 

            scores, r_values, std_errors = [], [], []
            cv = KFold(n_splits=5, random_state=42, shuffle=True)
            foldc = 1
            for train_index, test_index in cv.split(sentinel_frame, None):
                #print('Fold ', foldc, end =" ") 
                train, test  = sentinel_frame.iloc[train_index], sentinel_frame.iloc[test_index]
                train_n_t = get_numerical_tensor(train, numerical_columns).cuda()
                test_n_t = get_numerical_tensor(test, numerical_columns).cuda()

                outputs_train = torch.tensor(train['TOTAL'].values).flatten().type(torch.FloatTensor).cuda()
                outputs_test = torch.tensor(test['TOTAL'].values).flatten().type(torch.FloatTensor).cuda()

                best_fold_score, best_r_value, best_std_error = train_shallow_net(train_n_t,test_n_t,outputs_train,outputs_test, dropout, hidden_size, lr)
                scores.append(best_fold_score)
                r_values.append(best_r_value)
                std_errors.append(best_std_error)
                foldc += 1
            #print(scores)
            current_score = sum(scores) / len(scores)
            print('MAE = ', current_score ,'r2 = ', sum(r_values) / len(r_values) ,'SE = ', sum(std_errors) / len(std_errors),'lr = ', lr,'hz = ', hidden_size, 'dr = ', dropout )
            if current_score < best_score_k_fold:
                best_score_k_fold = current_score
                print('Best so far', best_score_k_fold)
                print('')


print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# 4 Layers Architecture
# MAE =  10.888934707641601 r2 =  0.24507840790041638 SE =  0.009977577556411163 lr =  0.01 hz =  100 dr =  0.2
# Best so far 10.888934707641601
#
# MAE =  11.833579444885254 r2 =  0.2610217087362604 SE =  0.014741444660635367 lr =  0.001 hz =  100 dr =  0.2
# MAE =  12.503955268859864 r2 =  0.22781815223868226 SE =  0.014935868506786612 lr =  0.0001 hz =  100 dr =  0.2
