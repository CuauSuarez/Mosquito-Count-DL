# %%
import argparse
import yaml
import time
import datetime
import cv2
import numpy as np
import pandas as pd
import random

from skimage import io, transform
import matplotlib.pyplot as plt
from scipy.ndimage import zoom
from scipy import ndimage, misc

import torch
import torch.utils.data
from torch import nn, optim
from torch.nn import functional as F
from torchvision import datasets, transforms, utils
from torchvision.utils import save_image
from torch.utils.data import Dataset, DataLoader
import torchvision
import torch
from torch.autograd import Variable
import torch.optim as optim

from google.colab import drive
import os
import warnings
from collections import defaultdict

# %%
drive.mount('/content/drive', force_remount = True)
os.chdir('/content/drive/My Drive/Mosquito-Tec')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
### Dataset functions

def paddedzoom(img, zoomfactor = 0.8):
    out  = np.zeros_like(img)
    zoomed = cv2.resize(img, None, fx = zoomfactor, fy = zoomfactor)
    
    h, w, _ = img.shape
    zh, zw, _ = zoomed.shape
    if zoomfactor < 1:    
        out[int((h - zh) / 2):int(-(h - zh) / 2), 
            int((w - zw) / 2):int(-(w - zw) / 2), :] = zoomed
    else:
        out = zoomed[int((zh - h) / 2):int(-(zh - h) / 2), 
                     int((zw - w) / 2):int(-(zw - w) / 2), :]

    return out

class SentinelDataset(Dataset):

    def __init__(self, csv_file, root_dir, training = True, transform = None):
        self.sentinel_frame = pd.read_csv(csv_file)
        self.root_dir = root_dir
        self.transform = transform
        self.training = training
        self.mean = np.array([[[0.0151]], [[0.0166]], [[0.0188]], [[0.0181]], 
                              [[0.0226]], [[0.0342]], [[0.0385]], [[0.0396]], 
                              [[0.0413]], [[0.0310]], [[0.0221]]])
        self.std =  np.array([[[0.0181]], [[0.0201]], [[0.0190]], [[0.0193]],
                              [[0.0191]], [[0.0187]], [[0.0195]], [[0.0207]],
                              [[0.0322]], [[0.0162]], [[0.0145]]])

    def __len__(self):
        return len(self.sentinel_frame)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()
        
        filename = str('data' + str(self.sentinel_frame.iloc[idx, 0]) + '.npy')

        img_name = os.path.join(self.root_dir, filename)
        image = np.load(img_name).astype(np.float32) / 65536

        #normalization
        image /= image.max()
        #image = (image - self.mean)/self.std 

        if self.training:
            #random flip
            if np.random.rand() > 0.5:
                image = np.flip(image, axis=2).copy()

            #random rotate
            image = ndimage.rotate(image, random.randint(-20, 20), axes = [1,2], 
                                   reshape = False)

            # random zoom
            or_image = image.copy()
            image =  np.swapaxes(image,0,2)
            image = paddedzoom(image, 1.0 + (np.random.rand()/2) )
            image =  np.swapaxes(image,0,2)
            if image.shape != or_image.shape:
                image = or_image

        if self.transform:
            image = self.transform(image)

        target = self.sentinel_frame.iloc[idx, -1]
        image = torch.from_numpy(image)
        return image, target

# %%
def crop(x, th, tw):
        _, _, w, h = x.size()
        x1 = int(round((w - tw) / 2.))
        y1 = int(round((h - th) / 2.))
        return x[:, :, x1:x1 + tw, y1:y1 + th]

# %%
BATCH_SIZE = 32

sentinel_dataset = SentinelDataset(csv_file = '/content/drive/My Drive/Colab/mosquito/Final_Mosquito_train.csv',
                                    root_dir = '/content/drive/My Drive/Colab/mosquito/data_mosquito/', training = True)

sentinel_dataset_test = SentinelDataset(csv_file = '/content/drive/My Drive/Colab/mosquito/Final_Mosquito_test.csv',
                                    root_dir = '/content/drive/My Drive/Colab/mosquito/data_mosquito/', training = False)

train_loader = DataLoader(sentinel_dataset, batch_size = BATCH_SIZE, 
                          shuffle = True, num_workers = 1)

test_loader = DataLoader(sentinel_dataset_test, batch_size = BATCH_SIZE, 
                         shuffle = False, num_workers=1)

# %%
def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

# %%
dataiter = iter(train_loader)
# the "_" is a placeholder for no labels
images, _ = dataiter.next()
print(images.shape)

# show images
fig = plt.figure(figsize=(12, 8))
images = images[0:8, 2:5, :, :]
images[:, 0, :, :] = torch.from_numpy(cv2.normalize(images[:, 0, :, :].numpy(), 
                                                    None, 0, 255, 
                                                    cv2.NORM_MINMAX, 
                                                    dtype = cv2.CV_8U) / 255.)
images[:, 1, :, :] = torch.from_numpy(cv2.normalize(images[:, 1, :, :].numpy(), 
                                                    None, 0, 255, 
                                                    cv2.NORM_MINMAX, 
                                                    dtype = cv2.CV_8U) / 255.)
images[:, 2, :, :] = torch.from_numpy(cv2.normalize(images[:, 2, :, :].numpy(), 
                                                    None, 0, 255, 
                                                    cv2.NORM_MINMAX, 
                                                    dtype = cv2.CV_8U) / 255.)

imshow(torchvision.utils.make_grid(images))
# Out:
# torch.Size([32, 11, 104, 104])

# %%
class Flatten(torch.nn.Module):
    def forward(self, x):
        return x.view(x.size(0), -1)
    
class Reshape(torch.nn.Module):
    def __init__(self, outer_shape):
        super(Reshape, self).__init__()
        self.outer_shape = outer_shape
    def forward(self, x):
        return x.view(x.size(0), *self.outer_shape)

# %%
# Encoder and decoder use the DC-GAN architecture
class Encoder(torch.nn.Module):
    def __init__(self, c, z_dim, n_latent):
        super(Encoder, self).__init__()
        self.model = torch.nn.ModuleList([
            nn.Conv2d(c, 32, 4, 2, padding=1),
            nn.LeakyReLU(),
            nn.Conv2d(32, 64, 4, 2, padding=1),
            nn.LeakyReLU(),
            Flatten(),
            nn.Linear(64 * z_dim**2, 1024),
            nn.LeakyReLU(),
            nn.Linear(1024, n_latent)
        ])
        
    def forward(self, x):
        i = 1
        for layer in self.model:
            x = layer(x)
        return x
    
    
class Decoder(torch.nn.Module):
    def __init__(self, c, z_dim, n_latent):
        super(Decoder, self).__init__()
        self.model = torch.nn.ModuleList([
            nn.Linear(n_latent, 1024),
            nn.ReLU(),
            nn.Linear(1024, 64 * z_dim**2),
            nn.ReLU(),
            Reshape((64, z_dim, z_dim,)),
            nn.ConvTranspose2d(64, 32, 4, 2, padding=1),
            nn.ReLU(),
            nn.ConvTranspose2d(32, c, 4, 2, padding=1),
            nn.Sigmoid()
        ])
        
    def forward(self, x):
        for layer in self.model:
            x = layer(x)
        return x

# %%
def compute_kernel(x, y):
    x_size = x.size(0)
    y_size = y.size(0)
    dim = x.size(1)
    x = x.unsqueeze(1) # (x_size, 1, dim)
    y = y.unsqueeze(0) # (1, y_size, dim)
    tiled_x = x.expand(x_size, y_size, dim)
    tiled_y = y.expand(x_size, y_size, dim)
    kernel_input = (tiled_x - tiled_y).pow(2).mean(2) / float(dim)
    return torch.exp(-kernel_input) # (x_size, y_size)

def compute_mmd(x, y):
    x_kernel = compute_kernel(x, x)
    y_kernel = compute_kernel(y, y)
    xy_kernel = compute_kernel(x, y)
    mmd = x_kernel.mean() + y_kernel.mean() - 2*xy_kernel.mean()
    return mmd

# %%
class MMD_VAE(torch.nn.Module):
    def __init__(self, in_shape, n_latent):
        super(MMD_VAE, self).__init__()
        self.in_shape = in_shape
        self.n_latent = n_latent
        self.c, self.h, self.w = in_shape
        self.z_dim = self.h // 2**2
        self.encoder = Encoder(self.c, self.z_dim, self.n_latent)
        self.decoder = Decoder(self.c, self.z_dim, self.n_latent)
        
    def forward(self, x):
        z = self.encoder(x)
        x_reconstructed = self.decoder(z)
        x_reconstructed = crop(x_reconstructed, self.h, self.h)
        return z, x_reconstructed

# %%
# Convert a numpy array of shape [batch_size, height, width, 1] into a displayable array 
# of shape [height*sqrt(batch_size, width*sqrt(batch_size))] by tiling the images
def convert_to_display(samples):
    cnt, height, width = int(math.floor(math.sqrt(samples.shape[0]))), samples.shape[1], samples.shape[2]
    samples = np.transpose(samples, axes=[1, 0, 2, 3])
    samples = np.reshape(samples, [height, cnt, cnt, width])
    samples = np.transpose(samples, axes=[1, 0, 2, 3])
    samples = np.reshape(samples, [height*cnt, width*cnt])
    return samples

def train(epoch, model, loader, optimizer, device, logs_interval, n_latent):
    model.train()
    train_loss = 0

    for batch_idx, (inputs, _) in enumerate(loader):
        inputs = inputs.to(device)
        true_samples = Variable(
            torch.randn(200, n_latent),
            requires_grad = False
        ).to(device)

        z, output = model(inputs)
        mmd = compute_mmd(true_samples, z)
        nll = (output - inputs).pow(2).mean()
        loss = nll + mmd

        optimizer.zero_grad()
        loss.backward()
        train_loss += loss.item()
        optimizer.step()


        if batch_idx % logs_interval == 0:
            print("Negative log likelihood is {:.5f}, mmd loss is {:.5f}".format(
                    nll.item(), mmd.item()))
            
    print('====> Epoch: {} Average loss: {:.4f}'.format(
          epoch, train_loss / len(loader.dataset)))

# %%
# Model
device = None
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

n_latent = 100

model = MMD_VAE((11, 104, 104), n_latent = n_latent).to(device).double()
optimizer = torch.optim.Adam(model.parameters())
#optimizer = optim.RMSprop(model.parameters(), lr = 1e-4)

# %%
EPOCHS = 70

for epoch in range(1, EPOCHS + 1):
    train(epoch, model, train_loader, optimizer, device, 20, n_latent)
    if epoch % 10 == 0:
        torch.save({
            'iter': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            },
            os.path.join('./last_mmd_vae.ckpt'))
# Out:
# Negative log likelihood is 0.10523, mmd loss is 0.00020
# Negative log likelihood is 0.02153, mmd loss is 0.00128
# Negative log likelihood is 0.01855, mmd loss is 0.00024
# ====> Epoch: 1 Average loss: 0.0010
# Negative log likelihood is 0.01361, mmd loss is 0.00024
# Negative log likelihood is 0.01465, mmd loss is 0.00023
# Negative log likelihood is 0.01581, mmd loss is 0.00025
# ====> Epoch: 2 Average loss: 0.0005
# Negative log likelihood is 0.01186, mmd loss is 0.00017
# Negative log likelihood is 0.01352, mmd loss is 0.00023
# Negative log likelihood is 0.01105, mmd loss is 0.00020
# ====> Epoch: 3 Average loss: 0.0004
# Negative log likelihood is 0.01021, mmd loss is 0.00030
# Negative log likelihood is 0.00896, mmd loss is 0.00024
# Negative log likelihood is 0.00763, mmd loss is 0.00019
# ====> Epoch: 4 Average loss: 0.0003
# Negative log likelihood is 0.00882, mmd loss is 0.00021
# Negative log likelihood is 0.00811, mmd loss is 0.00021
# Negative log likelihood is 0.00952, mmd loss is 0.00021
# ====> Epoch: 5 Average loss: 0.0003
# Negative log likelihood is 0.00683, mmd loss is 0.00021
# Negative log likelihood is 0.00753, mmd loss is 0.00021
# Negative log likelihood is 0.00889, mmd loss is 0.00025
# ====> Epoch: 6 Average loss: 0.0002
# Negative log likelihood is 0.00602, mmd loss is 0.00021
# Negative log likelihood is 0.00704, mmd loss is 0.00025
# Negative log likelihood is 0.00756, mmd loss is 0.00022
# ====> Epoch: 7 Average loss: 0.0002
# Negative log likelihood is 0.00552, mmd loss is 0.00023
# Negative log likelihood is 0.00572, mmd loss is 0.00025
# Negative log likelihood is 0.00586, mmd loss is 0.00025
# ====> Epoch: 8 Average loss: 0.0002
# Negative log likelihood is 0.00554, mmd loss is 0.00021
# Negative log likelihood is 0.00747, mmd loss is 0.00021
# Negative log likelihood is 0.00591, mmd loss is 0.00024
# ====> Epoch: 9 Average loss: 0.0002
# Negative log likelihood is 0.00582, mmd loss is 0.00020
# Negative log likelihood is 0.00501, mmd loss is 0.00019
# Negative log likelihood is 0.00562, mmd loss is 0.00023
# ====> Epoch: 10 Average loss: 0.0002
# Negative log likelihood is 0.00556, mmd loss is 0.00022
# Negative log likelihood is 0.00600, mmd loss is 0.00020
# Negative log likelihood is 0.00607, mmd loss is 0.00022
# ====> Epoch: 11 Average loss: 0.0002
# Negative log likelihood is 0.00579, mmd loss is 0.00024
# Negative log likelihood is 0.00530, mmd loss is 0.00021
# Negative log likelihood is 0.00611, mmd loss is 0.00022
# ====> Epoch: 12 Average loss: 0.0002
# Negative log likelihood is 0.00450, mmd loss is 0.00022
# Negative log likelihood is 0.00499, mmd loss is 0.00020
# Negative log likelihood is 0.00423, mmd loss is 0.00024
# ====> Epoch: 13 Average loss: 0.0002
# Negative log likelihood is 0.00497, mmd loss is 0.00021
# Negative log likelihood is 0.00460, mmd loss is 0.00021
# Negative log likelihood is 0.00457, mmd loss is 0.00020
# ====> Epoch: 14 Average loss: 0.0002
# Negative log likelihood is 0.00454, mmd loss is 0.00023
# Negative log likelihood is 0.00434, mmd loss is 0.00019
# Negative log likelihood is 0.00487, mmd loss is 0.00025
# ====> Epoch: 15 Average loss: 0.0002
# Negative log likelihood is 0.00442, mmd loss is 0.00023
# Negative log likelihood is 0.00486, mmd loss is 0.00023
# Negative log likelihood is 0.00460, mmd loss is 0.00024
# ====> Epoch: 16 Average loss: 0.0002
# Negative log likelihood is 0.00452, mmd loss is 0.00023
# Negative log likelihood is 0.00451, mmd loss is 0.00019
# Negative log likelihood is 0.00411, mmd loss is 0.00023
# ====> Epoch: 17 Average loss: 0.0001
# Negative log likelihood is 0.00419, mmd loss is 0.00021
# Negative log likelihood is 0.00435, mmd loss is 0.00022
# Negative log likelihood is 0.00505, mmd loss is 0.00026
# ====> Epoch: 18 Average loss: 0.0001
# Negative log likelihood is 0.00442, mmd loss is 0.00023
# Negative log likelihood is 0.00474, mmd loss is 0.00021
# Negative log likelihood is 0.00399, mmd loss is 0.00021
# ====> Epoch: 19 Average loss: 0.0001
# Negative log likelihood is 0.00418, mmd loss is 0.00022
# Negative log likelihood is 0.00442, mmd loss is 0.00018
# Negative log likelihood is 0.00407, mmd loss is 0.00026
# ====> Epoch: 20 Average loss: 0.0001
# Negative log likelihood is 0.00414, mmd loss is 0.00022
# Negative log likelihood is 0.00459, mmd loss is 0.00022
# Negative log likelihood is 0.00400, mmd loss is 0.00019
# ====> Epoch: 21 Average loss: 0.0001
# Negative log likelihood is 0.00424, mmd loss is 0.00025
# Negative log likelihood is 0.00463, mmd loss is 0.00022
# Negative log likelihood is 0.00464, mmd loss is 0.00026
# ====> Epoch: 22 Average loss: 0.0001
# Negative log likelihood is 0.00350, mmd loss is 0.00022
# Negative log likelihood is 0.00443, mmd loss is 0.00022
# Negative log likelihood is 0.00381, mmd loss is 0.00022
# ====> Epoch: 23 Average loss: 0.0001
# Negative log likelihood is 0.00314, mmd loss is 0.00023
# Negative log likelihood is 0.00324, mmd loss is 0.00020
# Negative log likelihood is 0.00358, mmd loss is 0.00019
# ====> Epoch: 24 Average loss: 0.0001
# Negative log likelihood is 0.00415, mmd loss is 0.00023
# Negative log likelihood is 0.00429, mmd loss is 0.00021
# Negative log likelihood is 0.00319, mmd loss is 0.00024
# ====> Epoch: 25 Average loss: 0.0001
# Negative log likelihood is 0.00399, mmd loss is 0.00025
# Negative log likelihood is 0.00416, mmd loss is 0.00022
# Negative log likelihood is 0.00370, mmd loss is 0.00022
# ====> Epoch: 26 Average loss: 0.0001
# Negative log likelihood is 0.00338, mmd loss is 0.00026
# Negative log likelihood is 0.00373, mmd loss is 0.00026
# Negative log likelihood is 0.00378, mmd loss is 0.00021
# ====> Epoch: 27 Average loss: 0.0001
# Negative log likelihood is 0.00362, mmd loss is 0.00023
# Negative log likelihood is 0.00345, mmd loss is 0.00023
# Negative log likelihood is 0.00364, mmd loss is 0.00022
# ====> Epoch: 28 Average loss: 0.0001
# Negative log likelihood is 0.00399, mmd loss is 0.00023
# Negative log likelihood is 0.00362, mmd loss is 0.00020
# Negative log likelihood is 0.00297, mmd loss is 0.00022
# ====> Epoch: 29 Average loss: 0.0001
# Negative log likelihood is 0.00354, mmd loss is 0.00022
# Negative log likelihood is 0.00357, mmd loss is 0.00021
# Negative log likelihood is 0.00396, mmd loss is 0.00024
# ====> Epoch: 30 Average loss: 0.0001
# Negative log likelihood is 0.00302, mmd loss is 0.00020
# Negative log likelihood is 0.00353, mmd loss is 0.00021
# Negative log likelihood is 0.00352, mmd loss is 0.00022
# ====> Epoch: 31 Average loss: 0.0001
# Negative log likelihood is 0.00360, mmd loss is 0.00021
# Negative log likelihood is 0.00370, mmd loss is 0.00025
# Negative log likelihood is 0.00340, mmd loss is 0.00021
# ====> Epoch: 32 Average loss: 0.0001
# Negative log likelihood is 0.00322, mmd loss is 0.00024
# Negative log likelihood is 0.00302, mmd loss is 0.00026
# Negative log likelihood is 0.00340, mmd loss is 0.00020
# ====> Epoch: 33 Average loss: 0.0001
# Negative log likelihood is 0.00290, mmd loss is 0.00021
# Negative log likelihood is 0.00343, mmd loss is 0.00025
# Negative log likelihood is 0.00324, mmd loss is 0.00022
# ====> Epoch: 34 Average loss: 0.0001
# Negative log likelihood is 0.00284, mmd loss is 0.00020
# Negative log likelihood is 0.00289, mmd loss is 0.00026
# Negative log likelihood is 0.00293, mmd loss is 0.00024
# ====> Epoch: 35 Average loss: 0.0001
# Negative log likelihood is 0.00314, mmd loss is 0.00022
# Negative log likelihood is 0.00325, mmd loss is 0.00023
# Negative log likelihood is 0.00313, mmd loss is 0.00025
# ====> Epoch: 36 Average loss: 0.0001
# Negative log likelihood is 0.00284, mmd loss is 0.00021
# Negative log likelihood is 0.00313, mmd loss is 0.00023
# Negative log likelihood is 0.00294, mmd loss is 0.00023
# ====> Epoch: 37 Average loss: 0.0001
# Negative log likelihood is 0.00326, mmd loss is 0.00022
# Negative log likelihood is 0.00307, mmd loss is 0.00023
# Negative log likelihood is 0.00290, mmd loss is 0.00019
# ====> Epoch: 38 Average loss: 0.0001
# Negative log likelihood is 0.00319, mmd loss is 0.00023
# Negative log likelihood is 0.00305, mmd loss is 0.00023
# Negative log likelihood is 0.00296, mmd loss is 0.00023
# ====> Epoch: 39 Average loss: 0.0001
# Negative log likelihood is 0.00294, mmd loss is 0.00023
# Negative log likelihood is 0.00282, mmd loss is 0.00022
# Negative log likelihood is 0.00308, mmd loss is 0.00022
# ====> Epoch: 40 Average loss: 0.0001
# Negative log likelihood is 0.00288, mmd loss is 0.00024
# Negative log likelihood is 0.00319, mmd loss is 0.00024
# Negative log likelihood is 0.00310, mmd loss is 0.00020
# ====> Epoch: 41 Average loss: 0.0001
# Negative log likelihood is 0.00285, mmd loss is 0.00023
# Negative log likelihood is 0.00285, mmd loss is 0.00027
# Negative log likelihood is 0.00283, mmd loss is 0.00024
# ====> Epoch: 42 Average loss: 0.0001
# Negative log likelihood is 0.00316, mmd loss is 0.00022
# Negative log likelihood is 0.00291, mmd loss is 0.00024
# Negative log likelihood is 0.00291, mmd loss is 0.00022
# ====> Epoch: 43 Average loss: 0.0001
# Negative log likelihood is 0.00344, mmd loss is 0.00021
# Negative log likelihood is 0.00284, mmd loss is 0.00021
# Negative log likelihood is 0.00278, mmd loss is 0.00020
# ====> Epoch: 44 Average loss: 0.0001
# Negative log likelihood is 0.00257, mmd loss is 0.00024
# Negative log likelihood is 0.00335, mmd loss is 0.00024
# Negative log likelihood is 0.00305, mmd loss is 0.00021
# ====> Epoch: 45 Average loss: 0.0001
# Negative log likelihood is 0.00264, mmd loss is 0.00024
# Negative log likelihood is 0.00253, mmd loss is 0.00022
# Negative log likelihood is 0.00263, mmd loss is 0.00017
# ====> Epoch: 46 Average loss: 0.0001
# Negative log likelihood is 0.00291, mmd loss is 0.00022
# Negative log likelihood is 0.00268, mmd loss is 0.00021
# Negative log likelihood is 0.00284, mmd loss is 0.00023
# ====> Epoch: 47 Average loss: 0.0001
# Negative log likelihood is 0.00274, mmd loss is 0.00021
# Negative log likelihood is 0.00301, mmd loss is 0.00024
# Negative log likelihood is 0.00281, mmd loss is 0.00026
# ====> Epoch: 48 Average loss: 0.0001
# Negative log likelihood is 0.00294, mmd loss is 0.00026
# Negative log likelihood is 0.00292, mmd loss is 0.00025
# Negative log likelihood is 0.00315, mmd loss is 0.00020
# ====> Epoch: 49 Average loss: 0.0001
# Negative log likelihood is 0.00265, mmd loss is 0.00020
# Negative log likelihood is 0.00246, mmd loss is 0.00022
# Negative log likelihood is 0.00276, mmd loss is 0.00025
# ====> Epoch: 50 Average loss: 0.0001
# Negative log likelihood is 0.00274, mmd loss is 0.00026
# Negative log likelihood is 0.00316, mmd loss is 0.00026
# Negative log likelihood is 0.00291, mmd loss is 0.00024
# ====> Epoch: 51 Average loss: 0.0001
# Negative log likelihood is 0.00311, mmd loss is 0.00023
# Negative log likelihood is 0.00291, mmd loss is 0.00021
# Negative log likelihood is 0.00293, mmd loss is 0.00021
# ====> Epoch: 52 Average loss: 0.0001
# Negative log likelihood is 0.00272, mmd loss is 0.00025
# Negative log likelihood is 0.00280, mmd loss is 0.00022
# Negative log likelihood is 0.00246, mmd loss is 0.00019
# ====> Epoch: 53 Average loss: 0.0001
# Negative log likelihood is 0.00309, mmd loss is 0.00026
# Negative log likelihood is 0.00246, mmd loss is 0.00019
# Negative log likelihood is 0.00273, mmd loss is 0.00025
# ====> Epoch: 54 Average loss: 0.0001
# Negative log likelihood is 0.00253, mmd loss is 0.00020
# Negative log likelihood is 0.00251, mmd loss is 0.00021
# Negative log likelihood is 0.00250, mmd loss is 0.00023
# ====> Epoch: 55 Average loss: 0.0001
# Negative log likelihood is 0.00218, mmd loss is 0.00022
# Negative log likelihood is 0.00252, mmd loss is 0.00020
# Negative log likelihood is 0.00218, mmd loss is 0.00019
# ====> Epoch: 56 Average loss: 0.0001
# Negative log likelihood is 0.00259, mmd loss is 0.00023
# Negative log likelihood is 0.00236, mmd loss is 0.00020
# Negative log likelihood is 0.00246, mmd loss is 0.00021
# ====> Epoch: 57 Average loss: 0.0001
# Negative log likelihood is 0.00260, mmd loss is 0.00022
# Negative log likelihood is 0.00251, mmd loss is 0.00024
# Negative log likelihood is 0.00256, mmd loss is 0.00025
# ====> Epoch: 58 Average loss: 0.0001
# Negative log likelihood is 0.00238, mmd loss is 0.00022
# Negative log likelihood is 0.00244, mmd loss is 0.00020
# Negative log likelihood is 0.00286, mmd loss is 0.00025
# ====> Epoch: 59 Average loss: 0.0001
# Negative log likelihood is 0.00238, mmd loss is 0.00025
# Negative log likelihood is 0.00236, mmd loss is 0.00021
# Negative log likelihood is 0.00238, mmd loss is 0.00020
# ====> Epoch: 60 Average loss: 0.0001
# Negative log likelihood is 0.00262, mmd loss is 0.00019
# Negative log likelihood is 0.00251, mmd loss is 0.00023
# Negative log likelihood is 0.00247, mmd loss is 0.00023
# ====> Epoch: 61 Average loss: 0.0001
# Negative log likelihood is 0.00236, mmd loss is 0.00023
# Negative log likelihood is 0.00227, mmd loss is 0.00019
# Negative log likelihood is 0.00248, mmd loss is 0.00020
# ====> Epoch: 62 Average loss: 0.0001
# Negative log likelihood is 0.00224, mmd loss is 0.00024
# Negative log likelihood is 0.00231, mmd loss is 0.00019
# Negative log likelihood is 0.00258, mmd loss is 0.00023
# ====> Epoch: 63 Average loss: 0.0001
# Negative log likelihood is 0.00253, mmd loss is 0.00024
# Negative log likelihood is 0.00230, mmd loss is 0.00021
# Negative log likelihood is 0.00229, mmd loss is 0.00024
# ====> Epoch: 64 Average loss: 0.0001
# Negative log likelihood is 0.00240, mmd loss is 0.00021
# Negative log likelihood is 0.00254, mmd loss is 0.00022
# Negative log likelihood is 0.00244, mmd loss is 0.00022
# ====> Epoch: 65 Average loss: 0.0001
# Negative log likelihood is 0.00246, mmd loss is 0.00027
# Negative log likelihood is 0.00211, mmd loss is 0.00020
# Negative log likelihood is 0.00233, mmd loss is 0.00022
# ====> Epoch: 66 Average loss: 0.0001
# Negative log likelihood is 0.00245, mmd loss is 0.00023
# Negative log likelihood is 0.00239, mmd loss is 0.00021
# Negative log likelihood is 0.00221, mmd loss is 0.00019
# ====> Epoch: 67 Average loss: 0.0001
# Negative log likelihood is 0.00229, mmd loss is 0.00021
# Negative log likelihood is 0.00228, mmd loss is 0.00022
# Negative log likelihood is 0.00271, mmd loss is 0.00021
# ====> Epoch: 68 Average loss: 0.0001
# Negative log likelihood is 0.00221, mmd loss is 0.00024
# Negative log likelihood is 0.00261, mmd loss is 0.00022
# Negative log likelihood is 0.00226, mmd loss is 0.00021
# ====> Epoch: 69 Average loss: 0.0001
# Negative log likelihood is 0.00245, mmd loss is 0.00021
# Negative log likelihood is 0.00229, mmd loss is 0.00022
# Negative log likelihood is 0.00231, mmd loss is 0.00020
# ====> Epoch: 70 Average loss: 0.0001

# %%
dataiter = iter(test_loader)
# the "_" is a placeholder for no labels
images, _ = dataiter.next()

# show images
fig = plt.figure(figsize=(12, 8))
images[:, 2, :, :] = torch.from_numpy(cv2.normalize(images[:, 0, :, :].numpy(), 
                                                    None, 0, 255, 
                                                    cv2.NORM_MINMAX, 
                                                    dtype = cv2.CV_8U) / 255.)
images[:, 3, :, :] = torch.from_numpy(cv2.normalize(images[:, 1, :, :].numpy(), 
                                                    None, 0, 255, 
                                                    cv2.NORM_MINMAX, 
                                                    dtype = cv2.CV_8U) / 255.)
images[:, 4, :, :] = torch.from_numpy(cv2.normalize(images[:, 2, :, :].numpy(), 
                                                    None, 0, 255, 
                                                    cv2.NORM_MINMAX, 
                                                    dtype = cv2.CV_8U) / 255.)
imshow(torchvision.utils.make_grid(images[0:8, 2:5, :, :]))

_, out = model(images.to(device).double())
fig = plt.figure(figsize=(12, 8))
images2 = out.to('cpu').detach()
imshow(torchvision.utils.make_grid(images2[0:8, 2:5, :, :]))
